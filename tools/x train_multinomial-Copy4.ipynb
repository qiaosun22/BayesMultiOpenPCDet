# %% [markdown]
# 怀疑是ADAM优化器导致的崩溃，换 SGD，固定前面层，从 ckpt80multi 开始微调
#
# 结论：还是不行
#
# 已完成：调整学习率，降低代码复杂度

# %%
import tqdm
from torch.nn.utils import clip_grad_norm_
from pcdet.models_multinomial_half.detectors.pointpillar import PointPillar

import argparse
import datetime
import glob
import os
from pathlib import Path
from test import repeat_eval_ckpt, eval_single_ckpt
from noise import add_noise_to_weights
import numba
import logging
import time

from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events

import torch
import torch.distributed as dist
import torch.nn as nn
from tensorboardX import SummaryWriter

from pcdet.config import cfg, cfg_from_list, cfg_from_yaml_file, log_config_to_file
from pcdet.datasets import build_dataloader
from pcdet.models_multinomial_half import build_network, model_fn_decorator
from pcdet.utils import common_utils
from train_utils.optimization import build_optimizer, build_scheduler
# from train_utils.train_utils import train_model
# from eval_utils import eval_utils_multinomial
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
from eval_utils import eval_utils_multinomial_finalv_half as eval_utils



def load_data_to_gpu(batch_dict):
    for key, val in batch_dict.items():
        if not isinstance(val, np.ndarray):
            continue
        elif key in ['frame_id', 'metadata', 'calib']:
            continue
        elif key in ['images']:
            batch_dict[key] = image_to_tensor(val).float().cuda().contiguous()
        elif key in ['image_shape']:
            batch_dict[key] = torch.from_numpy(val).int().cuda()
        else:
            batch_dict[key] = torch.from_numpy(val).float().cuda()


def parse_config():
    parser = argparse.ArgumentParser(description='arg parser')
    parser.add_argument('--cfg_file', type=str, default='./cfgs/kitti_models/pointpillar_bayes.yaml', help='specify the config for training')
    parser.add_argument('--batch_size', type=int, default=8, required=False, help='batch size for training')
    parser.add_argument('--workers', type=int, default=32, help='number of workers for dataloader')
    parser.add_argument('--extra_tag', type=str, default='default', help='extra tag for this experiment')
    parser.add_argument('--pretrained_model', type=str, default=True, help='pretrained_model')
    parser.add_argument('--launcher', choices=['none', 'pytorch', 'slurm'], default='none')
    parser.add_argument('--tcp_port', type=int, default=18888, help='tcp port for distrbuted training')
    parser.add_argument('--sync_bn', action='store_true', default=False, help='whether to use sync bn')
    parser.add_argument('--fix_random_seed', action='store_true', default=True, help='')
    parser.add_argument('--ckpt_save_interval', type=int, default=80, help='number of training epochs')
    parser.add_argument('--local_rank', type=int, default=0, help='local rank for distributed training')
    parser.add_argument('--max_ckpt_save_num', type=int, default=81, help='max number of saved checkpoint')
    parser.add_argument('--merge_all_iters_to_one_epoch', action='store_true', default=False, help='')
    parser.add_argument('--set', dest='set_cfgs', default=None, nargs=argparse.REMAINDER, help='set extra config keys if needed')
    parser.add_argument('--max_waiting_mins', type=int, default=0, help='max waiting minutes')
    parser.add_argument('--start_epoch', type=int, default=0, help='')
    parser.add_argument('--save_to_file', action='store_true', default=False, help='')

    parser.add_argument('--epochs', type=int, default=800, required=False, help='number of epochs to train for')
    parser.add_argument('--ckpt', type=str, default='checkpoint_epoch_80_bayes.pth', help='checkpoint to start from')
    # sunqiao/OpenPCDet/tools/save_path/0722/ckpt_epoch84.pth
    args = parser.parse_known_args()[0]

    cfg_from_yaml_file(args.cfg_file, cfg)
    cfg.TAG = Path(args.cfg_file).stem
    cfg.EXP_GROUP_PATH = '/'.join(args.cfg_file.split('/')[1: -1])  # remove 'cfgs' and 'xxxx.yaml'

    if args.set_cfgs is not None:
        cfg_from_list(args.set_cfgs, cfg)

    return args, cfg




if __name__ == '__main__':
    torch.cuda.set_device(0)

    args, cfg = parse_config()
    dist_train = False
    total_gpus = 1
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
    os.system('nvidia-smi -q -d Memory |grep -A4 GPU|grep Free >tmp')
    memory_gpu = [int(x.split()[2]) for x in open('tmp', 'r').readlines()]
    print('Using GPU:' + str(np.argmax(memory_gpu)))
    os.environ["CUDA_VISIBLE_DEVICES"] = str(np.argmax(memory_gpu))
    os.system('rm tmp')


    if args.batch_size is None:
        args.batch_size = cfg.OPTIMIZATION.BATCH_SIZE_PER_GPU
    else:
        assert args.batch_size % total_gpus == 0, 'Batch size should match the number of gpus'
        args.batch_size = args.batch_size // total_gpus

    args.epochs = cfg.OPTIMIZATION.NUM_EPOCHS if args.epochs is None else args.epochs
    
    common_utils.set_random_seed(666)
    save_path = './save_path/logger/'#/bayes/pointpillar/'+time.strftime('%m%d-%H%M',time.localtime(time.time()))+'/'

    logger = common_utils.create_logger(save_path+'log.txt', rank=cfg.LOCAL_RANK)
    
    print("=============")
    p1 = 0.23
    p2 = 0.77
    p3 = 0.68
    print(p1, p2, p3)
    print("=============")
    

    train_set, train_loader, train_sampler = build_dataloader(
        dataset_cfg=cfg.DATA_CONFIG,
        class_names=cfg.CLASS_NAMES,
        batch_size=args.batch_size,
        dist=dist_train, workers=args.workers,
        logger=logger,
        training=True,
        merge_all_iters_to_one_epoch=args.merge_all_iters_to_one_epoch,
        total_epochs=args.epochs
    )
    
    test_set, test_loader, sampler = build_dataloader(
                                    dataset_cfg=cfg.DATA_CONFIG,
                                    class_names=cfg.CLASS_NAMES,
                                    batch_size=args.batch_size,
                                    dist=dist_train, workers=args.workers, logger=logger, training=False
    )
    
    model = PointPillar(
        model_cfg=cfg.MODEL, num_class=len(cfg.CLASS_NAMES), p1=p1, p2=p2, p3=p3, dataset=train_set
    )
    
    model.load_state_dict(torch.load(args.ckpt, map_location=torch.device('cuda:0')), strict=False)#['model_state']
    # torch.load('./checkpoint_epoch_33_multinomial.pth')['model_state']
    
    model.cuda()
    model.train()  # before wrap to DistributedDataParallel to support fixed some parameters
    # for m in model.modules():
    #     if isinstance(m, nn.BatchNorm2d):
    #         m.eval()
    
    import pcdet
    for m in model.modules():
        if not isinstance(m, pcdet.models_multinomial_half.dense_heads.anchor_head_single.AnchorHeadSingle):
            m.eval()
            # print(m)

    optim_cfg = cfg.OPTIMIZATION
    optim_cfg.LR = 0.0000000000000000001
    optimizer = torch.optim.SGD(model.parameters(), lr=optim_cfg.LR)
    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 20, eta_min=0, last_epoch=-1)
    

#     # -----------------------start training---------------------------
    logger.info('**********************Start training %s/%s(%s)**********************'
                % (cfg.EXP_GROUP_PATH, cfg.TAG, args.extra_tag))
    
    optim_cfg=cfg.OPTIMIZATION
    total_epochs=args.epochs
    rank=cfg.LOCAL_RANK
    
    start_epoch = 0
    with tqdm.trange(start_epoch, total_epochs, desc='epochs', dynamic_ncols=True, leave=(rank==0)) as tbar:
        total_it_each_epoch = len(train_loader)
        for cur_epoch in tbar:
            dataloader_iter = iter(train_loader)
            loss_list = []

            for cur_it in range(total_it_each_epoch):
                batch = next(dataloader_iter)
                model.train()
                optimizer.zero_grad()
                
                load_data_to_gpu(batch)
                ret_dict, tb_dict, disp_dict = model(batch)

                loss = ret_dict['loss'].mean()
        
                loss_list.append(loss)
                loss_avg = sum(loss_list) / len(loss_list)

                loss.backward()
                # clip_grad_norm_(model.parameters(), optim_cfg.GRAD_NORM_CLIP)
                
                optimizer.step()
                lr_scheduler.step()

                print('cur_epoch: {}/{}, cur_it: {}/{}, lr: {:.6}, loss: {:.6}'.format(cur_epoch+1, total_epochs, cur_it+1, total_it_each_epoch, optimizer.param_groups[0]['lr'], loss_avg))
                
            logger.info('**********************Start testing**********************')


            acc1, acc2, ret = eval_utils.eval_(cfg, model, test_loader)
            print(acc1, acc2, ret)

            filename = './save_path/0722/ckpt_epoch{}-{:.6f}-{:.6f}.pth'.format(cur_epoch+1, acc1, acc2)
            last_filename = filename
            torch.save(model.state_dict(), filename)

        
    # filename = './save_path/0722/ckpt_epoch{}.pth'.format(0+1)
    # torch.save(model.state_dict(), filename)        
    
#     logger.info('**********************Start testing %s/%s(%s)**********************'
#                 % (cfg.EXP_GROUP_PATH, cfg.TAG, args.extra_tag))
#     test_set, test_loader, sampler = build_dataloader(
#                                     dataset_cfg=cfg.DATA_CONFIG,
#                                     class_names=cfg.CLASS_NAMES,
#                                     batch_size=args.batch_size,
#                                     dist=dist_train, workers=args.workers, logger=logger, training=False
#                                 )

#     acc1, acc2, ret = eval_utils.eval_(cfg, model, test_loader)
#     print(acc1, ac2, ret)

    # logger.info('----------------Bayes Optimization----------------')
    # Bounded region of parameter space
    # pbounds = {'p1': (0.1, 0.9), 'p2': (0.1, 0.9)}
    

#     optimizer = BayesianOptimization(
#         f=opt_function,
#         pbounds=pbounds,
#         verbose=2,  # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
#         random_state=1,
#     )
#     optimizer.probe(
#         params={'p1': 0.11, 'p2': 0.11},
#         lazy=True,
#     )

#     logger_bayes = JSONLogger(path=save_path+"logs2.json")
#     optimizer.subscribe(Events.OPTIMIZATION_STEP, logger_bayes)
    
    
#     n = 0
#     optimizer.maximize(
#         init_points=3,
#         n_iter=10,
#     )
    print("=======end========")
# Out:
# 2023-07-23 08:21:00,793   INFO  Database filter by min points Car: 14357 => 13532
# 2023-07-23 08:21:00,795   INFO  Database filter by min points Pedestrian: 2207 => 2168
# 2023-07-23 08:21:00,795   INFO  Database filter by min points Cyclist: 734 => 705
# 2023-07-23 08:21:00,810   INFO  Database filter by difficulty Car: 13532 => 10759
# 2023-07-23 08:21:00,814   INFO  Database filter by difficulty Pedestrian: 2168 => 2075
# 2023-07-23 08:21:00,816   INFO  Database filter by difficulty Cyclist: 705 => 581
# 2023-07-23 08:21:00,821   INFO  Loading KITTI dataset
# Using GPU:0
# =============
# 0.23 0.77 0.68
# =============
# 2023-07-23 08:21:00,905   INFO  Total samples for KITTI dataset: 3712
# 2023-07-23 08:21:00,907   INFO  Loading KITTI dataset
# 2023-07-23 08:21:00,985   INFO  Total samples for KITTI dataset: 3769
# /home/pai/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2023-07-23 08:21:02,380   INFO  **********************Start training cfgs/kitti_models/pointpillar_bayes(default)**********************
# epochs:   0%|          | 0/800 [00:00<?, ?it/s]
# cur_epoch: 1/800, cur_it: 1/464, lr: 9.93844e-20, loss: 7.1356
# cur_epoch: 1/800, cur_it: 2/464, lr: 9.75528e-20, loss: 9.17261
# cur_epoch: 1/800, cur_it: 3/464, lr: 9.45503e-20, loss: 8.93245
# cur_epoch: 1/800, cur_it: 4/464, lr: 9.04508e-20, loss: 10.3282
# cur_epoch: 1/800, cur_it: 5/464, lr: 8.53553e-20, loss: 9.97478
# cur_epoch: 1/800, cur_it: 6/464, lr: 7.93893e-20, loss: 9.92915
# cur_epoch: 1/800, cur_it: 7/464, lr: 7.26995e-20, loss: 9.36398
# cur_epoch: 1/800, cur_it: 8/464, lr: 6.54508e-20, loss: 9.24683
# cur_epoch: 1/800, cur_it: 9/464, lr: 5.78217e-20, loss: 9.01073
# cur_epoch: 1/800, cur_it: 10/464, lr: 5e-20, loss: 8.83528
# cur_epoch: 1/800, cur_it: 11/464, lr: 4.21783e-20, loss: 8.56983
# cur_epoch: 1/800, cur_it: 12/464, lr: 3.45492e-20, loss: 8.6069
# cur_epoch: 1/800, cur_it: 13/464, lr: 2.73005e-20, loss: 8.50186
# cur_epoch: 1/800, cur_it: 14/464, lr: 2.06107e-20, loss: 8.42008
# cur_epoch: 1/800, cur_it: 15/464, lr: 1.46447e-20, loss: 8.63271
# cur_epoch: 1/800, cur_it: 16/464, lr: 9.54915e-21, loss: 8.53395
# cur_epoch: 1/800, cur_it: 17/464, lr: 5.44967e-21, loss: 8.44239
# cur_epoch: 1/800, cur_it: 18/464, lr: 2.44717e-21, loss: 8.38248
# cur_epoch: 1/800, cur_it: 19/464, lr: 6.15583e-22, loss: 8.53507
# cur_epoch: 1/800, cur_it: 20/464, lr: 0.0, loss: 8.39018
# cur_epoch: 1/800, cur_it: 21/464, lr: 6.15583e-22, loss: 8.28272
# cur_epoch: 1/800, cur_it: 22/464, lr: 2.44717e-21, loss: 8.21049
# cur_epoch: 1/800, cur_it: 23/464, lr: 5.44967e-21, loss: 8.29011
# cur_epoch: 1/800, cur_it: 24/464, lr: 9.54915e-21, loss: 8.29872
# cur_epoch: 1/800, cur_it: 25/464, lr: 1.46447e-20, loss: 8.34305
# cur_epoch: 1/800, cur_it: 26/464, lr: 2.06107e-20, loss: 8.42279
# cur_epoch: 1/800, cur_it: 27/464, lr: 2.73005e-20, loss: 8.62877
# cur_epoch: 1/800, cur_it: 28/464, lr: 3.45492e-20, loss: 8.71907
# cur_epoch: 1/800, cur_it: 29/464, lr: 4.21783e-20, loss: 8.64685
# cur_epoch: 1/800, cur_it: 30/464, lr: 5e-20, loss: 8.55635
# cur_epoch: 1/800, cur_it: 31/464, lr: 5.78217e-20, loss: 8.50574
# cur_epoch: 1/800, cur_it: 32/464, lr: 6.54508e-20, loss: 8.65048
# cur_epoch: 1/800, cur_it: 33/464, lr: 7.26995e-20, loss: 8.69598
# cur_epoch: 1/800, cur_it: 34/464, lr: 7.93893e-20, loss: 8.64631
# cur_epoch: 1/800, cur_it: 35/464, lr: 8.53553e-20, loss: 8.6876
# cur_epoch: 1/800, cur_it: 36/464, lr: 9.04508e-20, loss: 8.68876
# cur_epoch: 1/800, cur_it: 37/464, lr: 9.45503e-20, loss: 8.65732
# cur_epoch: 1/800, cur_it: 38/464, lr: 9.75528e-20, loss: 8.65859
# cur_epoch: 1/800, cur_it: 39/464, lr: 9.93844e-20, loss: 8.61703
# cur_epoch: 1/800, cur_it: 40/464, lr: 1e-19, loss: 8.63577
# cur_epoch: 1/800, cur_it: 41/464, lr: 9.93844e-20, loss: 8.66317
# cur_epoch: 1/800, cur_it: 42/464, lr: 9.75528e-20, loss: 8.64342
# cur_epoch: 1/800, cur_it: 43/464, lr: 9.45503e-20, loss: 8.78659
# cur_epoch: 1/800, cur_it: 44/464, lr: 9.04508e-20, loss: 8.92667
# cur_epoch: 1/800, cur_it: 45/464, lr: 8.53553e-20, loss: 8.88569
# cur_epoch: 1/800, cur_it: 46/464, lr: 7.93893e-20, loss: 9.06095
# cur_epoch: 1/800, cur_it: 47/464, lr: 7.26995e-20, loss: 9.0696
# cur_epoch: 1/800, cur_it: 48/464, lr: 6.54508e-20, loss: 9.04366
# cur_epoch: 1/800, cur_it: 49/464, lr: 5.78217e-20, loss: 9.02315
# cur_epoch: 1/800, cur_it: 50/464, lr: 5e-20, loss: 9.02958
# cur_epoch: 1/800, cur_it: 51/464, lr: 4.21783e-20, loss: 9.07817
# cur_epoch: 1/800, cur_it: 52/464, lr: 3.45492e-20, loss: 9.03947
# cur_epoch: 1/800, cur_it: 53/464, lr: 2.73005e-20, loss: 8.97891
# cur_epoch: 1/800, cur_it: 54/464, lr: 2.06107e-20, loss: 8.93264
# cur_epoch: 1/800, cur_it: 55/464, lr: 1.46447e-20, loss: 8.95045
# cur_epoch: 1/800, cur_it: 56/464, lr: 9.54915e-21, loss: 8.89005
# cur_epoch: 1/800, cur_it: 57/464, lr: 5.44967e-21, loss: 8.85871
# cur_epoch: 1/800, cur_it: 58/464, lr: 2.44717e-21, loss: 8.79705
# cur_epoch: 1/800, cur_it: 59/464, lr: 6.15583e-22, loss: 8.75663
# cur_epoch: 1/800, cur_it: 60/464, lr: 0.0, loss: 8.73464
# cur_epoch: 1/800, cur_it: 61/464, lr: 6.15583e-22, loss: 8.75101
# cur_epoch: 1/800, cur_it: 62/464, lr: 2.44717e-21, loss: 8.76432
# cur_epoch: 1/800, cur_it: 63/464, lr: 5.44967e-21, loss: 8.76508
# cur_epoch: 1/800, cur_it: 64/464, lr: 9.54915e-21, loss: 8.76849
# cur_epoch: 1/800, cur_it: 65/464, lr: 1.46447e-20, loss: 8.75636
# cur_epoch: 1/800, cur_it: 66/464, lr: 2.06107e-20, loss: 8.73546
# cur_epoch: 1/800, cur_it: 67/464, lr: 2.73005e-20, loss: 8.69528
# cur_epoch: 1/800, cur_it: 68/464, lr: 3.45492e-20, loss: 8.6832
# cur_epoch: 1/800, cur_it: 69/464, lr: 4.21783e-20, loss: 8.63632
# cur_epoch: 1/800, cur_it: 70/464, lr: 5e-20, loss: 8.6448
# cur_epoch: 1/800, cur_it: 71/464, lr: 5.78217e-20, loss: 8.65852
# cur_epoch: 1/800, cur_it: 72/464, lr: 6.54508e-20, loss: 8.71491
# cur_epoch: 1/800, cur_it: 73/464, lr: 7.26995e-20, loss: 8.72257
# cur_epoch: 1/800, cur_it: 74/464, lr: 7.93893e-20, loss: 8.69397
# cur_epoch: 1/800, cur_it: 75/464, lr: 8.53553e-20, loss: 8.68426
# cur_epoch: 1/800, cur_it: 76/464, lr: 9.04508e-20, loss: 8.70509
# cur_epoch: 1/800, cur_it: 77/464, lr: 9.45503e-20, loss: 8.68448
# cur_epoch: 1/800, cur_it: 78/464, lr: 9.75528e-20, loss: 8.71416
# cur_epoch: 1/800, cur_it: 79/464, lr: 9.93844e-20, loss: 8.70308
# cur_epoch: 1/800, cur_it: 80/464, lr: 1e-19, loss: 8.73359
# cur_epoch: 1/800, cur_it: 81/464, lr: 9.93844e-20, loss: 8.74713
# cur_epoch: 1/800, cur_it: 82/464, lr: 9.75528e-20, loss: 8.76762
# cur_epoch: 1/800, cur_it: 83/464, lr: 9.45503e-20, loss: 8.74176
# cur_epoch: 1/800, cur_it: 84/464, lr: 9.04508e-20, loss: 8.7931
# cur_epoch: 1/800, cur_it: 85/464, lr: 8.53553e-20, loss: 8.78326
# cur_epoch: 1/800, cur_it: 86/464, lr: 7.93893e-20, loss: 8.77704
# cur_epoch: 1/800, cur_it: 87/464, lr: 7.26995e-20, loss: 8.78898
# cur_epoch: 1/800, cur_it: 88/464, lr: 6.54508e-20, loss: 8.797
# cur_epoch: 1/800, cur_it: 89/464, lr: 5.78217e-20, loss: 8.79091
# cur_epoch: 1/800, cur_it: 90/464, lr: 5e-20, loss: 8.77728
# cur_epoch: 1/800, cur_it: 91/464, lr: 4.21783e-20, loss: 8.76792
# cur_epoch: 1/800, cur_it: 92/464, lr: 3.45492e-20, loss: 8.81429
# cur_epoch: 1/800, cur_it: 93/464, lr: 2.73005e-20, loss: 8.78996
# cur_epoch: 1/800, cur_it: 94/464, lr: 2.06107e-20, loss: 8.81045
# cur_epoch: 1/800, cur_it: 95/464, lr: 1.46447e-20, loss: 8.8374
# cur_epoch: 1/800, cur_it: 96/464, lr: 9.54915e-21, loss: 8.81001
# cur_epoch: 1/800, cur_it: 97/464, lr: 5.44967e-21, loss: 8.82615
# cur_epoch: 1/800, cur_it: 98/464, lr: 2.44717e-21, loss: 8.82018
# cur_epoch: 1/800, cur_it: 99/464, lr: 6.15583e-22, loss: 8.82789
# cur_epoch: 1/800, cur_it: 100/464, lr: 0.0, loss: 8.81643
# cur_epoch: 1/800, cur_it: 101/464, lr: 6.15583e-22, loss: 8.79202
# cur_epoch: 1/800, cur_it: 102/464, lr: 2.44717e-21, loss: 8.80973
# cur_epoch: 1/800, cur_it: 103/464, lr: 5.44967e-21, loss: 8.79706
# cur_epoch: 1/800, cur_it: 104/464, lr: 9.54915e-21, loss: 8.88764
# cur_epoch: 1/800, cur_it: 105/464, lr: 1.46447e-20, loss: 8.88137
# cur_epoch: 1/800, cur_it: 106/464, lr: 2.06107e-20, loss: 8.89558
# cur_epoch: 1/800, cur_it: 107/464, lr: 2.73005e-20, loss: 8.86817
# cur_epoch: 1/800, cur_it: 108/464, lr: 3.45492e-20, loss: 8.85907
# cur_epoch: 1/800, cur_it: 109/464, lr: 4.21783e-20, loss: 8.91128
# cur_epoch: 1/800, cur_it: 110/464, lr: 5e-20, loss: 8.92309
# cur_epoch: 1/800, cur_it: 111/464, lr: 5.78217e-20, loss: 8.9558
# cur_epoch: 1/800, cur_it: 112/464, lr: 6.54508e-20, loss: 8.96128
# cur_epoch: 1/800, cur_it: 113/464, lr: 7.26995e-20, loss: 8.92376
# cur_epoch: 1/800, cur_it: 114/464, lr: 7.93893e-20, loss: 8.96318
# cur_epoch: 1/800, cur_it: 115/464, lr: 8.53553e-20, loss: 9.02025
# cur_epoch: 1/800, cur_it: 116/464, lr: 9.04508e-20, loss: 9.02438
# cur_epoch: 1/800, cur_it: 117/464, lr: 9.45503e-20, loss: 9.04587
# cur_epoch: 1/800, cur_it: 118/464, lr: 9.75528e-20, loss: 9.04731
# cur_epoch: 1/800, cur_it: 119/464, lr: 9.93844e-20, loss: 9.04855
# cur_epoch: 1/800, cur_it: 120/464, lr: 1e-19, loss: 9.0749
# cur_epoch: 1/800, cur_it: 121/464, lr: 9.93844e-20, loss: 9.1092
# cur_epoch: 1/800, cur_it: 122/464, lr: 9.75528e-20, loss: 9.12913
# cur_epoch: 1/800, cur_it: 123/464, lr: 9.45503e-20, loss: 9.12662
# cur_epoch: 1/800, cur_it: 124/464, lr: 9.04508e-20, loss: 9.13256
# cur_epoch: 1/800, cur_it: 125/464, lr: 8.53553e-20, loss: 9.10936
# cur_epoch: 1/800, cur_it: 126/464, lr: 7.93893e-20, loss: 9.0924
# cur_epoch: 1/800, cur_it: 127/464, lr: 7.26995e-20, loss: 9.10245
# cur_epoch: 1/800, cur_it: 128/464, lr: 6.54508e-20, loss: 9.09338
# cur_epoch: 1/800, cur_it: 129/464, lr: 5.78217e-20, loss: 9.09801
# cur_epoch: 1/800, cur_it: 130/464, lr: 5e-20, loss: 9.09629
# cur_epoch: 1/800, cur_it: 131/464, lr: 4.21783e-20, loss: 9.0778
# cur_epoch: 1/800, cur_it: 132/464, lr: 3.45492e-20, loss: 9.05854
# cur_epoch: 1/800, cur_it: 133/464, lr: 2.73005e-20, loss: 9.05521
# cur_epoch: 1/800, cur_it: 134/464, lr: 2.06107e-20, loss: 9.05893
# cur_epoch: 1/800, cur_it: 135/464, lr: 1.46447e-20, loss: 9.04183
# cur_epoch: 1/800, cur_it: 136/464, lr: 9.54915e-21, loss: 9.04311
# cur_epoch: 1/800, cur_it: 137/464, lr: 5.44967e-21, loss: 9.06975
# cur_epoch: 1/800, cur_it: 138/464, lr: 2.44717e-21, loss: 9.08964
# cur_epoch: 1/800, cur_it: 139/464, lr: 6.15583e-22, loss: 9.14782
# cur_epoch: 1/800, cur_it: 140/464, lr: 0.0, loss: 9.14355
# cur_epoch: 1/800, cur_it: 141/464, lr: 6.15583e-22, loss: 9.1481
# cur_epoch: 1/800, cur_it: 142/464, lr: 2.44717e-21, loss: 9.17417
# cur_epoch: 1/800, cur_it: 143/464, lr: 5.44967e-21, loss: 9.16669
# cur_epoch: 1/800, cur_it: 144/464, lr: 9.54915e-21, loss: 9.16298
# cur_epoch: 1/800, cur_it: 145/464, lr: 1.46447e-20, loss: 9.14659
# cur_epoch: 1/800, cur_it: 146/464, lr: 2.06107e-20, loss: 9.14377
# cur_epoch: 1/800, cur_it: 147/464, lr: 2.73005e-20, loss: 9.14924
# cur_epoch: 1/800, cur_it: 148/464, lr: 3.45492e-20, loss: 9.13655
# cur_epoch: 1/800, cur_it: 149/464, lr: 4.21783e-20, loss: 9.18063
# cur_epoch: 1/800, cur_it: 150/464, lr: 5e-20, loss: 9.18464
# cur_epoch: 1/800, cur_it: 151/464, lr: 5.78217e-20, loss: 9.19457
# cur_epoch: 1/800, cur_it: 152/464, lr: 6.54508e-20, loss: 9.20688
# cur_epoch: 1/800, cur_it: 153/464, lr: 7.26995e-20, loss: 9.20969
# cur_epoch: 1/800, cur_it: 154/464, lr: 7.93893e-20, loss: 9.19504
# cur_epoch: 1/800, cur_it: 155/464, lr: 8.53553e-20, loss: 9.20952
# cur_epoch: 1/800, cur_it: 156/464, lr: 9.04508e-20, loss: 9.23468
# cur_epoch: 1/800, cur_it: 157/464, lr: 9.45503e-20, loss: 9.22663
# cur_epoch: 1/800, cur_it: 158/464, lr: 9.75528e-20, loss: 9.21786
# cur_epoch: 1/800, cur_it: 159/464, lr: 9.93844e-20, loss: 9.22689
# cur_epoch: 1/800, cur_it: 160/464, lr: 1e-19, loss: 9.21432
# cur_epoch: 1/800, cur_it: 161/464, lr: 9.93844e-20, loss: 9.24046
# cur_epoch: 1/800, cur_it: 162/464, lr: 9.75528e-20, loss: 9.23572
# cur_epoch: 1/800, cur_it: 163/464, lr: 9.45503e-20, loss: 9.23825
# cur_epoch: 1/800, cur_it: 164/464, lr: 9.04508e-20, loss: 9.22721
# cur_epoch: 1/800, cur_it: 165/464, lr: 8.53553e-20, loss: 9.21164
# cur_epoch: 1/800, cur_it: 166/464, lr: 7.93893e-20, loss: 9.19546
# cur_epoch: 1/800, cur_it: 167/464, lr: 7.26995e-20, loss: 9.19258
# cur_epoch: 1/800, cur_it: 168/464, lr: 6.54508e-20, loss: 9.19868
# cur_epoch: 1/800, cur_it: 169/464, lr: 5.78217e-20, loss: 9.18756
# cur_epoch: 1/800, cur_it: 170/464, lr: 5e-20, loss: 9.19342
# cur_epoch: 1/800, cur_it: 171/464, lr: 4.21783e-20, loss: 9.18187
# cur_epoch: 1/800, cur_it: 172/464, lr: 3.45492e-20, loss: 9.16835
# cur_epoch: 1/800, cur_it: 173/464, lr: 2.73005e-20, loss: 9.16309
# cur_epoch: 1/800, cur_it: 174/464, lr: 2.06107e-20, loss: 9.18097
# cur_epoch: 1/800, cur_it: 175/464, lr: 1.46447e-20, loss: 9.16713
# cur_epoch: 1/800, cur_it: 176/464, lr: 9.54915e-21, loss: 9.16203
# cur_epoch: 1/800, cur_it: 177/464, lr: 5.44967e-21, loss: 9.15547
# cur_epoch: 1/800, cur_it: 178/464, lr: 2.44717e-21, loss: 9.1485
# cur_epoch: 1/800, cur_it: 179/464, lr: 6.15583e-22, loss: 9.13738
# cur_epoch: 1/800, cur_it: 180/464, lr: 0.0, loss: 9.16055
# cur_epoch: 1/800, cur_it: 181/464, lr: 6.15583e-22, loss: 9.17315
# cur_epoch: 1/800, cur_it: 182/464, lr: 2.44717e-21, loss: 9.17483
# cur_epoch: 1/800, cur_it: 183/464, lr: 5.44967e-21, loss: 9.16992
# cur_epoch: 1/800, cur_it: 184/464, lr: 9.54915e-21, loss: 9.16538
# cur_epoch: 1/800, cur_it: 185/464, lr: 1.46447e-20, loss: 9.16786
# cur_epoch: 1/800, cur_it: 186/464, lr: 2.06107e-20, loss: 9.1568
# cur_epoch: 1/800, cur_it: 187/464, lr: 2.73005e-20, loss: 9.13913
# cur_epoch: 1/800, cur_it: 188/464, lr: 3.45492e-20, loss: 9.14986
# cur_epoch: 1/800, cur_it: 189/464, lr: 4.21783e-20, loss: 9.13398
# cur_epoch: 1/800, cur_it: 190/464, lr: 5e-20, loss: 9.12775
# cur_epoch: 1/800, cur_it: 191/464, lr: 5.78217e-20, loss: 9.11207
# cur_epoch: 1/800, cur_it: 192/464, lr: 6.54508e-20, loss: 9.11313
# cur_epoch: 1/800, cur_it: 193/464, lr: 7.26995e-20, loss: 9.10886
# cur_epoch: 1/800, cur_it: 194/464, lr: 7.93893e-20, loss: 9.12794
# cur_epoch: 1/800, cur_it: 195/464, lr: 8.53553e-20, loss: 9.13003
# cur_epoch: 1/800, cur_it: 196/464, lr: 9.04508e-20, loss: 9.12043
# cur_epoch: 1/800, cur_it: 197/464, lr: 9.45503e-20, loss: 9.11435
# cur_epoch: 1/800, cur_it: 198/464, lr: 9.75528e-20, loss: 9.1058
# cur_epoch: 1/800, cur_it: 199/464, lr: 9.93844e-20, loss: 9.09851
# cur_epoch: 1/800, cur_it: 200/464, lr: 1e-19, loss: 9.08758
# cur_epoch: 1/800, cur_it: 201/464, lr: 9.93844e-20, loss: 9.06862
# cur_epoch: 1/800, cur_it: 202/464, lr: 9.75528e-20, loss: 9.06899
# cur_epoch: 1/800, cur_it: 203/464, lr: 9.45503e-20, loss: 9.08016
# cur_epoch: 1/800, cur_it: 204/464, lr: 9.04508e-20, loss: 9.07797
# cur_epoch: 1/800, cur_it: 205/464, lr: 8.53553e-20, loss: 9.10568
# cur_epoch: 1/800, cur_it: 206/464, lr: 7.93893e-20, loss: 9.10368
# cur_epoch: 1/800, cur_it: 207/464, lr: 7.26995e-20, loss: 9.11474
# cur_epoch: 1/800, cur_it: 208/464, lr: 6.54508e-20, loss: 9.1214
# cur_epoch: 1/800, cur_it: 209/464, lr: 5.78217e-20, loss: 9.11533
# cur_epoch: 1/800, cur_it: 210/464, lr: 5e-20, loss: 9.10911
# cur_epoch: 1/800, cur_it: 211/464, lr: 4.21783e-20, loss: 9.12701
# cur_epoch: 1/800, cur_it: 212/464, lr: 3.45492e-20, loss: 9.11928
# cur_epoch: 1/800, cur_it: 213/464, lr: 2.73005e-20, loss: 9.11016
# cur_epoch: 1/800, cur_it: 214/464, lr: 2.06107e-20, loss: 9.11884
# cur_epoch: 1/800, cur_it: 215/464, lr: 1.46447e-20, loss: 9.11294
# cur_epoch: 1/800, cur_it: 216/464, lr: 9.54915e-21, loss: 9.11455
# cur_epoch: 1/800, cur_it: 217/464, lr: 5.44967e-21, loss: 9.11095
# cur_epoch: 1/800, cur_it: 218/464, lr: 2.44717e-21, loss: 9.10864
# cur_epoch: 1/800, cur_it: 219/464, lr: 6.15583e-22, loss: 9.11925
# cur_epoch: 1/800, cur_it: 220/464, lr: 0.0, loss: 9.11924
# cur_epoch: 1/800, cur_it: 221/464, lr: 6.15583e-22, loss: 9.119
# cur_epoch: 1/800, cur_it: 222/464, lr: 2.44717e-21, loss: 9.11169
# cur_epoch: 1/800, cur_it: 223/464, lr: 5.44967e-21, loss: 9.11331
# cur_epoch: 1/800, cur_it: 224/464, lr: 9.54915e-21, loss: 9.12717
# cur_epoch: 1/800, cur_it: 225/464, lr: 1.46447e-20, loss: 9.16099
# cur_epoch: 1/800, cur_it: 226/464, lr: 2.06107e-20, loss: 9.16035
# cur_epoch: 1/800, cur_it: 227/464, lr: 2.73005e-20, loss: 9.16327
# cur_epoch: 1/800, cur_it: 228/464, lr: 3.45492e-20, loss: 9.14929
# cur_epoch: 1/800, cur_it: 229/464, lr: 4.21783e-20, loss: 9.17639
# cur_epoch: 1/800, cur_it: 230/464, lr: 5e-20, loss: 9.16495
# cur_epoch: 1/800, cur_it: 231/464, lr: 5.78217e-20, loss: 9.16792
# cur_epoch: 1/800, cur_it: 232/464, lr: 6.54508e-20, loss: 9.16804
# cur_epoch: 1/800, cur_it: 233/464, lr: 7.26995e-20, loss: 9.16526
# cur_epoch: 1/800, cur_it: 234/464, lr: 7.93893e-20, loss: 9.16811
# cur_epoch: 1/800, cur_it: 235/464, lr: 8.53553e-20, loss: 9.16369
# cur_epoch: 1/800, cur_it: 236/464, lr: 9.04508e-20, loss: 9.15323
# cur_epoch: 1/800, cur_it: 237/464, lr: 9.45503e-20, loss: 9.16608
# cur_epoch: 1/800, cur_it: 238/464, lr: 9.75528e-20, loss: 9.16629
# cur_epoch: 1/800, cur_it: 239/464, lr: 9.93844e-20, loss: 9.15614
# cur_epoch: 1/800, cur_it: 240/464, lr: 1e-19, loss: 9.16587
# cur_epoch: 1/800, cur_it: 241/464, lr: 9.93844e-20, loss: 9.18844
# cur_epoch: 1/800, cur_it: 242/464, lr: 9.75528e-20, loss: 9.17961
# cur_epoch: 1/800, cur_it: 243/464, lr: 9.45503e-20, loss: 9.17286
# cur_epoch: 1/800, cur_it: 244/464, lr: 9.04508e-20, loss: 9.17863
# cur_epoch: 1/800, cur_it: 245/464, lr: 8.53553e-20, loss: 9.17837
# cur_epoch: 1/800, cur_it: 246/464, lr: 7.93893e-20, loss: 9.17875
# cur_epoch: 1/800, cur_it: 247/464, lr: 7.26995e-20, loss: 9.17475
# cur_epoch: 1/800, cur_it: 248/464, lr: 6.54508e-20, loss: 9.16604
# cur_epoch: 1/800, cur_it: 249/464, lr: 5.78217e-20, loss: 9.1592
# cur_epoch: 1/800, cur_it: 250/464, lr: 5e-20, loss: 9.16004
# cur_epoch: 1/800, cur_it: 251/464, lr: 4.21783e-20, loss: 9.16003
# cur_epoch: 1/800, cur_it: 252/464, lr: 3.45492e-20, loss: 9.15222
# cur_epoch: 1/800, cur_it: 253/464, lr: 2.73005e-20, loss: 9.14736
# cur_epoch: 1/800, cur_it: 254/464, lr: 2.06107e-20, loss: 9.15038
# cur_epoch: 1/800, cur_it: 255/464, lr: 1.46447e-20, loss: 9.15686
# cur_epoch: 1/800, cur_it: 256/464, lr: 9.54915e-21, loss: 9.16059
# cur_epoch: 1/800, cur_it: 257/464, lr: 5.44967e-21, loss: 9.15754
# cur_epoch: 1/800, cur_it: 258/464, lr: 2.44717e-21, loss: 9.15922
# cur_epoch: 1/800, cur_it: 259/464, lr: 6.15583e-22, loss: 9.14797
# cur_epoch: 1/800, cur_it: 260/464, lr: 0.0, loss: 9.14178
# cur_epoch: 1/800, cur_it: 261/464, lr: 6.15583e-22, loss: 9.15513
# cur_epoch: 1/800, cur_it: 262/464, lr: 2.44717e-21, loss: 9.16585
# cur_epoch: 1/800, cur_it: 263/464, lr: 5.44967e-21, loss: 9.19659
# cur_epoch: 1/800, cur_it: 264/464, lr: 9.54915e-21, loss: 9.19263
# cur_epoch: 1/800, cur_it: 265/464, lr: 1.46447e-20, loss: 9.18917
# cur_epoch: 1/800, cur_it: 266/464, lr: 2.06107e-20, loss: 9.18986
# cur_epoch: 1/800, cur_it: 267/464, lr: 2.73005e-20, loss: 9.19213
# cur_epoch: 1/800, cur_it: 268/464, lr: 3.45492e-20, loss: 9.1946
# cur_epoch: 1/800, cur_it: 269/464, lr: 4.21783e-20, loss: 9.19783
# cur_epoch: 1/800, cur_it: 270/464, lr: 5e-20, loss: 9.19023
# cur_epoch: 1/800, cur_it: 271/464, lr: 5.78217e-20, loss: 9.20031
# cur_epoch: 1/800, cur_it: 272/464, lr: 6.54508e-20, loss: 9.18479
# cur_epoch: 1/800, cur_it: 273/464, lr: 7.26995e-20, loss: 9.18332
# cur_epoch: 1/800, cur_it: 274/464, lr: 7.93893e-20, loss: 9.17886
# cur_epoch: 1/800, cur_it: 275/464, lr: 8.53553e-20, loss: 9.18029
# cur_epoch: 1/800, cur_it: 276/464, lr: 9.04508e-20, loss: 9.18564
# cur_epoch: 1/800, cur_it: 277/464, lr: 9.45503e-20, loss: 9.19118
# cur_epoch: 1/800, cur_it: 278/464, lr: 9.75528e-20, loss: 9.18055
# cur_epoch: 1/800, cur_it: 279/464, lr: 9.93844e-20, loss: 9.19963
# cur_epoch: 1/800, cur_it: 280/464, lr: 1e-19, loss: 9.18932
# cur_epoch: 1/800, cur_it: 281/464, lr: 9.93844e-20, loss: 9.19247
# cur_epoch: 1/800, cur_it: 282/464, lr: 9.75528e-20, loss: 9.19589
# cur_epoch: 1/800, cur_it: 283/464, lr: 9.45503e-20, loss: 9.18579
# cur_epoch: 1/800, cur_it: 284/464, lr: 9.04508e-20, loss: 9.18997
# cur_epoch: 1/800, cur_it: 285/464, lr: 8.53553e-20, loss: 9.19271
# cur_epoch: 1/800, cur_it: 286/464, lr: 7.93893e-20, loss: 9.19002
# cur_epoch: 1/800, cur_it: 287/464, lr: 7.26995e-20, loss: 9.1882
# cur_epoch: 1/800, cur_it: 288/464, lr: 6.54508e-20, loss: 9.19185
# cur_epoch: 1/800, cur_it: 289/464, lr: 5.78217e-20, loss: 9.19476
# cur_epoch: 1/800, cur_it: 290/464, lr: 5e-20, loss: 9.17921
# cur_epoch: 1/800, cur_it: 291/464, lr: 4.21783e-20, loss: 9.174
# cur_epoch: 1/800, cur_it: 292/464, lr: 3.45492e-20, loss: 9.1884
# cur_epoch: 1/800, cur_it: 293/464, lr: 2.73005e-20, loss: 9.21245
# cur_epoch: 1/800, cur_it: 294/464, lr: 2.06107e-20, loss: 9.2099
# cur_epoch: 1/800, cur_it: 295/464, lr: 1.46447e-20, loss: 9.20454
# cur_epoch: 1/800, cur_it: 296/464, lr: 9.54915e-21, loss: 9.20045
# cur_epoch: 1/800, cur_it: 297/464, lr: 5.44967e-21, loss: 9.1957
# cur_epoch: 1/800, cur_it: 298/464, lr: 2.44717e-21, loss: 9.20343
# cur_epoch: 1/800, cur_it: 299/464, lr: 6.15583e-22, loss: 9.21732
# cur_epoch: 1/800, cur_it: 300/464, lr: 0.0, loss: 9.22316
# cur_epoch: 1/800, cur_it: 301/464, lr: 6.15583e-22, loss: 9.22864
# cur_epoch: 1/800, cur_it: 302/464, lr: 2.44717e-21, loss: 9.23096
# cur_epoch: 1/800, cur_it: 303/464, lr: 5.44967e-21, loss: 9.2373
# cur_epoch: 1/800, cur_it: 304/464, lr: 9.54915e-21, loss: 9.23439
# cur_epoch: 1/800, cur_it: 305/464, lr: 1.46447e-20, loss: 9.22957
# cur_epoch: 1/800, cur_it: 306/464, lr: 2.06107e-20, loss: 9.22738
# cur_epoch: 1/800, cur_it: 307/464, lr: 2.73005e-20, loss: 9.22705
# cur_epoch: 1/800, cur_it: 308/464, lr: 3.45492e-20, loss: 9.22976
# cur_epoch: 1/800, cur_it: 309/464, lr: 4.21783e-20, loss: 9.23679
# cur_epoch: 1/800, cur_it: 310/464, lr: 5e-20, loss: 9.23946
# cur_epoch: 1/800, cur_it: 311/464, lr: 5.78217e-20, loss: 9.2411
# cur_epoch: 1/800, cur_it: 312/464, lr: 6.54508e-20, loss: 9.23638
# cur_epoch: 1/800, cur_it: 313/464, lr: 7.26995e-20, loss: 9.25465
# cur_epoch: 1/800, cur_it: 314/464, lr: 7.93893e-20, loss: 9.24463
# cur_epoch: 1/800, cur_it: 315/464, lr: 8.53553e-20, loss: 9.23967
# cur_epoch: 1/800, cur_it: 316/464, lr: 9.04508e-20, loss: 9.23304
# cur_epoch: 1/800, cur_it: 317/464, lr: 9.45503e-20, loss: 9.25092
# cur_epoch: 1/800, cur_it: 318/464, lr: 9.75528e-20, loss: 9.25074
# cur_epoch: 1/800, cur_it: 319/464, lr: 9.93844e-20, loss: 9.2448
# cur_epoch: 1/800, cur_it: 320/464, lr: 1e-19, loss: 9.25546
# cur_epoch: 1/800, cur_it: 321/464, lr: 9.93844e-20, loss: 9.25165
# cur_epoch: 1/800, cur_it: 322/464, lr: 9.75528e-20, loss: 9.24298
# cur_epoch: 1/800, cur_it: 323/464, lr: 9.45503e-20, loss: 9.2452
# cur_epoch: 1/800, cur_it: 324/464, lr: 9.04508e-20, loss: 9.24622
# cur_epoch: 1/800, cur_it: 325/464, lr: 8.53553e-20, loss: 9.24467
# cur_epoch: 1/800, cur_it: 326/464, lr: 7.93893e-20, loss: 9.23489
# cur_epoch: 1/800, cur_it: 327/464, lr: 7.26995e-20, loss: 9.23596
# cur_epoch: 1/800, cur_it: 328/464, lr: 6.54508e-20, loss: 9.22884
# cur_epoch: 1/800, cur_it: 329/464, lr: 5.78217e-20, loss: 9.24303
# cur_epoch: 1/800, cur_it: 330/464, lr: 5e-20, loss: 9.25345
# cur_epoch: 1/800, cur_it: 331/464, lr: 4.21783e-20, loss: 9.25954
# cur_epoch: 1/800, cur_it: 332/464, lr: 3.45492e-20, loss: 9.25583
# cur_epoch: 1/800, cur_it: 333/464, lr: 2.73005e-20, loss: 9.25406
# cur_epoch: 1/800, cur_it: 334/464, lr: 2.06107e-20, loss: 9.25052
# cur_epoch: 1/800, cur_it: 335/464, lr: 1.46447e-20, loss: 9.2641
# cur_epoch: 1/800, cur_it: 336/464, lr: 9.54915e-21, loss: 9.27493
# cur_epoch: 1/800, cur_it: 337/464, lr: 5.44967e-21, loss: 9.27024
# cur_epoch: 1/800, cur_it: 338/464, lr: 2.44717e-21, loss: 9.26775
# cur_epoch: 1/800, cur_it: 339/464, lr: 6.15583e-22, loss: 9.26205
# cur_epoch: 1/800, cur_it: 340/464, lr: 0.0, loss: 9.26995
# cur_epoch: 1/800, cur_it: 341/464, lr: 6.15583e-22, loss: 9.26811
# cur_epoch: 1/800, cur_it: 342/464, lr: 2.44717e-21, loss: 9.27118
# cur_epoch: 1/800, cur_it: 343/464, lr: 5.44967e-21, loss: 9.26689
# cur_epoch: 1/800, cur_it: 344/464, lr: 9.54915e-21, loss: 9.27118
# cur_epoch: 1/800, cur_it: 345/464, lr: 1.46447e-20, loss: 9.26635
# cur_epoch: 1/800, cur_it: 346/464, lr: 2.06107e-20, loss: 9.26349
# cur_epoch: 1/800, cur_it: 347/464, lr: 2.73005e-20, loss: 9.27045
# cur_epoch: 1/800, cur_it: 348/464, lr: 3.45492e-20, loss: 9.26566
# cur_epoch: 1/800, cur_it: 349/464, lr: 4.21783e-20, loss: 9.26545
# cur_epoch: 1/800, cur_it: 350/464, lr: 5e-20, loss: 9.27494
# cur_epoch: 1/800, cur_it: 351/464, lr: 5.78217e-20, loss: 9.27312
# cur_epoch: 1/800, cur_it: 352/464, lr: 6.54508e-20, loss: 9.26672
# cur_epoch: 1/800, cur_it: 353/464, lr: 7.26995e-20, loss: 9.26539
# cur_epoch: 1/800, cur_it: 354/464, lr: 7.93893e-20, loss: 9.26835
# cur_epoch: 1/800, cur_it: 355/464, lr: 8.53553e-20, loss: 9.27885
# cur_epoch: 1/800, cur_it: 356/464, lr: 9.04508e-20, loss: 9.27055
# cur_epoch: 1/800, cur_it: 357/464, lr: 9.45503e-20, loss: 9.26673
# cur_epoch: 1/800, cur_it: 358/464, lr: 9.75528e-20, loss: 9.26106
# cur_epoch: 1/800, cur_it: 359/464, lr: 9.93844e-20, loss: 9.25744
# cur_epoch: 1/800, cur_it: 360/464, lr: 1e-19, loss: 9.25731
# cur_epoch: 1/800, cur_it: 361/464, lr: 9.93844e-20, loss: 9.25676
# cur_epoch: 1/800, cur_it: 362/464, lr: 9.75528e-20, loss: 9.25859
# cur_epoch: 1/800, cur_it: 363/464, lr: 9.45503e-20, loss: 9.24769
# cur_epoch: 1/800, cur_it: 364/464, lr: 9.04508e-20, loss: 9.24576
# cur_epoch: 1/800, cur_it: 365/464, lr: 8.53553e-20, loss: 9.25198
# cur_epoch: 1/800, cur_it: 366/464, lr: 7.93893e-20, loss: 9.26589
# cur_epoch: 1/800, cur_it: 367/464, lr: 7.26995e-20, loss: 9.26368
# cur_epoch: 1/800, cur_it: 368/464, lr: 6.54508e-20, loss: 9.2572
# cur_epoch: 1/800, cur_it: 369/464, lr: 5.78217e-20, loss: 9.26177
# cur_epoch: 1/800, cur_it: 370/464, lr: 5e-20, loss: 9.2734
# cur_epoch: 1/800, cur_it: 371/464, lr: 4.21783e-20, loss: 9.28059
# cur_epoch: 1/800, cur_it: 372/464, lr: 3.45492e-20, loss: 9.27361
# cur_epoch: 1/800, cur_it: 373/464, lr: 2.73005e-20, loss: 9.27151
# cur_epoch: 1/800, cur_it: 374/464, lr: 2.06107e-20, loss: 9.27694
# cur_epoch: 1/800, cur_it: 375/464, lr: 1.46447e-20, loss: 9.26622
# cur_epoch: 1/800, cur_it: 376/464, lr: 9.54915e-21, loss: 9.25792
# cur_epoch: 1/800, cur_it: 377/464, lr: 5.44967e-21, loss: 9.2539
# cur_epoch: 1/800, cur_it: 378/464, lr: 2.44717e-21, loss: 9.26075
# cur_epoch: 1/800, cur_it: 379/464, lr: 6.15583e-22, loss: 9.25858
# cur_epoch: 1/800, cur_it: 380/464, lr: 0.0, loss: 9.26011
# cur_epoch: 1/800, cur_it: 381/464, lr: 6.15583e-22, loss: 9.26033
# cur_epoch: 1/800, cur_it: 382/464, lr: 2.44717e-21, loss: 9.25873
# cur_epoch: 1/800, cur_it: 383/464, lr: 5.44967e-21, loss: 9.26015
# cur_epoch: 1/800, cur_it: 384/464, lr: 9.54915e-21, loss: 9.25447
# cur_epoch: 1/800, cur_it: 385/464, lr: 1.46447e-20, loss: 9.26701
# cur_epoch: 1/800, cur_it: 386/464, lr: 2.06107e-20, loss: 9.26081
# cur_epoch: 1/800, cur_it: 387/464, lr: 2.73005e-20, loss: 9.25083
# cur_epoch: 1/800, cur_it: 388/464, lr: 3.45492e-20, loss: 9.24465
# cur_epoch: 1/800, cur_it: 389/464, lr: 4.21783e-20, loss: 9.25152
# cur_epoch: 1/800, cur_it: 390/464, lr: 5e-20, loss: 9.25858
# cur_epoch: 1/800, cur_it: 391/464, lr: 5.78217e-20, loss: 9.25516
# cur_epoch: 1/800, cur_it: 392/464, lr: 6.54508e-20, loss: 9.25854
# cur_epoch: 1/800, cur_it: 393/464, lr: 7.26995e-20, loss: 9.25617
# cur_epoch: 1/800, cur_it: 394/464, lr: 7.93893e-20, loss: 9.2672
# cur_epoch: 1/800, cur_it: 395/464, lr: 8.53553e-20, loss: 9.26448
# cur_epoch: 1/800, cur_it: 396/464, lr: 9.04508e-20, loss: 9.26483
# cur_epoch: 1/800, cur_it: 397/464, lr: 9.45503e-20, loss: 9.2611
# cur_epoch: 1/800, cur_it: 398/464, lr: 9.75528e-20, loss: 9.25698
# cur_epoch: 1/800, cur_it: 399/464, lr: 9.93844e-20, loss: 9.25362
# cur_epoch: 1/800, cur_it: 400/464, lr: 1e-19, loss: 9.24949
# cur_epoch: 1/800, cur_it: 401/464, lr: 9.93844e-20, loss: 9.24924
# cur_epoch: 1/800, cur_it: 402/464, lr: 9.75528e-20, loss: 9.24936
# cur_epoch: 1/800, cur_it: 403/464, lr: 9.45503e-20, loss: 9.24942
# cur_epoch: 1/800, cur_it: 404/464, lr: 9.04508e-20, loss: 9.24474
# cur_epoch: 1/800, cur_it: 405/464, lr: 8.53553e-20, loss: 9.24563
# cur_epoch: 1/800, cur_it: 406/464, lr: 7.93893e-20, loss: 9.24567
# cur_epoch: 1/800, cur_it: 407/464, lr: 7.26995e-20, loss: 9.26042
# cur_epoch: 1/800, cur_it: 408/464, lr: 6.54508e-20, loss: 9.26283
# cur_epoch: 1/800, cur_it: 409/464, lr: 5.78217e-20, loss: 9.25899
# cur_epoch: 1/800, cur_it: 410/464, lr: 5e-20, loss: 9.25578
# cur_epoch: 1/800, cur_it: 411/464, lr: 4.21783e-20, loss: 9.25735
# cur_epoch: 1/800, cur_it: 412/464, lr: 3.45492e-20, loss: 9.2553
# cur_epoch: 1/800, cur_it: 413/464, lr: 2.73005e-20, loss: 9.25214
# cur_epoch: 1/800, cur_it: 414/464, lr: 2.06107e-20, loss: 9.24911
# cur_epoch: 1/800, cur_it: 415/464, lr: 1.46447e-20, loss: 9.25772
# cur_epoch: 1/800, cur_it: 416/464, lr: 9.54915e-21, loss: 9.25923
# cur_epoch: 1/800, cur_it: 417/464, lr: 5.44967e-21, loss: 9.26244
# cur_epoch: 1/800, cur_it: 418/464, lr: 2.44717e-21, loss: 9.27498
# cur_epoch: 1/800, cur_it: 419/464, lr: 6.15583e-22, loss: 9.27491
# cur_epoch: 1/800, cur_it: 420/464, lr: 0.0, loss: 9.27774
# cur_epoch: 1/800, cur_it: 421/464, lr: 6.15583e-22, loss: 9.28227
# cur_epoch: 1/800, cur_it: 422/464, lr: 2.44717e-21, loss: 9.288
# cur_epoch: 1/800, cur_it: 423/464, lr: 5.44967e-21, loss: 9.28843
# cur_epoch: 1/800, cur_it: 424/464, lr: 9.54915e-21, loss: 9.28258
# cur_epoch: 1/800, cur_it: 425/464, lr: 1.46447e-20, loss: 9.28195
# cur_epoch: 1/800, cur_it: 426/464, lr: 2.06107e-20, loss: 9.28122
# cur_epoch: 1/800, cur_it: 427/464, lr: 2.73005e-20, loss: 9.28411
# cur_epoch: 1/800, cur_it: 428/464, lr: 3.45492e-20, loss: 9.27409
# cur_epoch: 1/800, cur_it: 429/464, lr: 4.21783e-20, loss: 9.28076
# cur_epoch: 1/800, cur_it: 430/464, lr: 5e-20, loss: 9.28518
# cur_epoch: 1/800, cur_it: 431/464, lr: 5.78217e-20, loss: 9.2819
# cur_epoch: 1/800, cur_it: 432/464, lr: 6.54508e-20, loss: 9.27463
# cur_epoch: 1/800, cur_it: 433/464, lr: 7.26995e-20, loss: 9.27234
# cur_epoch: 1/800, cur_it: 434/464, lr: 7.93893e-20, loss: 9.26445
# cur_epoch: 1/800, cur_it: 435/464, lr: 8.53553e-20, loss: 9.26758
# cur_epoch: 1/800, cur_it: 436/464, lr: 9.04508e-20, loss: 9.2632
# cur_epoch: 1/800, cur_it: 437/464, lr: 9.45503e-20, loss: 9.2662
# cur_epoch: 1/800, cur_it: 438/464, lr: 9.75528e-20, loss: 9.27561
# cur_epoch: 1/800, cur_it: 439/464, lr: 9.93844e-20, loss: 9.26877
# cur_epoch: 1/800, cur_it: 440/464, lr: 1e-19, loss: 9.26491
# cur_epoch: 1/800, cur_it: 441/464, lr: 9.93844e-20, loss: 9.25924
# cur_epoch: 1/800, cur_it: 442/464, lr: 9.75528e-20, loss: 9.26046
# cur_epoch: 1/800, cur_it: 443/464, lr: 9.45503e-20, loss: 9.25657
# cur_epoch: 1/800, cur_it: 444/464, lr: 9.04508e-20, loss: 9.25541
# cur_epoch: 1/800, cur_it: 445/464, lr: 8.53553e-20, loss: 9.25248
# cur_epoch: 1/800, cur_it: 446/464, lr: 7.93893e-20, loss: 9.25944
# cur_epoch: 1/800, cur_it: 447/464, lr: 7.26995e-20, loss: 9.26735
# cur_epoch: 1/800, cur_it: 448/464, lr: 6.54508e-20, loss: 9.27296
# cur_epoch: 1/800, cur_it: 449/464, lr: 5.78217e-20, loss: 9.26959
# cur_epoch: 1/800, cur_it: 450/464, lr: 5e-20, loss: 9.28634
# cur_epoch: 1/800, cur_it: 451/464, lr: 4.21783e-20, loss: 9.28597
# cur_epoch: 1/800, cur_it: 452/464, lr: 3.45492e-20, loss: 9.28063
# cur_epoch: 1/800, cur_it: 453/464, lr: 2.73005e-20, loss: 9.28502
# cur_epoch: 1/800, cur_it: 454/464, lr: 2.06107e-20, loss: 9.27764
# cur_epoch: 1/800, cur_it: 455/464, lr: 1.46447e-20, loss: 9.27614
# cur_epoch: 1/800, cur_it: 456/464, lr: 9.54915e-21, loss: 9.27297
# cur_epoch: 1/800, cur_it: 457/464, lr: 5.44967e-21, loss: 9.26571
# cur_epoch: 1/800, cur_it: 458/464, lr: 2.44717e-21, loss: 9.27375
# cur_epoch: 1/800, cur_it: 459/464, lr: 6.15583e-22, loss: 9.26836
# cur_epoch: 1/800, cur_it: 460/464, lr: 0.0, loss: 9.26239
# cur_epoch: 1/800, cur_it: 461/464, lr: 6.15583e-22, loss: 9.26037
# cur_epoch: 1/800, cur_it: 462/464, lr: 2.44717e-21, loss: 9.25512
# cur_epoch: 1/800, cur_it: 463/464, lr: 5.44967e-21, loss: 9.25922
# 2023-07-23 08:26:37,842   INFO  **********************Start testing**********************
# cur_epoch: 1/800, cur_it: 464/464, lr: 9.54915e-21, loss: 9.25734
# Average predicted number of objects(3769 samples): 0.000
# /home/pai/lib/python3.9/site-packages/numba/core/typed_passes.py:329: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "../pcdet/datasets/kitti/kitti_object_eval_python/eval.py", line 122:
# @numba.jit(nopython=True, parallel=True)
# def d3_box_overlap_kernel(boxes, qboxes, rinc, criterion=-1):
# ^
#
#   warnings.warn(errors.NumbaPerformanceWarning(msg,
# epochs:   0%|          | 1/800 [08:56<119:07:22, 536.72s/it]
# 0.0 0.0 {'recall/roi_0.3': 0.0, 'recall/rcnn_0.3': 0.0, 'recall/roi_0.5': 0.0, 'recall/rcnn_0.5': 0.0, 'recall/roi_0.7': 0.0, 'recall/rcnn_0.7': 0.0, 'Car_3d/easy_R40': 0.0, 'Car_3d/moderate_R40': 0.0, 'Car_3d/hard_R40': 0.0, 'Car_bev/easy_R40': 0.0, 'Car_bev/moderate_R40': 0.0, 'Car_bev/hard_R40': 0.0, 'Car_image/easy_R40': 0.0, 'Car_image/moderate_R40': 0.0, 'Car_image/hard_R40': 0.0, 'Pedestrian_3d/easy_R40': 0.0, 'Pedestrian_3d/moderate_R40': 0.0, 'Pedestrian_3d/hard_R40': 0.0, 'Pedestrian_bev/easy_R40': 0.0, 'Pedestrian_bev/moderate_R40': 0.0, 'Pedestrian_bev/hard_R40': 0.0, 'Pedestrian_image/easy_R40': 0.0, 'Pedestrian_image/moderate_R40': 0.0, 'Pedestrian_image/hard_R40': 0.0, 'Cyclist_3d/easy_R40': 0.0, 'Cyclist_3d/moderate_R40': 0.0, 'Cyclist_3d/hard_R40': 0.0, 'Cyclist_bev/easy_R40': 0.0, 'Cyclist_bev/moderate_R40': 0.0, 'Cyclist_bev/hard_R40': 0.0, 'Cyclist_image/easy_R40': 0.0, 'Cyclist_image/moderate_R40': 0.0, 'Cyclist_image/hard_R40': 0.0}
# cur_epoch: 2/800, cur_it: 1/464, lr: 1.46447e-20, loss: 13.2927
# cur_epoch: 2/800, cur_it: 2/464, lr: 2.06107e-20, loss: 11.9014
# cur_epoch: 2/800, cur_it: 3/464, lr: 2.73005e-20, loss: 12.3611
# cur_epoch: 2/800, cur_it: 4/464, lr: 3.45492e-20, loss: 11.5336
# cur_epoch: 2/800, cur_it: 5/464, lr: 4.21783e-20, loss: 10.5669
# cur_epoch: 2/800, cur_it: 6/464, lr: 5e-20, loss: 10.1602
# cur_epoch: 2/800, cur_it: 7/464, lr: 5.78217e-20, loss: 9.99329
# cur_epoch: 2/800, cur_it: 8/464, lr: 6.54508e-20, loss: 9.79415
# cur_epoch: 2/800, cur_it: 9/464, lr: 7.26995e-20, loss: 10.0919
# cur_epoch: 2/800, cur_it: 10/464, lr: 7.93893e-20, loss: 10.0055
# cur_epoch: 2/800, cur_it: 11/464, lr: 8.53553e-20, loss: 9.861
# cur_epoch: 2/800, cur_it: 12/464, lr: 9.04508e-20, loss: 9.65934
# cur_epoch: 2/800, cur_it: 13/464, lr: 9.45503e-20, loss: 9.42999
# cur_epoch: 2/800, cur_it: 14/464, lr: 9.75528e-20, loss: 9.62672
# cur_epoch: 2/800, cur_it: 15/464, lr: 9.93844e-20, loss: 9.43592
# cur_epoch: 2/800, cur_it: 16/464, lr: 1e-19, loss: 9.23827
# cur_epoch: 2/800, cur_it: 17/464, lr: 9.93844e-20, loss: 9.1628
# cur_epoch: 2/800, cur_it: 18/464, lr: 9.75528e-20, loss: 9.11255
# cur_epoch: 2/800, cur_it: 19/464, lr: 9.45503e-20, loss: 9.22204
# cur_epoch: 2/800, cur_it: 20/464, lr: 9.04508e-20, loss: 9.21007
# cur_epoch: 2/800, cur_it: 21/464, lr: 8.53553e-20, loss: 9.27114
# cur_epoch: 2/800, cur_it: 22/464, lr: 7.93893e-20, loss: 9.32401
# cur_epoch: 2/800, cur_it: 23/464, lr: 7.26995e-20, loss: 9.24885
# cur_epoch: 2/800, cur_it: 24/464, lr: 6.54508e-20, loss: 9.17929
# cur_epoch: 2/800, cur_it: 25/464, lr: 5.78217e-20, loss: 9.29603
# cur_epoch: 2/800, cur_it: 26/464, lr: 5e-20, loss: 9.21957
# cur_epoch: 2/800, cur_it: 27/464, lr: 4.21783e-20, loss: 9.13189
# cur_epoch: 2/800, cur_it: 28/464, lr: 3.45492e-20, loss: 9.04664
# cur_epoch: 2/800, cur_it: 29/464, lr: 2.73005e-20, loss: 9.36757
# cur_epoch: 2/800, cur_it: 30/464, lr: 2.06107e-20, loss: 9.516
# cur_epoch: 2/800, cur_it: 31/464, lr: 1.46447e-20, loss: 9.42699
# cur_epoch: 2/800, cur_it: 32/464, lr: 9.54915e-21, loss: 9.45686
# cur_epoch: 2/800, cur_it: 33/464, lr: 5.44967e-21, loss: 9.37833
# cur_epoch: 2/800, cur_it: 34/464, lr: 2.44717e-21, loss: 9.30892
# cur_epoch: 2/800, cur_it: 35/464, lr: 6.15583e-22, loss: 9.24709
# cur_epoch: 2/800, cur_it: 36/464, lr: 0.0, loss: 9.1597
# cur_epoch: 2/800, cur_it: 37/464, lr: 6.15583e-22, loss: 9.07432
# cur_epoch: 2/800, cur_it: 38/464, lr: 2.44717e-21, loss: 9.04864
# cur_epoch: 2/800, cur_it: 39/464, lr: 5.44967e-21, loss: 9.01116
# cur_epoch: 2/800, cur_it: 40/464, lr: 9.54915e-21, loss: 8.91801
# cur_epoch: 2/800, cur_it: 41/464, lr: 1.46447e-20, loss: 8.86336
# cur_epoch: 2/800, cur_it: 42/464, lr: 2.06107e-20, loss: 8.90753
# cur_epoch: 2/800, cur_it: 43/464, lr: 2.73005e-20, loss: 8.89239
# cur_epoch: 2/800, cur_it: 44/464, lr: 3.45492e-20, loss: 8.82258
# cur_epoch: 2/800, cur_it: 45/464, lr: 4.21783e-20, loss: 8.85269
# cur_epoch: 2/800, cur_it: 46/464, lr: 5e-20, loss: 8.85363
# cur_epoch: 2/800, cur_it: 47/464, lr: 5.78217e-20, loss: 8.82602
# cur_epoch: 2/800, cur_it: 48/464, lr: 6.54508e-20, loss: 8.7997
# cur_epoch: 2/800, cur_it: 49/464, lr: 7.26995e-20, loss: 8.7709
# cur_epoch: 2/800, cur_it: 50/464, lr: 7.93893e-20, loss: 8.79946
# cur_epoch: 2/800, cur_it: 51/464, lr: 8.53553e-20, loss: 8.79673
# cur_epoch: 2/800, cur_it: 52/464, lr: 9.04508e-20, loss: 8.79894
# cur_epoch: 2/800, cur_it: 53/464, lr: 9.45503e-20, loss: 8.80818
# cur_epoch: 2/800, cur_it: 54/464, lr: 9.75528e-20, loss: 8.79237
# cur_epoch: 2/800, cur_it: 55/464, lr: 9.93844e-20, loss: 8.76183
# cur_epoch: 2/800, cur_it: 56/464, lr: 1e-19, loss: 8.79306
# cur_epoch: 2/800, cur_it: 57/464, lr: 9.93844e-20, loss: 8.77335
# cur_epoch: 2/800, cur_it: 58/464, lr: 9.75528e-20, loss: 8.71148
# cur_epoch: 2/800, cur_it: 59/464, lr: 9.45503e-20, loss: 8.80938
# cur_epoch: 2/800, cur_it: 60/464, lr: 9.04508e-20, loss: 8.81554
# cur_epoch: 2/800, cur_it: 61/464, lr: 8.53553e-20, loss: 8.80487
# cur_epoch: 2/800, cur_it: 62/464, lr: 7.93893e-20, loss: 8.81302
# cur_epoch: 2/800, cur_it: 63/464, lr: 7.26995e-20, loss: 8.84113
# cur_epoch: 2/800, cur_it: 64/464, lr: 6.54508e-20, loss: 8.87066
# cur_epoch: 2/800, cur_it: 65/464, lr: 5.78217e-20, loss: 8.85755
# cur_epoch: 2/800, cur_it: 66/464, lr: 5e-20, loss: 8.92581
# cur_epoch: 2/800, cur_it: 67/464, lr: 4.21783e-20, loss: 8.93403
# cur_epoch: 2/800, cur_it: 68/464, lr: 3.45492e-20, loss: 8.94477
# cur_epoch: 2/800, cur_it: 69/464, lr: 2.73005e-20, loss: 8.99821
# cur_epoch: 2/800, cur_it: 70/464, lr: 2.06107e-20, loss: 8.99525
# cur_epoch: 2/800, cur_it: 71/464, lr: 1.46447e-20, loss: 9.0201
# cur_epoch: 2/800, cur_it: 72/464, lr: 9.54915e-21, loss: 9.04824
# cur_epoch: 2/800, cur_it: 73/464, lr: 5.44967e-21, loss: 8.99282
# cur_epoch: 2/800, cur_it: 74/464, lr: 2.44717e-21, loss: 9.00352
# cur_epoch: 2/800, cur_it: 75/464, lr: 6.15583e-22, loss: 8.97938
# cur_epoch: 2/800, cur_it: 76/464, lr: 0.0, loss: 8.99516
# cur_epoch: 2/800, cur_it: 77/464, lr: 6.15583e-22, loss: 8.95254
# cur_epoch: 2/800, cur_it: 78/464, lr: 2.44717e-21, loss: 8.91438
# cur_epoch: 2/800, cur_it: 79/464, lr: 5.44967e-21, loss: 8.94931
# cur_epoch: 2/800, cur_it: 80/464, lr: 9.54915e-21, loss: 8.9145
# cur_epoch: 2/800, cur_it: 81/464, lr: 1.46447e-20, loss: 8.94289
# cur_epoch: 2/800, cur_it: 82/464, lr: 2.06107e-20, loss: 9.09615
# cur_epoch: 2/800, cur_it: 83/464, lr: 2.73005e-20, loss: 9.09713
# cur_epoch: 2/800, cur_it: 84/464, lr: 3.45492e-20, loss: 9.14925
# cur_epoch: 2/800, cur_it: 85/464, lr: 4.21783e-20, loss: 9.16583
# cur_epoch: 2/800, cur_it: 86/464, lr: 5e-20, loss: 9.19288
# cur_epoch: 2/800, cur_it: 87/464, lr: 5.78217e-20, loss: 9.18186
# cur_epoch: 2/800, cur_it: 88/464, lr: 6.54508e-20, loss: 9.20084
# cur_epoch: 2/800, cur_it: 89/464, lr: 7.26995e-20, loss: 9.2917
# cur_epoch: 2/800, cur_it: 90/464, lr: 7.93893e-20, loss: 9.30617
# cur_epoch: 2/800, cur_it: 91/464, lr: 8.53553e-20, loss: 9.3896
# cur_epoch: 2/800, cur_it: 92/464, lr: 9.04508e-20, loss: 9.41393
# cur_epoch: 2/800, cur_it: 93/464, lr: 9.45503e-20, loss: 9.39464
# cur_epoch: 2/800, cur_it: 94/464, lr: 9.75528e-20, loss: 9.50586
# cur_epoch: 2/800, cur_it: 95/464, lr: 9.93844e-20, loss: 9.49536
# cur_epoch: 2/800, cur_it: 96/464, lr: 1e-19, loss: 9.46484
# cur_epoch: 2/800, cur_it: 97/464, lr: 9.93844e-20, loss: 9.49077
# cur_epoch: 2/800, cur_it: 98/464, lr: 9.75528e-20, loss: 9.44543
# cur_epoch: 2/800, cur_it: 99/464, lr: 9.45503e-20, loss: 9.45525
# cur_epoch: 2/800, cur_it: 100/464, lr: 9.04508e-20, loss: 9.42483
# cur_epoch: 2/800, cur_it: 101/464, lr: 8.53553e-20, loss: 9.43511
# cur_epoch: 2/800, cur_it: 102/464, lr: 7.93893e-20, loss: 9.42458
# cur_epoch: 2/800, cur_it: 103/464, lr: 7.26995e-20, loss: 9.39742
# cur_epoch: 2/800, cur_it: 104/464, lr: 6.54508e-20, loss: 9.41126
# cur_epoch: 2/800, cur_it: 105/464, lr: 5.78217e-20, loss: 9.38529
# cur_epoch: 2/800, cur_it: 106/464, lr: 5e-20, loss: 9.37694
# cur_epoch: 2/800, cur_it: 107/464, lr: 4.21783e-20, loss: 9.36146
# cur_epoch: 2/800, cur_it: 108/464, lr: 3.45492e-20, loss: 9.34444
# cur_epoch: 2/800, cur_it: 109/464, lr: 2.73005e-20, loss: 9.34079
# cur_epoch: 2/800, cur_it: 110/464, lr: 2.06107e-20, loss: 9.32005
# cur_epoch: 2/800, cur_it: 111/464, lr: 1.46447e-20, loss: 9.34367
# cur_epoch: 2/800, cur_it: 112/464, lr: 9.54915e-21, loss: 9.36909
# cur_epoch: 2/800, cur_it: 113/464, lr: 5.44967e-21, loss: 9.40134
# cur_epoch: 2/800, cur_it: 114/464, lr: 2.44717e-21, loss: 9.38048
# cur_epoch: 2/800, cur_it: 115/464, lr: 6.15583e-22, loss: 9.40459
# cur_epoch: 2/800, cur_it: 116/464, lr: 0.0, loss: 9.39593
# cur_epoch: 2/800, cur_it: 117/464, lr: 6.15583e-22, loss: 9.37107
# cur_epoch: 2/800, cur_it: 118/464, lr: 2.44717e-21, loss: 9.3793
# cur_epoch: 2/800, cur_it: 119/464, lr: 5.44967e-21, loss: 9.41027
# cur_epoch: 2/800, cur_it: 120/464, lr: 9.54915e-21, loss: 9.44594
# cur_epoch: 2/800, cur_it: 121/464, lr: 1.46447e-20, loss: 9.43182
# cur_epoch: 2/800, cur_it: 122/464, lr: 2.06107e-20, loss: 9.45011
# cur_epoch: 2/800, cur_it: 123/464, lr: 2.73005e-20, loss: 9.46466
# cur_epoch: 2/800, cur_it: 124/464, lr: 3.45492e-20, loss: 9.45897
# cur_epoch: 2/800, cur_it: 125/464, lr: 4.21783e-20, loss: 9.44327
# cur_epoch: 2/800, cur_it: 126/464, lr: 5e-20, loss: 9.44333
# cur_epoch: 2/800, cur_it: 127/464, lr: 5.78217e-20, loss: 9.42481
# cur_epoch: 2/800, cur_it: 128/464, lr: 6.54508e-20, loss: 9.49148
# cur_epoch: 2/800, cur_it: 129/464, lr: 7.26995e-20, loss: 9.4827
# cur_epoch: 2/800, cur_it: 130/464, lr: 7.93893e-20, loss: 9.4843
# cur_epoch: 2/800, cur_it: 131/464, lr: 8.53553e-20, loss: 9.45691
# cur_epoch: 2/800, cur_it: 132/464, lr: 9.04508e-20, loss: 9.46134
# cur_epoch: 2/800, cur_it: 133/464, lr: 9.45503e-20, loss: 9.42826
# cur_epoch: 2/800, cur_it: 134/464, lr: 9.75528e-20, loss: 9.43029
# cur_epoch: 2/800, cur_it: 135/464, lr: 9.93844e-20, loss: 9.42253
# cur_epoch: 2/800, cur_it: 136/464, lr: 1e-19, loss: 9.39964
# cur_epoch: 2/800, cur_it: 137/464, lr: 9.93844e-20, loss: 9.44868
# cur_epoch: 2/800, cur_it: 138/464, lr: 9.75528e-20, loss: 9.46145
# cur_epoch: 2/800, cur_it: 139/464, lr: 9.45503e-20, loss: 9.44356
# cur_epoch: 2/800, cur_it: 140/464, lr: 9.04508e-20, loss: 9.49613
# cur_epoch: 2/800, cur_it: 141/464, lr: 8.53553e-20, loss: 9.49137
# cur_epoch: 2/800, cur_it: 142/464, lr: 7.93893e-20, loss: 9.4784
# cur_epoch: 2/800, cur_it: 143/464, lr: 7.26995e-20, loss: 9.44786
# cur_epoch: 2/800, cur_it: 144/464, lr: 6.54508e-20, loss: 9.4451
# cur_epoch: 2/800, cur_it: 145/464, lr: 5.78217e-20, loss: 9.41573
# cur_epoch: 2/800, cur_it: 146/464, lr: 5e-20, loss: 9.38818
# cur_epoch: 2/800, cur_it: 147/464, lr: 4.21783e-20, loss: 9.38216
# cur_epoch: 2/800, cur_it: 148/464, lr: 3.45492e-20, loss: 9.40459
# cur_epoch: 2/800, cur_it: 149/464, lr: 2.73005e-20, loss: 9.40198
# cur_epoch: 2/800, cur_it: 150/464, lr: 2.06107e-20, loss: 9.38056
# cur_epoch: 2/800, cur_it: 151/464, lr: 1.46447e-20, loss: 9.36643
# cur_epoch: 2/800, cur_it: 152/464, lr: 9.54915e-21, loss: 9.35373
# cur_epoch: 2/800, cur_it: 153/464, lr: 5.44967e-21, loss: 9.39157
# cur_epoch: 2/800, cur_it: 154/464, lr: 2.44717e-21, loss: 9.37508
# cur_epoch: 2/800, cur_it: 155/464, lr: 6.15583e-22, loss: 9.37827
# cur_epoch: 2/800, cur_it: 156/464, lr: 0.0, loss: 9.39757
# cur_epoch: 2/800, cur_it: 157/464, lr: 6.15583e-22, loss: 9.41012
# cur_epoch: 2/800, cur_it: 158/464, lr: 2.44717e-21, loss: 9.41522
# cur_epoch: 2/800, cur_it: 159/464, lr: 5.44967e-21, loss: 9.40206
# cur_epoch: 2/800, cur_it: 160/464, lr: 9.54915e-21, loss: 9.38622
# cur_epoch: 2/800, cur_it: 161/464, lr: 1.46447e-20, loss: 9.36746
# cur_epoch: 2/800, cur_it: 162/464, lr: 2.06107e-20, loss: 9.37642
# cur_epoch: 2/800, cur_it: 163/464, lr: 2.73005e-20, loss: 9.40558
# cur_epoch: 2/800, cur_it: 164/464, lr: 3.45492e-20, loss: 9.40789
# cur_epoch: 2/800, cur_it: 165/464, lr: 4.21783e-20, loss: 9.40948
# cur_epoch: 2/800, cur_it: 166/464, lr: 5e-20, loss: 9.40311
# cur_epoch: 2/800, cur_it: 167/464, lr: 5.78217e-20, loss: 9.3847
# cur_epoch: 2/800, cur_it: 168/464, lr: 6.54508e-20, loss: 9.4056
# cur_epoch: 2/800, cur_it: 169/464, lr: 7.26995e-20, loss: 9.413
# cur_epoch: 2/800, cur_it: 170/464, lr: 7.93893e-20, loss: 9.41568
# cur_epoch: 2/800, cur_it: 171/464, lr: 8.53553e-20, loss: 9.4045
# cur_epoch: 2/800, cur_it: 172/464, lr: 9.04508e-20, loss: 9.41099
# cur_epoch: 2/800, cur_it: 173/464, lr: 9.45503e-20, loss: 9.42088
# cur_epoch: 2/800, cur_it: 174/464, lr: 9.75528e-20, loss: 9.40323
# cur_epoch: 2/800, cur_it: 175/464, lr: 9.93844e-20, loss: 9.39653
# cur_epoch: 2/800, cur_it: 176/464, lr: 1e-19, loss: 9.39439
# cur_epoch: 2/800, cur_it: 177/464, lr: 9.93844e-20, loss: 9.38289
# cur_epoch: 2/800, cur_it: 178/464, lr: 9.75528e-20, loss: 9.39499
# cur_epoch: 2/800, cur_it: 179/464, lr: 9.45503e-20, loss: 9.38277
# cur_epoch: 2/800, cur_it: 180/464, lr: 9.04508e-20, loss: 9.37935
# cur_epoch: 2/800, cur_it: 181/464, lr: 8.53553e-20, loss: 9.36864
# cur_epoch: 2/800, cur_it: 182/464, lr: 7.93893e-20, loss: 9.34695
# cur_epoch: 2/800, cur_it: 183/464, lr: 7.26995e-20, loss: 9.35816
# cur_epoch: 2/800, cur_it: 184/464, lr: 6.54508e-20, loss: 9.35388
# cur_epoch: 2/800, cur_it: 185/464, lr: 5.78217e-20, loss: 9.34932
# cur_epoch: 2/800, cur_it: 186/464, lr: 5e-20, loss: 9.36481
# cur_epoch: 2/800, cur_it: 187/464, lr: 4.21783e-20, loss: 9.35956
# cur_epoch: 2/800, cur_it: 188/464, lr: 3.45492e-20, loss: 9.36355
# cur_epoch: 2/800, cur_it: 189/464, lr: 2.73005e-20, loss: 9.36442
# cur_epoch: 2/800, cur_it: 190/464, lr: 2.06107e-20, loss: 9.35144
# cur_epoch: 2/800, cur_it: 191/464, lr: 1.46447e-20, loss: 9.36294
# cur_epoch: 2/800, cur_it: 192/464, lr: 9.54915e-21, loss: 9.36828
# cur_epoch: 2/800, cur_it: 193/464, lr: 5.44967e-21, loss: 9.36297
# cur_epoch: 2/800, cur_it: 194/464, lr: 2.44717e-21, loss: 9.37905
# cur_epoch: 2/800, cur_it: 195/464, lr: 6.15583e-22, loss: 9.37846
# cur_epoch: 2/800, cur_it: 196/464, lr: 0.0, loss: 9.39569
# cur_epoch: 2/800, cur_it: 197/464, lr: 6.15583e-22, loss: 9.42584
# cur_epoch: 2/800, cur_it: 198/464, lr: 2.44717e-21, loss: 9.43089
# cur_epoch: 2/800, cur_it: 199/464, lr: 5.44967e-21, loss: 9.42393
# cur_epoch: 2/800, cur_it: 200/464, lr: 9.54915e-21, loss: 9.42926
# cur_epoch: 2/800, cur_it: 201/464, lr: 1.46447e-20, loss: 9.43182
# cur_epoch: 2/800, cur_it: 202/464, lr: 2.06107e-20, loss: 9.43905
# cur_epoch: 2/800, cur_it: 203/464, lr: 2.73005e-20, loss: 9.41955
# cur_epoch: 2/800, cur_it: 204/464, lr: 3.45492e-20, loss: 9.42177
# cur_epoch: 2/800, cur_it: 205/464, lr: 4.21783e-20, loss: 9.41232
# cur_epoch: 2/800, cur_it: 206/464, lr: 5e-20, loss: 9.39482
# cur_epoch: 2/800, cur_it: 207/464, lr: 5.78217e-20, loss: 9.39689
# cur_epoch: 2/800, cur_it: 208/464, lr: 6.54508e-20, loss: 9.39268
# cur_epoch: 2/800, cur_it: 209/464, lr: 7.26995e-20, loss: 9.40132
# cur_epoch: 2/800, cur_it: 210/464, lr: 7.93893e-20, loss: 9.39285
# cur_epoch: 2/800, cur_it: 211/464, lr: 8.53553e-20, loss: 9.38718
# cur_epoch: 2/800, cur_it: 212/464, lr: 9.04508e-20, loss: 9.37739
# cur_epoch: 2/800, cur_it: 213/464, lr: 9.45503e-20, loss: 9.36766
# cur_epoch: 2/800, cur_it: 214/464, lr: 9.75528e-20, loss: 9.37655
# cur_epoch: 2/800, cur_it: 215/464, lr: 9.93844e-20, loss: 9.38623
# cur_epoch: 2/800, cur_it: 216/464, lr: 1e-19, loss: 9.39773
# cur_epoch: 2/800, cur_it: 217/464, lr: 9.93844e-20, loss: 9.40375
# cur_epoch: 2/800, cur_it: 218/464, lr: 9.75528e-20, loss: 9.44466
# cur_epoch: 2/800, cur_it: 219/464, lr: 9.45503e-20, loss: 9.42958
# cur_epoch: 2/800, cur_it: 220/464, lr: 9.04508e-20, loss: 9.44159
# cur_epoch: 2/800, cur_it: 221/464, lr: 8.53553e-20, loss: 9.42865
# cur_epoch: 2/800, cur_it: 222/464, lr: 7.93893e-20, loss: 9.41876
# cur_epoch: 2/800, cur_it: 223/464, lr: 7.26995e-20, loss: 9.42427
# cur_epoch: 2/800, cur_it: 224/464, lr: 6.54508e-20, loss: 9.42427
# cur_epoch: 2/800, cur_it: 225/464, lr: 5.78217e-20, loss: 9.40661
# cur_epoch: 2/800, cur_it: 226/464, lr: 5e-20, loss: 9.409
# cur_epoch: 2/800, cur_it: 227/464, lr: 4.21783e-20, loss: 9.42645
# cur_epoch: 2/800, cur_it: 228/464, lr: 3.45492e-20, loss: 9.42603
# ...
# cur_epoch: 2/800, cur_it: 270/464, lr: 2.06107e-20, loss: 9.53478
# cur_epoch: 2/800, cur_it: 271/464, lr: 1.46447e-20, loss: 9.54915
# cur_epoch: 2/800, cur_it: 272/464, lr: 9.54915e-21, loss: 9.55627
# cur_epoch: 2/800, cur_it: 273/464, lr: 5.44967e-21, loss: 9.54889
# cur_epoch: 2/800, cur_it: 274/464, lr: 2.44717e-21, loss: 9.55312
# cur_epoch: 2/800, cur_it: 275/464, lr: 6.15583e-22, loss: 9.58597
# cur_epoch: 2/800, cur_it: 276/464, lr: 0.0, loss: 9.58356
# cur_epoch: 2/800, cur_it: 277/464, lr: 6.15583e-22, loss: 9.58494
# cur_epoch: 2/800, cur_it: 278/464, lr: 2.44717e-21, loss: 9.58855
# cur_epoch: 2/800, cur_it: 279/464, lr: 5.44967e-21, loss: 9.5904
# cur_epoch: 2/800, cur_it: 280/464, lr: 9.54915e-21, loss: 9.60004
# cur_epoch: 2/800, cur_it: 281/464, lr: 1.46447e-20, loss: 9.58867
# cur_epoch: 2/800, cur_it: 282/464, lr: 2.06107e-20, loss: 9.58204
# cur_epoch: 2/800, cur_it: 283/464, lr: 2.73005e-20, loss: 9.58393
# cur_epoch: 2/800, cur_it: 284/464, lr: 3.45492e-20, loss: 9.58646
# cur_epoch: 2/800, cur_it: 285/464, lr: 4.21783e-20, loss: 9.58144
# cur_epoch: 2/800, cur_it: 286/464, lr: 5e-20, loss: 9.58036
# cur_epoch: 2/800, cur_it: 287/464, lr: 5.78217e-20, loss: 9.58531
# cur_epoch: 2/800, cur_it: 288/464, lr: 6.54508e-20, loss: 9.58913
# cur_epoch: 2/800, cur_it: 289/464, lr: 7.26995e-20, loss: 9.58379
# cur_epoch: 2/800, cur_it: 290/464, lr: 7.93893e-20, loss: 9.57439
# cur_epoch: 2/800, cur_it: 291/464, lr: 8.53553e-20, loss: 9.57225
# cur_epoch: 2/800, cur_it: 292/464, lr: 9.04508e-20, loss: 9.58193
# cur_epoch: 2/800, cur_it: 293/464, lr: 9.45503e-20, loss: 9.57003
# cur_epoch: 2/800, cur_it: 294/464, lr: 9.75528e-20, loss: 9.57205
# cur_epoch: 2/800, cur_it: 295/464, lr: 9.93844e-20, loss: 9.57209
# cur_epoch: 2/800, cur_it: 296/464, lr: 1e-19, loss: 9.57055
# cur_epoch: 2/800, cur_it: 297/464, lr: 9.93844e-20, loss: 9.57285
# cur_epoch: 2/800, cur_it: 298/464, lr: 9.75528e-20, loss: 9.56989
# cur_epoch: 2/800, cur_it: 299/464, lr: 9.45503e-20, loss: 9.56775
# cur_epoch: 2/800, cur_it: 300/464, lr: 9.04508e-20, loss: 9.58313
# cur_epoch: 2/800, cur_it: 301/464, lr: 8.53553e-20, loss: 9.59015
# cur_epoch: 2/800, cur_it: 302/464, lr: 7.93893e-20, loss: 9.59743
# cur_epoch: 2/800, cur_it: 303/464, lr: 7.26995e-20, loss: 9.60047
# cur_epoch: 2/800, cur_it: 304/464, lr: 6.54508e-20, loss: 9.61053
# cur_epoch: 2/800, cur_it: 305/464, lr: 5.78217e-20, loss: 9.6132
# cur_epoch: 2/800, cur_it: 306/464, lr: 5e-20, loss: 9.60374
# cur_epoch: 2/800, cur_it: 307/464, lr: 4.21783e-20, loss: 9.59925
# cur_epoch: 2/800, cur_it: 308/464, lr: 3.45492e-20, loss: 9.60533
# cur_epoch: 2/800, cur_it: 309/464, lr: 2.73005e-20, loss: 9.59617
# cur_epoch: 2/800, cur_it: 310/464, lr: 2.06107e-20, loss: 9.59476
# cur_epoch: 2/800, cur_it: 311/464, lr: 1.46447e-20, loss: 9.59627
# cur_epoch: 2/800, cur_it: 312/464, lr: 9.54915e-21, loss: 9.59917
# cur_epoch: 2/800, cur_it: 313/464, lr: 5.44967e-21, loss: 9.60301
# cur_epoch: 2/800, cur_it: 314/464, lr: 2.44717e-21, loss: 9.59546
# cur_epoch: 2/800, cur_it: 315/464, lr: 6.15583e-22, loss: 9.58259
# cur_epoch: 2/800, cur_it: 316/464, lr: 0.0, loss: 9.58425
# cur_epoch: 2/800, cur_it: 317/464, lr: 6.15583e-22, loss: 9.57562
# cur_epoch: 2/800, cur_it: 318/464, lr: 2.44717e-21, loss: 9.59494
# cur_epoch: 2/800, cur_it: 319/464, lr: 5.44967e-21, loss: 9.588
# cur_epoch: 2/800, cur_it: 320/464, lr: 9.54915e-21, loss: 9.58942
# cur_epoch: 2/800, cur_it: 321/464, lr: 1.46447e-20, loss: 9.58757
# cur_epoch: 2/800, cur_it: 322/464, lr: 2.06107e-20, loss: 9.57543
# cur_epoch: 2/800, cur_it: 323/464, lr: 2.73005e-20, loss: 9.56691
# cur_epoch: 2/800, cur_it: 324/464, lr: 3.45492e-20, loss: 9.56593
# cur_epoch: 2/800, cur_it: 325/464, lr: 4.21783e-20, loss: 9.55362
# cur_epoch: 2/800, cur_it: 326/464, lr: 5e-20, loss: 9.54968
# cur_epoch: 2/800, cur_it: 327/464, lr: 5.78217e-20, loss: 9.55193
# cur_epoch: 2/800, cur_it: 328/464, lr: 6.54508e-20, loss: 9.55668
# cur_epoch: 2/800, cur_it: 329/464, lr: 7.26995e-20, loss: 9.54787
# cur_epoch: 2/800, cur_it: 330/464, lr: 7.93893e-20, loss: 9.53944
# cur_epoch: 2/800, cur_it: 331/464, lr: 8.53553e-20, loss: 9.5399
# cur_epoch: 2/800, cur_it: 332/464, lr: 9.04508e-20, loss: 9.54051
# cur_epoch: 2/800, cur_it: 333/464, lr: 9.45503e-20, loss: 9.58629
# cur_epoch: 2/800, cur_it: 334/464, lr: 9.75528e-20, loss: 9.58647
# cur_epoch: 2/800, cur_it: 335/464, lr: 9.93844e-20, loss: 9.58437
# cur_epoch: 2/800, cur_it: 336/464, lr: 1e-19, loss: 9.57852
# cur_epoch: 2/800, cur_it: 337/464, lr: 9.93844e-20, loss: 9.5778
# cur_epoch: 2/800, cur_it: 338/464, lr: 9.75528e-20, loss: 9.57794
# cur_epoch: 2/800, cur_it: 339/464, lr: 9.45503e-20, loss: 9.57029
# cur_epoch: 2/800, cur_it: 340/464, lr: 9.04508e-20, loss: 9.5991
# cur_epoch: 2/800, cur_it: 341/464, lr: 8.53553e-20, loss: 9.60322
# cur_epoch: 2/800, cur_it: 342/464, lr: 7.93893e-20, loss: 9.6092
# cur_epoch: 2/800, cur_it: 343/464, lr: 7.26995e-20, loss: 9.61763
# cur_epoch: 2/800, cur_it: 344/464, lr: 6.54508e-20, loss: 9.62547
# cur_epoch: 2/800, cur_it: 345/464, lr: 5.78217e-20, loss: 9.61707
# cur_epoch: 2/800, cur_it: 346/464, lr: 5e-20, loss: 9.61312
# cur_epoch: 2/800, cur_it: 347/464, lr: 4.21783e-20, loss: 9.61149
# cur_epoch: 2/800, cur_it: 348/464, lr: 3.45492e-20, loss: 9.61109
# cur_epoch: 2/800, cur_it: 349/464, lr: 2.73005e-20, loss: 9.60711
# cur_epoch: 2/800, cur_it: 350/464, lr: 2.06107e-20, loss: 9.60685
# cur_epoch: 2/800, cur_it: 351/464, lr: 1.46447e-20, loss: 9.60702
# cur_epoch: 2/800, cur_it: 352/464, lr: 9.54915e-21, loss: 9.61114
# cur_epoch: 2/800, cur_it: 353/464, lr: 5.44967e-21, loss: 9.60533
# cur_epoch: 2/800, cur_it: 354/464, lr: 2.44717e-21, loss: 9.60213
# cur_epoch: 2/800, cur_it: 355/464, lr: 6.15583e-22, loss: 9.60125
# cur_epoch: 2/800, cur_it: 356/464, lr: 0.0, loss: 9.60902
# cur_epoch: 2/800, cur_it: 357/464, lr: 6.15583e-22, loss: 9.6165
# cur_epoch: 2/800, cur_it: 358/464, lr: 2.44717e-21, loss: 9.62597
# cur_epoch: 2/800, cur_it: 359/464, lr: 5.44967e-21, loss: 9.61933
# cur_epoch: 2/800, cur_it: 360/464, lr: 9.54915e-21, loss: 9.61312
# cur_epoch: 2/800, cur_it: 361/464, lr: 1.46447e-20, loss: 9.61049
# cur_epoch: 2/800, cur_it: 362/464, lr: 2.06107e-20, loss: 9.61806
# cur_epoch: 2/800, cur_it: 363/464, lr: 2.73005e-20, loss: 9.61633
# cur_epoch: 2/800, cur_it: 364/464, lr: 3.45492e-20, loss: 9.61843
# cur_epoch: 2/800, cur_it: 365/464, lr: 4.21783e-20, loss: 9.61727
# cur_epoch: 2/800, cur_it: 366/464, lr: 5e-20, loss: 9.60866
# cur_epoch: 2/800, cur_it: 367/464, lr: 5.78217e-20, loss: 9.59817
# cur_epoch: 2/800, cur_it: 368/464, lr: 6.54508e-20, loss: 9.59433
# cur_epoch: 2/800, cur_it: 369/464, lr: 7.26995e-20, loss: 9.58572
# cur_epoch: 2/800, cur_it: 370/464, lr: 7.93893e-20, loss: 9.58665
# cur_epoch: 2/800, cur_it: 371/464, lr: 8.53553e-20, loss: 9.58254
# cur_epoch: 2/800, cur_it: 372/464, lr: 9.04508e-20, loss: 9.5792
# cur_epoch: 2/800, cur_it: 373/464, lr: 9.45503e-20, loss: 9.57624
# cur_epoch: 2/800, cur_it: 374/464, lr: 9.75528e-20, loss: 9.56894
# cur_epoch: 2/800, cur_it: 375/464, lr: 9.93844e-20, loss: 9.57775
# cur_epoch: 2/800, cur_it: 376/464, lr: 1e-19, loss: 9.57161
# cur_epoch: 2/800, cur_it: 377/464, lr: 9.93844e-20, loss: 9.56914
# cur_epoch: 2/800, cur_it: 378/464, lr: 9.75528e-20, loss: 9.56775
# cur_epoch: 2/800, cur_it: 379/464, lr: 9.45503e-20, loss: 9.5591
# cur_epoch: 2/800, cur_it: 380/464, lr: 9.04508e-20, loss: 9.55538
# cur_epoch: 2/800, cur_it: 381/464, lr: 8.53553e-20, loss: 9.55715
# cur_epoch: 2/800, cur_it: 382/464, lr: 7.93893e-20, loss: 9.55147
# cur_epoch: 2/800, cur_it: 383/464, lr: 7.26995e-20, loss: 9.55255
# cur_epoch: 2/800, cur_it: 384/464, lr: 6.54508e-20, loss: 9.55857
# cur_epoch: 2/800, cur_it: 385/464, lr: 5.78217e-20, loss: 9.56627
# cur_epoch: 2/800, cur_it: 386/464, lr: 5e-20, loss: 9.5731
# cur_epoch: 2/800, cur_it: 387/464, lr: 4.21783e-20, loss: 9.56986
# cur_epoch: 2/800, cur_it: 388/464, lr: 3.45492e-20, loss: 9.5683
# cur_epoch: 2/800, cur_it: 389/464, lr: 2.73005e-20, loss: 9.56213
# cur_epoch: 2/800, cur_it: 390/464, lr: 2.06107e-20, loss: 9.5695
# cur_epoch: 2/800, cur_it: 391/464, lr: 1.46447e-20, loss: 9.56177
# cur_epoch: 2/800, cur_it: 392/464, lr: 9.54915e-21, loss: 9.56001
# cur_epoch: 2/800, cur_it: 393/464, lr: 5.44967e-21, loss: 9.55295
# cur_epoch: 2/800, cur_it: 394/464, lr: 2.44717e-21, loss: 9.54328
# cur_epoch: 2/800, cur_it: 395/464, lr: 6.15583e-22, loss: 9.53316
# cur_epoch: 2/800, cur_it: 396/464, lr: 0.0, loss: 9.5313
# cur_epoch: 2/800, cur_it: 397/464, lr: 6.15583e-22, loss: 9.53304
# cur_epoch: 2/800, cur_it: 398/464, lr: 2.44717e-21, loss: 9.52981
# cur_epoch: 2/800, cur_it: 399/464, lr: 5.44967e-21, loss: 9.52411
# cur_epoch: 2/800, cur_it: 400/464, lr: 9.54915e-21, loss: 9.53117
# cur_epoch: 2/800, cur_it: 401/464, lr: 1.46447e-20, loss: 9.53908
# cur_epoch: 2/800, cur_it: 402/464, lr: 2.06107e-20, loss: 9.54215
# cur_epoch: 2/800, cur_it: 403/464, lr: 2.73005e-20, loss: 9.54083
# cur_epoch: 2/800, cur_it: 404/464, lr: 3.45492e-20, loss: 9.53745
# cur_epoch: 2/800, cur_it: 405/464, lr: 4.21783e-20, loss: 9.54241
# cur_epoch: 2/800, cur_it: 406/464, lr: 5e-20, loss: 9.54109
# cur_epoch: 2/800, cur_it: 407/464, lr: 5.78217e-20, loss: 9.54648
# cur_epoch: 2/800, cur_it: 408/464, lr: 6.54508e-20, loss: 9.54674
# cur_epoch: 2/800, cur_it: 409/464, lr: 7.26995e-20, loss: 9.5439
# cur_epoch: 2/800, cur_it: 410/464, lr: 7.93893e-20, loss: 9.5492
# cur_epoch: 2/800, cur_it: 411/464, lr: 8.53553e-20, loss: 9.55758
# cur_epoch: 2/800, cur_it: 412/464, lr: 9.04508e-20, loss: 9.55438
# cur_epoch: 2/800, cur_it: 413/464, lr: 9.45503e-20, loss: 9.55972
# cur_epoch: 2/800, cur_it: 414/464, lr: 9.75528e-20, loss: 9.55371
# cur_epoch: 2/800, cur_it: 415/464, lr: 9.93844e-20, loss: 9.54999
# cur_epoch: 2/800, cur_it: 416/464, lr: 1e-19, loss: 9.54516
# cur_epoch: 2/800, cur_it: 417/464, lr: 9.93844e-20, loss: 9.56487
# cur_epoch: 2/800, cur_it: 418/464, lr: 9.75528e-20, loss: 9.55862
# cur_epoch: 2/800, cur_it: 419/464, lr: 9.45503e-20, loss: 9.55897
# cur_epoch: 2/800, cur_it: 420/464, lr: 9.04508e-20, loss: 9.55937
# cur_epoch: 2/800, cur_it: 421/464, lr: 8.53553e-20, loss: 9.55531
# cur_epoch: 2/800, cur_it: 422/464, lr: 7.93893e-20, loss: 9.54898
# cur_epoch: 2/800, cur_it: 423/464, lr: 7.26995e-20, loss: 9.54641
# cur_epoch: 2/800, cur_it: 424/464, lr: 6.54508e-20, loss: 9.53902
# cur_epoch: 2/800, cur_it: 425/464, lr: 5.78217e-20, loss: 9.54993
# cur_epoch: 2/800, cur_it: 426/464, lr: 5e-20, loss: 9.54512
# cur_epoch: 2/800, cur_it: 427/464, lr: 4.21783e-20, loss: 9.53801
# cur_epoch: 2/800, cur_it: 428/464, lr: 3.45492e-20, loss: 9.54593
# cur_epoch: 2/800, cur_it: 429/464, lr: 2.73005e-20, loss: 9.54477
# cur_epoch: 2/800, cur_it: 430/464, lr: 2.06107e-20, loss: 9.55391
# cur_epoch: 2/800, cur_it: 431/464, lr: 1.46447e-20, loss: 9.55093
# cur_epoch: 2/800, cur_it: 432/464, lr: 9.54915e-21, loss: 9.55103
# cur_epoch: 2/800, cur_it: 433/464, lr: 5.44967e-21, loss: 9.54574
# cur_epoch: 2/800, cur_it: 434/464, lr: 2.44717e-21, loss: 9.53925
# cur_epoch: 2/800, cur_it: 435/464, lr: 6.15583e-22, loss: 9.54975
# cur_epoch: 2/800, cur_it: 436/464, lr: 0.0, loss: 9.54695
# cur_epoch: 2/800, cur_it: 437/464, lr: 6.15583e-22, loss: 9.54216
# cur_epoch: 2/800, cur_it: 438/464, lr: 2.44717e-21, loss: 9.54044
# cur_epoch: 2/800, cur_it: 439/464, lr: 5.44967e-21, loss: 9.53581
# cur_epoch: 2/800, cur_it: 440/464, lr: 9.54915e-21, loss: 9.52981
# cur_epoch: 2/800, cur_it: 441/464, lr: 1.46447e-20, loss: 9.53014
# cur_epoch: 2/800, cur_it: 442/464, lr: 2.06107e-20, loss: 9.53082
# cur_epoch: 2/800, cur_it: 443/464, lr: 2.73005e-20, loss: 9.52509
# cur_epoch: 2/800, cur_it: 444/464, lr: 3.45492e-20, loss: 9.52723
# cur_epoch: 2/800, cur_it: 445/464, lr: 4.21783e-20, loss: 9.52512
# cur_epoch: 2/800, cur_it: 446/464, lr: 5e-20, loss: 9.52428
# cur_epoch: 2/800, cur_it: 447/464, lr: 5.78217e-20, loss: 9.52034
# cur_epoch: 2/800, cur_it: 448/464, lr: 6.54508e-20, loss: 9.53458
# cur_epoch: 2/800, cur_it: 449/464, lr: 7.26995e-20, loss: 9.53563
# cur_epoch: 2/800, cur_it: 450/464, lr: 7.93893e-20, loss: 9.52759
# cur_epoch: 2/800, cur_it: 451/464, lr: 8.53553e-20, loss: 9.52753
# cur_epoch: 2/800, cur_it: 452/464, lr: 9.04508e-20, loss: 9.52267
# cur_epoch: 2/800, cur_it: 453/464, lr: 9.45503e-20, loss: 9.52103
# cur_epoch: 2/800, cur_it: 454/464, lr: 9.75528e-20, loss: 9.51938
# cur_epoch: 2/800, cur_it: 455/464, lr: 9.93844e-20, loss: 9.51849
# cur_epoch: 2/800, cur_it: 456/464, lr: 1e-19, loss: 9.52128
# cur_epoch: 2/800, cur_it: 457/464, lr: 9.93844e-20, loss: 9.51539
# cur_epoch: 2/800, cur_it: 458/464, lr: 9.75528e-20, loss: 9.51949
# cur_epoch: 2/800, cur_it: 459/464, lr: 9.45503e-20, loss: 9.52385
# cur_epoch: 2/800, cur_it: 460/464, lr: 9.04508e-20, loss: 9.52889
# cur_epoch: 2/800, cur_it: 461/464, lr: 8.53553e-20, loss: 9.52911
# cur_epoch: 2/800, cur_it: 462/464, lr: 7.93893e-20, loss: 9.5329
# cur_epoch: 2/800, cur_it: 463/464, lr: 7.26995e-20, loss: 9.52884
# 2023-07-23 08:35:44,843   INFO  **********************Start testing**********************
# cur_epoch: 2/800, cur_it: 464/464, lr: 6.54508e-20, loss: 9.52854
# Error in collate_batch: key=voxels
# epochs:   0%|          | 1/800 [15:21<204:26:57, 921.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 208
#     203     print('cur_epoch: {}/{}, cur_it: {}/{}, lr: {:.6}, loss: {:.6}'.format(cur_epoch+1, total_epochs, cur_it+1, total_it_each_epoch, optimizer.param_groups[0]['lr'], loss_avg))
#     205 logger.info('**********************Start testing**********************')
# --> 208 acc1, acc2, ret = eval_utils.eval_(cfg, model, test_loader)
#     209 print(acc1, acc2, ret)
#     211 filename = './save_path/0722/ckpt_epoch{}-{:.6f}-{:.6f}.pth'.format(cur_epoch+1, acc1, acc2)
#
# File /mnt/workspace/sunqiao/OpenPCDet/tools/eval_utils/eval_utils_multinomial_finalv_half.py:31, in eval_(cfg, model, dataloader)
#      29 load_data_to_gpu(batch_dict)
#      30 with torch.no_grad():
# ---> 31     pred_dicts, ret_dict = model(batch_dict)
#      32 disp_dict = {}
#      34 annos = dataset.generate_prediction_dicts(
#      35     batch_dict, pred_dicts, class_names, None
#      36 )
#
# File /home/pai/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /mnt/workspace/sunqiao/OpenPCDet/pcdet/models_multinomial_half/detectors/pointpillar.py:423, in PointPillar.forward(self, batch_dict)
#     421     return ret_dict, tb_dict, disp_dict
#     422 else:
# --> 423     pred_dicts, recall_dicts = self.post_processing(batch_dict)
#     424     return pred_dicts, recall_dicts
#
# File /mnt/workspace/sunqiao/OpenPCDet/pcdet/models_multinomial_half/detectors/pointpillar.py:285, in Detector3DTemplate.post_processing(self, batch_dict)
#     282     final_labels = label_preds[selected]
#     283     final_boxes = box_preds[selected]
# --> 285 recall_dict = self.generate_recall_record(
#     286     box_preds=final_boxes if 'rois' not in batch_dict else src_box_preds,
#     287     recall_dict=recall_dict, batch_index=index, data_dict=batch_dict,
#     288     thresh_list=post_process_cfg.RECALL_THRESH_LIST
#     289 )
#     291 record_dict = {
#     292     'pred_boxes': final_boxes,
#     293     'pred_scores': final_scores,
#     294     'pred_labels': final_labels
#     295 }
#     296 pred_dicts.append(record_dict)
#
# File /mnt/workspace/sunqiao/OpenPCDet/pcdet/models_multinomial_half/detectors/pointpillar.py:316, in Detector3DTemplate.generate_recall_record(box_preds, recall_dict, batch_index, data_dict, thresh_list)
#     314 cur_gt = gt_boxes
#     315 k = cur_gt.__len__() - 1
# --> 316 while k > 0 and cur_gt[k].sum() == 0:
#     317     k -= 1
#     318 cur_gt = cur_gt[:k + 1]
#
# KeyboardInterrupt:
