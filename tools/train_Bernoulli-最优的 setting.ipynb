# %% [markdown]
# 用最优的 setting 优化 Multinomial
#
# 已完成：调整学习率，降低代码复杂度

# %%
import tqdm
from torch.nn.utils import clip_grad_norm_
from pcdet.models_multinomial_half.detectors.pointpillar import PointPillar

import argparse
import datetime
import glob
import os
from pathlib import Path
from test import repeat_eval_ckpt, eval_single_ckpt
from noise import add_noise_to_weights
import numba
import logging
import time

from bayes_opt import BayesianOptimization
from bayes_opt.logger import JSONLogger
from bayes_opt.event import Events

import torch
import torch.distributed as dist
import torch.nn as nn
from tensorboardX import SummaryWriter

from pcdet.config import cfg, cfg_from_list, cfg_from_yaml_file, log_config_to_file
from pcdet.datasets import build_dataloader
from pcdet.models_multinomial_half import build_network, model_fn_decorator
from pcdet.utils import common_utils
from train_utils.optimization import build_optimizer, build_scheduler
# from train_utils.train_utils import train_model
# from eval_utils import eval_utils_multinomial
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
from eval_utils import eval_utils_multinomial_finalv_half as eval_utils



def load_data_to_gpu(batch_dict):
    for key, val in batch_dict.items():
        if not isinstance(val, np.ndarray):
            continue
        elif key in ['frame_id', 'metadata', 'calib']:
            continue
        elif key in ['images']:
            batch_dict[key] = image_to_tensor(val).float().cuda().contiguous()
        elif key in ['image_shape']:
            batch_dict[key] = torch.from_numpy(val).int().cuda()
        else:
            batch_dict[key] = torch.from_numpy(val).float().cuda()


def parse_config():
    parser = argparse.ArgumentParser(description='arg parser')
    parser.add_argument('--cfg_file', type=str, default='./cfgs/kitti_models/pointpillar_bayes.yaml', help='specify the config for training')
    parser.add_argument('--batch_size', type=int, default=8, required=False, help='batch size for training')
    parser.add_argument('--workers', type=int, default=32, help='number of workers for dataloader')
    parser.add_argument('--extra_tag', type=str, default='default', help='extra tag for this experiment')
    parser.add_argument('--pretrained_model', type=str, default=True, help='pretrained_model')
    parser.add_argument('--launcher', choices=['none', 'pytorch', 'slurm'], default='none')
    parser.add_argument('--tcp_port', type=int, default=18888, help='tcp port for distrbuted training')
    parser.add_argument('--sync_bn', action='store_true', default=False, help='whether to use sync bn')
    parser.add_argument('--fix_random_seed', action='store_true', default=True, help='')
    parser.add_argument('--ckpt_save_interval', type=int, default=80, help='number of training epochs')
    parser.add_argument('--local_rank', type=int, default=0, help='local rank for distributed training')
    parser.add_argument('--max_ckpt_save_num', type=int, default=81, help='max number of saved checkpoint')
    parser.add_argument('--merge_all_iters_to_one_epoch', action='store_true', default=False, help='')
    parser.add_argument('--set', dest='set_cfgs', default=None, nargs=argparse.REMAINDER, help='set extra config keys if needed')
    parser.add_argument('--max_waiting_mins', type=int, default=0, help='max waiting minutes')
    parser.add_argument('--start_epoch', type=int, default=0, help='')
    parser.add_argument('--save_to_file', action='store_true', default=False, help='')
    
    
    parser.add_argument('--epochs', type=int, default=800, required=False, help='number of epochs to train for')
    parser.add_argument('--ckpt', type=str, default='checkpoint_epoch_80_multinomial.pth', help='checkpoint to start from')

    args = parser.parse_known_args()[0]

    cfg_from_yaml_file(args.cfg_file, cfg)
    cfg.TAG = Path(args.cfg_file).stem
    cfg.EXP_GROUP_PATH = '/'.join(args.cfg_file.split('/')[1: -1])  # remove 'cfgs' and 'xxxx.yaml'

    if args.set_cfgs is not None:
        cfg_from_list(args.set_cfgs, cfg)

    return args, cfg




if __name__ == '__main__':
    torch.cuda.set_device(0)

    args, cfg = parse_config()
    dist_train = False
    total_gpus = 1
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
    os.system('nvidia-smi -q -d Memory |grep -A4 GPU|grep Free >tmp')
    memory_gpu = [int(x.split()[2]) for x in open('tmp', 'r').readlines()]
    print('Using GPU:' + str(np.argmax(memory_gpu)))
    os.environ["CUDA_VISIBLE_DEVICES"] = str(np.argmax(memory_gpu))
    os.system('rm tmp')


    if args.batch_size is None:
        args.batch_size = cfg.OPTIMIZATION.BATCH_SIZE_PER_GPU
    else:
        assert args.batch_size % total_gpus == 0, 'Batch size should match the number of gpus'
        args.batch_size = args.batch_size // total_gpus

    args.epochs = cfg.OPTIMIZATION.NUM_EPOCHS if args.epochs is None else args.epochs
    
    common_utils.set_random_seed(666)
    save_path = './save_path/logger/'#/bayes/pointpillar/'+time.strftime('%m%d-%H%M',time.localtime(time.time()))+'/'

    logger = common_utils.create_logger(save_path+'log.txt', rank=cfg.LOCAL_RANK)
    
    print("=============")
    p1 = 0.23
    p2 = 0.77
    p3 = 0.68
    print(p1, p2, p3)
    print("=============")
    

    train_set, train_loader, train_sampler = build_dataloader(
        dataset_cfg=cfg.DATA_CONFIG,
        class_names=cfg.CLASS_NAMES,
        batch_size=args.batch_size,
        dist=dist_train, workers=args.workers,
        logger=logger,
        training=True,
        merge_all_iters_to_one_epoch=args.merge_all_iters_to_one_epoch,
        total_epochs=args.epochs
    )

    model = PointPillar(
        model_cfg=cfg.MODEL, num_class=len(cfg.CLASS_NAMES), p1=p1, p2=p2, p3=p3, dataset=train_set
    )
    
    # model.load_state_dict(torch.load(args.ckpt)['model_state'], strict=False)#['model_state']
    # torch.load('./checkpoint_epoch_33_multinomial.pth')['model_state']
    
    model.cuda()

    optim_cfg = cfg.OPTIMIZATION
    optim_cfg.LR = 0.00001
    optimizer = torch.optim.Adam(model.parameters(), lr=optim_cfg.LR, weight_decay=optim_cfg.WEIGHT_DECAY)

    start_epoch = it = 0
    last_epoch = -1

    model.train()  # before wrap to DistributedDataParallel to support fixed some parameters
    for m in model.modules():
        if isinstance(m, nn.BatchNorm2d):
            m.eval()

    # lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, 20, eta_min=0, last_epoch=-1)
    

#     # -----------------------start training---------------------------
    logger.info('**********************Start training %s/%s(%s)**********************'
                % (cfg.EXP_GROUP_PATH, cfg.TAG, args.extra_tag))
    
    optim_cfg=cfg.OPTIMIZATION
    total_epochs=args.epochs
    rank=cfg.LOCAL_RANK
    
    with tqdm.trange(start_epoch, total_epochs, desc='epochs', dynamic_ncols=True, leave=(rank==0)) as tbar:
        total_it_each_epoch = len(train_loader)
        for cur_epoch in tbar:
            dataloader_iter = iter(train_loader)
            loss_list = []

            for cur_it in range(total_it_each_epoch):
                batch = next(dataloader_iter)
                model.train()
                optimizer.zero_grad()
                
                load_data_to_gpu(batch)
                ret_dict, tb_dict, disp_dict = model(batch)

                loss = ret_dict['loss'].mean()
        
                loss_list.append(loss)
                loss_avg = sum(loss_list) / len(loss_list)

                loss.backward()
                # clip_grad_norm_(model.parameters(), optim_cfg.GRAD_NORM_CLIP)
                
                optimizer.step()
                # lr_scheduler.step()

                print('cur_epoch: {}/{}, cur_it: {}/{}, lr: {:.6}, loss: {:.6}'.format(cur_epoch+1, total_epochs, cur_it+1, total_it_each_epoch, optim_cfg.LR, loss_avg))
                
            logger.info('**********************Start testing**********************')
            test_set, test_loader, sampler = build_dataloader(
                                            dataset_cfg=cfg.DATA_CONFIG,
                                            class_names=cfg.CLASS_NAMES,
                                            batch_size=args.batch_size,
                                            dist=dist_train, workers=args.workers, logger=logger, training=False
                                        )

            acc1, acc2, ret = eval_utils.eval_(cfg, model, test_loader)
            print(acc1, acc2, ret)

            filename = './save_path/0722/ckpt_epoch{}.pth'.format(cur_epoch+1)
            last_filename = filename
            torch.save(model.state_dict(), filename)
        
        
    # filename = './save_path/0722/ckpt_epoch{}.pth'.format(0+1)
    # torch.save(model.state_dict(), filename)        
    
#     logger.info('**********************Start testing %s/%s(%s)**********************'
#                 % (cfg.EXP_GROUP_PATH, cfg.TAG, args.extra_tag))
#     test_set, test_loader, sampler = build_dataloader(
#                                     dataset_cfg=cfg.DATA_CONFIG,
#                                     class_names=cfg.CLASS_NAMES,
#                                     batch_size=args.batch_size,
#                                     dist=dist_train, workers=args.workers, logger=logger, training=False
#                                 )

#     acc1, acc2, ret = eval_utils.eval_(cfg, model, test_loader)
#     print(acc1, ac2, ret)

    # logger.info('----------------Bayes Optimization----------------')
    # Bounded region of parameter space
    # pbounds = {'p1': (0.1, 0.9), 'p2': (0.1, 0.9)}
    

#     optimizer = BayesianOptimization(
#         f=opt_function,
#         pbounds=pbounds,
#         verbose=2,  # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
#         random_state=1,
#     )
#     optimizer.probe(
#         params={'p1': 0.11, 'p2': 0.11},
#         lazy=True,
#     )

#     logger_bayes = JSONLogger(path=save_path+"logs2.json")
#     optimizer.subscribe(Events.OPTIMIZATION_STEP, logger_bayes)
    
    
#     n = 0
#     optimizer.maximize(
#         init_points=3,
#         n_iter=10,
#     )
    print("=======end========")
# Out:
# 2023-07-22 22:04:25,500   INFO  Database filter by min points Car: 14357 => 13532
# 2023-07-22 22:04:25,501   INFO  Database filter by min points Pedestrian: 2207 => 2168
# 2023-07-22 22:04:25,502   INFO  Database filter by min points Cyclist: 734 => 705
# 2023-07-22 22:04:25,517   INFO  Database filter by difficulty Car: 13532 => 10759
# 2023-07-22 22:04:25,519   INFO  Database filter by difficulty Pedestrian: 2168 => 2075
# 2023-07-22 22:04:25,520   INFO  Database filter by difficulty Cyclist: 705 => 581
# 2023-07-22 22:04:25,525   INFO  Loading KITTI dataset
# Using GPU:0
# =============
# 0.23 0.77 0.68
# =============
# 2023-07-22 22:04:25,604   INFO  Total samples for KITTI dataset: 3712
# /home/pai/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2023-07-22 22:04:27,098   INFO  **********************Start training cfgs/kitti_models/pointpillar_bayes(default)**********************
# epochs:   0%|          | 0/800 [00:00<?, ?it/s]
# cur_epoch: 1/800, cur_it: 1/464, lr: 1e-05, loss: 2.99904
# cur_epoch: 1/800, cur_it: 2/464, lr: 1e-05, loss: 2.9739
# cur_epoch: 1/800, cur_it: 3/464, lr: 1e-05, loss: 2.96254
# cur_epoch: 1/800, cur_it: 4/464, lr: 1e-05, loss: 2.95852
# cur_epoch: 1/800, cur_it: 5/464, lr: 1e-05, loss: 2.98015
# cur_epoch: 1/800, cur_it: 6/464, lr: 1e-05, loss: 3.00158
# cur_epoch: 1/800, cur_it: 7/464, lr: 1e-05, loss: 3.00062
# cur_epoch: 1/800, cur_it: 8/464, lr: 1e-05, loss: 2.98449
# cur_epoch: 1/800, cur_it: 9/464, lr: 1e-05, loss: 2.97721
# cur_epoch: 1/800, cur_it: 10/464, lr: 1e-05, loss: 2.95589
# cur_epoch: 1/800, cur_it: 11/464, lr: 1e-05, loss: 2.95109
# cur_epoch: 1/800, cur_it: 12/464, lr: 1e-05, loss: 2.95507
# cur_epoch: 1/800, cur_it: 13/464, lr: 1e-05, loss: 2.94089
# cur_epoch: 1/800, cur_it: 14/464, lr: 1e-05, loss: 2.94122
# cur_epoch: 1/800, cur_it: 15/464, lr: 1e-05, loss: 2.93463
# cur_epoch: 1/800, cur_it: 16/464, lr: 1e-05, loss: 2.9323
# cur_epoch: 1/800, cur_it: 17/464, lr: 1e-05, loss: 2.9307
# cur_epoch: 1/800, cur_it: 18/464, lr: 1e-05, loss: 2.92532
# cur_epoch: 1/800, cur_it: 19/464, lr: 1e-05, loss: 2.92158
# cur_epoch: 1/800, cur_it: 20/464, lr: 1e-05, loss: 2.91868
# cur_epoch: 1/800, cur_it: 21/464, lr: 1e-05, loss: 2.9198
# cur_epoch: 1/800, cur_it: 22/464, lr: 1e-05, loss: 2.91364
# cur_epoch: 1/800, cur_it: 23/464, lr: 1e-05, loss: 2.90231
# cur_epoch: 1/800, cur_it: 24/464, lr: 1e-05, loss: 2.90205
# cur_epoch: 1/800, cur_it: 25/464, lr: 1e-05, loss: 2.90191
# cur_epoch: 1/800, cur_it: 26/464, lr: 1e-05, loss: 2.89847
# cur_epoch: 1/800, cur_it: 27/464, lr: 1e-05, loss: 2.90107
# cur_epoch: 1/800, cur_it: 28/464, lr: 1e-05, loss: 2.8992
# cur_epoch: 1/800, cur_it: 29/464, lr: 1e-05, loss: 2.8978
# cur_epoch: 1/800, cur_it: 30/464, lr: 1e-05, loss: 2.89175
# cur_epoch: 1/800, cur_it: 31/464, lr: 1e-05, loss: 2.88776
# cur_epoch: 1/800, cur_it: 32/464, lr: 1e-05, loss: 2.88683
# cur_epoch: 1/800, cur_it: 33/464, lr: 1e-05, loss: 2.89127
# cur_epoch: 1/800, cur_it: 34/464, lr: 1e-05, loss: 2.89119
# cur_epoch: 1/800, cur_it: 35/464, lr: 1e-05, loss: 2.89277
# cur_epoch: 1/800, cur_it: 36/464, lr: 1e-05, loss: 2.88901
# cur_epoch: 1/800, cur_it: 37/464, lr: 1e-05, loss: 2.89308
# cur_epoch: 1/800, cur_it: 38/464, lr: 1e-05, loss: 2.89087
# cur_epoch: 1/800, cur_it: 39/464, lr: 1e-05, loss: 2.89687
# cur_epoch: 1/800, cur_it: 40/464, lr: 1e-05, loss: 2.90307
# cur_epoch: 1/800, cur_it: 41/464, lr: 1e-05, loss: 2.8996
# cur_epoch: 1/800, cur_it: 42/464, lr: 1e-05, loss: 2.89855
# cur_epoch: 1/800, cur_it: 43/464, lr: 1e-05, loss: 2.90092
# cur_epoch: 1/800, cur_it: 44/464, lr: 1e-05, loss: 2.90165
# cur_epoch: 1/800, cur_it: 45/464, lr: 1e-05, loss: 2.90226
# cur_epoch: 1/800, cur_it: 46/464, lr: 1e-05, loss: 2.90171
# cur_epoch: 1/800, cur_it: 47/464, lr: 1e-05, loss: 2.90478
# cur_epoch: 1/800, cur_it: 48/464, lr: 1e-05, loss: 2.90278
# cur_epoch: 1/800, cur_it: 49/464, lr: 1e-05, loss: 2.91122
# cur_epoch: 1/800, cur_it: 50/464, lr: 1e-05, loss: 2.91401
# cur_epoch: 1/800, cur_it: 51/464, lr: 1e-05, loss: 2.91205
# cur_epoch: 1/800, cur_it: 52/464, lr: 1e-05, loss: 2.90961
# cur_epoch: 1/800, cur_it: 53/464, lr: 1e-05, loss: 2.91074
# cur_epoch: 1/800, cur_it: 54/464, lr: 1e-05, loss: 2.91056
# cur_epoch: 1/800, cur_it: 55/464, lr: 1e-05, loss: 2.91122
# cur_epoch: 1/800, cur_it: 56/464, lr: 1e-05, loss: 2.91076
# cur_epoch: 1/800, cur_it: 57/464, lr: 1e-05, loss: 2.9114
# cur_epoch: 1/800, cur_it: 58/464, lr: 1e-05, loss: 2.90981
# cur_epoch: 1/800, cur_it: 59/464, lr: 1e-05, loss: 2.90887
# cur_epoch: 1/800, cur_it: 60/464, lr: 1e-05, loss: 2.90796
# cur_epoch: 1/800, cur_it: 61/464, lr: 1e-05, loss: 2.91158
# cur_epoch: 1/800, cur_it: 62/464, lr: 1e-05, loss: 2.91338
# cur_epoch: 1/800, cur_it: 63/464, lr: 1e-05, loss: 2.91445
# cur_epoch: 1/800, cur_it: 64/464, lr: 1e-05, loss: 2.91461
# cur_epoch: 1/800, cur_it: 65/464, lr: 1e-05, loss: 2.9154
# cur_epoch: 1/800, cur_it: 66/464, lr: 1e-05, loss: 2.91605
# cur_epoch: 1/800, cur_it: 67/464, lr: 1e-05, loss: 2.91502
# cur_epoch: 1/800, cur_it: 68/464, lr: 1e-05, loss: 2.91441
# cur_epoch: 1/800, cur_it: 69/464, lr: 1e-05, loss: 2.91311
# cur_epoch: 1/800, cur_it: 70/464, lr: 1e-05, loss: 2.91472
# cur_epoch: 1/800, cur_it: 71/464, lr: 1e-05, loss: 2.9143
# cur_epoch: 1/800, cur_it: 72/464, lr: 1e-05, loss: 2.91402
# cur_epoch: 1/800, cur_it: 73/464, lr: 1e-05, loss: 2.91232
# cur_epoch: 1/800, cur_it: 74/464, lr: 1e-05, loss: 2.91028
# cur_epoch: 1/800, cur_it: 75/464, lr: 1e-05, loss: 2.9102
# cur_epoch: 1/800, cur_it: 76/464, lr: 1e-05, loss: 2.91064
# cur_epoch: 1/800, cur_it: 77/464, lr: 1e-05, loss: 2.91224
# cur_epoch: 1/800, cur_it: 78/464, lr: 1e-05, loss: 2.91481
# cur_epoch: 1/800, cur_it: 79/464, lr: 1e-05, loss: 2.9146
# cur_epoch: 1/800, cur_it: 80/464, lr: 1e-05, loss: 2.91413
# cur_epoch: 1/800, cur_it: 81/464, lr: 1e-05, loss: 2.91503
# cur_epoch: 1/800, cur_it: 82/464, lr: 1e-05, loss: 2.91646
# cur_epoch: 1/800, cur_it: 83/464, lr: 1e-05, loss: 2.91684
# cur_epoch: 1/800, cur_it: 84/464, lr: 1e-05, loss: 2.91656
# cur_epoch: 1/800, cur_it: 85/464, lr: 1e-05, loss: 2.91746
# cur_epoch: 1/800, cur_it: 86/464, lr: 1e-05, loss: 2.91652
# cur_epoch: 1/800, cur_it: 87/464, lr: 1e-05, loss: 2.91483
# cur_epoch: 1/800, cur_it: 88/464, lr: 1e-05, loss: 2.91437
# cur_epoch: 1/800, cur_it: 89/464, lr: 1e-05, loss: 2.91443
# cur_epoch: 1/800, cur_it: 90/464, lr: 1e-05, loss: 2.9165
# cur_epoch: 1/800, cur_it: 91/464, lr: 1e-05, loss: 2.91712
# cur_epoch: 1/800, cur_it: 92/464, lr: 1e-05, loss: 2.9186
# cur_epoch: 1/800, cur_it: 93/464, lr: 1e-05, loss: 2.91847
# cur_epoch: 1/800, cur_it: 94/464, lr: 1e-05, loss: 2.91844
# cur_epoch: 1/800, cur_it: 95/464, lr: 1e-05, loss: 2.9179
# cur_epoch: 1/800, cur_it: 96/464, lr: 1e-05, loss: 2.91708
# cur_epoch: 1/800, cur_it: 97/464, lr: 1e-05, loss: 2.91693
# cur_epoch: 1/800, cur_it: 98/464, lr: 1e-05, loss: 2.91634
# cur_epoch: 1/800, cur_it: 99/464, lr: 1e-05, loss: 2.91791
# cur_epoch: 1/800, cur_it: 100/464, lr: 1e-05, loss: 2.91871
# cur_epoch: 1/800, cur_it: 101/464, lr: 1e-05, loss: 2.91922
# cur_epoch: 1/800, cur_it: 102/464, lr: 1e-05, loss: 2.92019
# cur_epoch: 1/800, cur_it: 103/464, lr: 1e-05, loss: 2.92067
# cur_epoch: 1/800, cur_it: 104/464, lr: 1e-05, loss: 2.9197
# cur_epoch: 1/800, cur_it: 105/464, lr: 1e-05, loss: 2.92073
# cur_epoch: 1/800, cur_it: 106/464, lr: 1e-05, loss: 2.92115
# cur_epoch: 1/800, cur_it: 107/464, lr: 1e-05, loss: 2.91965
# cur_epoch: 1/800, cur_it: 108/464, lr: 1e-05, loss: 2.91991
# cur_epoch: 1/800, cur_it: 109/464, lr: 1e-05, loss: 2.92021
# cur_epoch: 1/800, cur_it: 110/464, lr: 1e-05, loss: 2.91983
# cur_epoch: 1/800, cur_it: 111/464, lr: 1e-05, loss: 2.91938
# cur_epoch: 1/800, cur_it: 112/464, lr: 1e-05, loss: 2.91867
# cur_epoch: 1/800, cur_it: 113/464, lr: 1e-05, loss: 2.91882
# cur_epoch: 1/800, cur_it: 114/464, lr: 1e-05, loss: 2.91896
# cur_epoch: 1/800, cur_it: 115/464, lr: 1e-05, loss: 2.9183
# cur_epoch: 1/800, cur_it: 116/464, lr: 1e-05, loss: 2.91774
# cur_epoch: 1/800, cur_it: 117/464, lr: 1e-05, loss: 2.91668
# cur_epoch: 1/800, cur_it: 118/464, lr: 1e-05, loss: 2.91543
# cur_epoch: 1/800, cur_it: 119/464, lr: 1e-05, loss: 2.91581
# cur_epoch: 1/800, cur_it: 120/464, lr: 1e-05, loss: 2.9172
# cur_epoch: 1/800, cur_it: 121/464, lr: 1e-05, loss: 2.91717
# cur_epoch: 1/800, cur_it: 122/464, lr: 1e-05, loss: 2.91696
# cur_epoch: 1/800, cur_it: 123/464, lr: 1e-05, loss: 2.91633
# cur_epoch: 1/800, cur_it: 124/464, lr: 1e-05, loss: 2.91573
# cur_epoch: 1/800, cur_it: 125/464, lr: 1e-05, loss: 2.91609
# cur_epoch: 1/800, cur_it: 126/464, lr: 1e-05, loss: 2.91498
# cur_epoch: 1/800, cur_it: 127/464, lr: 1e-05, loss: 2.91517
# cur_epoch: 1/800, cur_it: 128/464, lr: 1e-05, loss: 2.91523
# cur_epoch: 1/800, cur_it: 129/464, lr: 1e-05, loss: 2.91578
# cur_epoch: 1/800, cur_it: 130/464, lr: 1e-05, loss: 2.91607
# cur_epoch: 1/800, cur_it: 131/464, lr: 1e-05, loss: 2.91678
# cur_epoch: 1/800, cur_it: 132/464, lr: 1e-05, loss: 2.91656
# cur_epoch: 1/800, cur_it: 133/464, lr: 1e-05, loss: 2.91733
# cur_epoch: 1/800, cur_it: 134/464, lr: 1e-05, loss: 2.917
# cur_epoch: 1/800, cur_it: 135/464, lr: 1e-05, loss: 2.91656
# cur_epoch: 1/800, cur_it: 136/464, lr: 1e-05, loss: 2.9158
# cur_epoch: 1/800, cur_it: 137/464, lr: 1e-05, loss: 2.91687
# cur_epoch: 1/800, cur_it: 138/464, lr: 1e-05, loss: 2.9168
# cur_epoch: 1/800, cur_it: 139/464, lr: 1e-05, loss: 2.91707
# cur_epoch: 1/800, cur_it: 140/464, lr: 1e-05, loss: 2.91553
# cur_epoch: 1/800, cur_it: 141/464, lr: 1e-05, loss: 2.91525
# cur_epoch: 1/800, cur_it: 142/464, lr: 1e-05, loss: 2.91402
# cur_epoch: 1/800, cur_it: 143/464, lr: 1e-05, loss: 2.91401
# cur_epoch: 1/800, cur_it: 144/464, lr: 1e-05, loss: 2.91478
# cur_epoch: 1/800, cur_it: 145/464, lr: 1e-05, loss: 2.91345
# cur_epoch: 1/800, cur_it: 146/464, lr: 1e-05, loss: 2.91269
# cur_epoch: 1/800, cur_it: 147/464, lr: 1e-05, loss: 2.91263
# cur_epoch: 1/800, cur_it: 148/464, lr: 1e-05, loss: 2.9135
# cur_epoch: 1/800, cur_it: 149/464, lr: 1e-05, loss: 2.91455
# cur_epoch: 1/800, cur_it: 150/464, lr: 1e-05, loss: 2.91349
# cur_epoch: 1/800, cur_it: 151/464, lr: 1e-05, loss: 2.91318
# cur_epoch: 1/800, cur_it: 152/464, lr: 1e-05, loss: 2.91266
# cur_epoch: 1/800, cur_it: 153/464, lr: 1e-05, loss: 2.91215
# cur_epoch: 1/800, cur_it: 154/464, lr: 1e-05, loss: 2.90995
# cur_epoch: 1/800, cur_it: 155/464, lr: 1e-05, loss: 2.90903
# cur_epoch: 1/800, cur_it: 156/464, lr: 1e-05, loss: 2.91076
# cur_epoch: 1/800, cur_it: 157/464, lr: 1e-05, loss: 2.91036
# cur_epoch: 1/800, cur_it: 158/464, lr: 1e-05, loss: 2.90978
# cur_epoch: 1/800, cur_it: 159/464, lr: 1e-05, loss: 2.90893
# cur_epoch: 1/800, cur_it: 160/464, lr: 1e-05, loss: 2.90813
# cur_epoch: 1/800, cur_it: 161/464, lr: 1e-05, loss: 2.90841
# cur_epoch: 1/800, cur_it: 162/464, lr: 1e-05, loss: 2.90711
# cur_epoch: 1/800, cur_it: 163/464, lr: 1e-05, loss: 2.90645
# cur_epoch: 1/800, cur_it: 164/464, lr: 1e-05, loss: 2.90636
# cur_epoch: 1/800, cur_it: 165/464, lr: 1e-05, loss: 2.90694
# cur_epoch: 1/800, cur_it: 166/464, lr: 1e-05, loss: 2.90624
# cur_epoch: 1/800, cur_it: 167/464, lr: 1e-05, loss: 2.90536
# cur_epoch: 1/800, cur_it: 168/464, lr: 1e-05, loss: 2.90454
# cur_epoch: 1/800, cur_it: 169/464, lr: 1e-05, loss: 2.90428
# cur_epoch: 1/800, cur_it: 170/464, lr: 1e-05, loss: 2.90447
# cur_epoch: 1/800, cur_it: 171/464, lr: 1e-05, loss: 2.9041
# cur_epoch: 1/800, cur_it: 172/464, lr: 1e-05, loss: 2.90446
# cur_epoch: 1/800, cur_it: 173/464, lr: 1e-05, loss: 2.90359
# cur_epoch: 1/800, cur_it: 174/464, lr: 1e-05, loss: 2.90411
# cur_epoch: 1/800, cur_it: 175/464, lr: 1e-05, loss: 2.90318
# cur_epoch: 1/800, cur_it: 176/464, lr: 1e-05, loss: 2.9023
# cur_epoch: 1/800, cur_it: 177/464, lr: 1e-05, loss: 2.90229
# cur_epoch: 1/800, cur_it: 178/464, lr: 1e-05, loss: 2.90129
# cur_epoch: 1/800, cur_it: 179/464, lr: 1e-05, loss: 2.90147
# cur_epoch: 1/800, cur_it: 180/464, lr: 1e-05, loss: 2.90091
# cur_epoch: 1/800, cur_it: 181/464, lr: 1e-05, loss: 2.90024
# cur_epoch: 1/800, cur_it: 182/464, lr: 1e-05, loss: 2.90005
# cur_epoch: 1/800, cur_it: 183/464, lr: 1e-05, loss: 2.90002
# cur_epoch: 1/800, cur_it: 184/464, lr: 1e-05, loss: 2.90009
# cur_epoch: 1/800, cur_it: 185/464, lr: 1e-05, loss: 2.90021
# cur_epoch: 1/800, cur_it: 186/464, lr: 1e-05, loss: 2.89936
# cur_epoch: 1/800, cur_it: 187/464, lr: 1e-05, loss: 2.89848
# cur_epoch: 1/800, cur_it: 188/464, lr: 1e-05, loss: 2.89874
# cur_epoch: 1/800, cur_it: 189/464, lr: 1e-05, loss: 2.89869
# cur_epoch: 1/800, cur_it: 190/464, lr: 1e-05, loss: 2.89821
# cur_epoch: 1/800, cur_it: 191/464, lr: 1e-05, loss: 2.89674
# cur_epoch: 1/800, cur_it: 192/464, lr: 1e-05, loss: 2.89536
# cur_epoch: 1/800, cur_it: 193/464, lr: 1e-05, loss: 2.89552
# cur_epoch: 1/800, cur_it: 194/464, lr: 1e-05, loss: 2.89606
# cur_epoch: 1/800, cur_it: 195/464, lr: 1e-05, loss: 2.89641
# cur_epoch: 1/800, cur_it: 196/464, lr: 1e-05, loss: 2.89607
# cur_epoch: 1/800, cur_it: 197/464, lr: 1e-05, loss: 2.89584
# cur_epoch: 1/800, cur_it: 198/464, lr: 1e-05, loss: 2.89437
# cur_epoch: 1/800, cur_it: 199/464, lr: 1e-05, loss: 2.89451
# cur_epoch: 1/800, cur_it: 200/464, lr: 1e-05, loss: 2.89386
# cur_epoch: 1/800, cur_it: 201/464, lr: 1e-05, loss: 2.89276
# cur_epoch: 1/800, cur_it: 202/464, lr: 1e-05, loss: 2.89199
# cur_epoch: 1/800, cur_it: 203/464, lr: 1e-05, loss: 2.89159
# cur_epoch: 1/800, cur_it: 204/464, lr: 1e-05, loss: 2.89176
# cur_epoch: 1/800, cur_it: 205/464, lr: 1e-05, loss: 2.89209
# cur_epoch: 1/800, cur_it: 206/464, lr: 1e-05, loss: 2.89227
# cur_epoch: 1/800, cur_it: 207/464, lr: 1e-05, loss: 2.89188
# cur_epoch: 1/800, cur_it: 208/464, lr: 1e-05, loss: 2.89119
# cur_epoch: 1/800, cur_it: 209/464, lr: 1e-05, loss: 2.89101
# cur_epoch: 1/800, cur_it: 210/464, lr: 1e-05, loss: 2.89064
# cur_epoch: 1/800, cur_it: 211/464, lr: 1e-05, loss: 2.88972
# cur_epoch: 1/800, cur_it: 212/464, lr: 1e-05, loss: 2.89003
# cur_epoch: 1/800, cur_it: 213/464, lr: 1e-05, loss: 2.88946
# cur_epoch: 1/800, cur_it: 214/464, lr: 1e-05, loss: 2.8887
# cur_epoch: 1/800, cur_it: 215/464, lr: 1e-05, loss: 2.88778
# cur_epoch: 1/800, cur_it: 216/464, lr: 1e-05, loss: 2.88685
# cur_epoch: 1/800, cur_it: 217/464, lr: 1e-05, loss: 2.88704
# cur_epoch: 1/800, cur_it: 218/464, lr: 1e-05, loss: 2.88723
# cur_epoch: 1/800, cur_it: 219/464, lr: 1e-05, loss: 2.88761
# cur_epoch: 1/800, cur_it: 220/464, lr: 1e-05, loss: 2.88796
# cur_epoch: 1/800, cur_it: 221/464, lr: 1e-05, loss: 2.88792
# cur_epoch: 1/800, cur_it: 222/464, lr: 1e-05, loss: 2.88811
# cur_epoch: 1/800, cur_it: 223/464, lr: 1e-05, loss: 2.88813
# cur_epoch: 1/800, cur_it: 224/464, lr: 1e-05, loss: 2.8879
# cur_epoch: 1/800, cur_it: 225/464, lr: 1e-05, loss: 2.88756
# cur_epoch: 1/800, cur_it: 226/464, lr: 1e-05, loss: 2.88727
# cur_epoch: 1/800, cur_it: 227/464, lr: 1e-05, loss: 2.88677
# cur_epoch: 1/800, cur_it: 228/464, lr: 1e-05, loss: 2.887
# cur_epoch: 1/800, cur_it: 229/464, lr: 1e-05, loss: 2.88689
# cur_epoch: 1/800, cur_it: 230/464, lr: 1e-05, loss: 2.88643
# cur_epoch: 1/800, cur_it: 231/464, lr: 1e-05, loss: 2.88599
# cur_epoch: 1/800, cur_it: 232/464, lr: 1e-05, loss: 2.88641
# cur_epoch: 1/800, cur_it: 233/464, lr: 1e-05, loss: 2.88644
# cur_epoch: 1/800, cur_it: 234/464, lr: 1e-05, loss: 2.88591
# cur_epoch: 1/800, cur_it: 235/464, lr: 1e-05, loss: 2.8853
# cur_epoch: 1/800, cur_it: 236/464, lr: 1e-05, loss: 2.8858
# cur_epoch: 1/800, cur_it: 237/464, lr: 1e-05, loss: 2.88531
# cur_epoch: 1/800, cur_it: 238/464, lr: 1e-05, loss: 2.88494
# cur_epoch: 1/800, cur_it: 239/464, lr: 1e-05, loss: 2.88423
# cur_epoch: 1/800, cur_it: 240/464, lr: 1e-05, loss: 2.88446
# cur_epoch: 1/800, cur_it: 241/464, lr: 1e-05, loss: 2.88429
# cur_epoch: 1/800, cur_it: 242/464, lr: 1e-05, loss: 2.88417
# cur_epoch: 1/800, cur_it: 243/464, lr: 1e-05, loss: 2.88414
# cur_epoch: 1/800, cur_it: 244/464, lr: 1e-05, loss: 2.88381
# cur_epoch: 1/800, cur_it: 245/464, lr: 1e-05, loss: 2.88302
# cur_epoch: 1/800, cur_it: 246/464, lr: 1e-05, loss: 2.88326
# cur_epoch: 1/800, cur_it: 247/464, lr: 1e-05, loss: 2.8817
# cur_epoch: 1/800, cur_it: 248/464, lr: 1e-05, loss: 2.88128
# cur_epoch: 1/800, cur_it: 249/464, lr: 1e-05, loss: 2.88112
# cur_epoch: 1/800, cur_it: 250/464, lr: 1e-05, loss: 2.88059
# cur_epoch: 1/800, cur_it: 251/464, lr: 1e-05, loss: 2.88017
# cur_epoch: 1/800, cur_it: 252/464, lr: 1e-05, loss: 2.8794
# cur_epoch: 1/800, cur_it: 253/464, lr: 1e-05, loss: 2.87887
# cur_epoch: 1/800, cur_it: 254/464, lr: 1e-05, loss: 2.87863
# cur_epoch: 1/800, cur_it: 255/464, lr: 1e-05, loss: 2.87809
# cur_epoch: 1/800, cur_it: 256/464, lr: 1e-05, loss: 2.87726
# cur_epoch: 1/800, cur_it: 257/464, lr: 1e-05, loss: 2.8765
# cur_epoch: 1/800, cur_it: 258/464, lr: 1e-05, loss: 2.8765
# cur_epoch: 1/800, cur_it: 259/464, lr: 1e-05, loss: 2.87551
# cur_epoch: 1/800, cur_it: 260/464, lr: 1e-05, loss: 2.87533
# cur_epoch: 1/800, cur_it: 261/464, lr: 1e-05, loss: 2.87471
# cur_epoch: 1/800, cur_it: 262/464, lr: 1e-05, loss: 2.87495
# cur_epoch: 1/800, cur_it: 263/464, lr: 1e-05, loss: 2.87468
# cur_epoch: 1/800, cur_it: 264/464, lr: 1e-05, loss: 2.87432
# cur_epoch: 1/800, cur_it: 265/464, lr: 1e-05, loss: 2.87396
# cur_epoch: 1/800, cur_it: 266/464, lr: 1e-05, loss: 2.87309
# cur_epoch: 1/800, cur_it: 267/464, lr: 1e-05, loss: 2.87245
# cur_epoch: 1/800, cur_it: 268/464, lr: 1e-05, loss: 2.87197
# cur_epoch: 1/800, cur_it: 269/464, lr: 1e-05, loss: 2.87098
# cur_epoch: 1/800, cur_it: 270/464, lr: 1e-05, loss: 2.87058
# cur_epoch: 1/800, cur_it: 271/464, lr: 1e-05, loss: 2.87123
# cur_epoch: 1/800, cur_it: 272/464, lr: 1e-05, loss: 2.87093
# cur_epoch: 1/800, cur_it: 273/464, lr: 1e-05, loss: 2.87084
# cur_epoch: 1/800, cur_it: 274/464, lr: 1e-05, loss: 2.87059
# cur_epoch: 1/800, cur_it: 275/464, lr: 1e-05, loss: 2.8706
# cur_epoch: 1/800, cur_it: 276/464, lr: 1e-05, loss: 2.87051
# cur_epoch: 1/800, cur_it: 277/464, lr: 1e-05, loss: 2.86997
# cur_epoch: 1/800, cur_it: 278/464, lr: 1e-05, loss: 2.86971
# cur_epoch: 1/800, cur_it: 279/464, lr: 1e-05, loss: 2.86915
# cur_epoch: 1/800, cur_it: 280/464, lr: 1e-05, loss: 2.86834
# cur_epoch: 1/800, cur_it: 281/464, lr: 1e-05, loss: 2.86784
# cur_epoch: 1/800, cur_it: 282/464, lr: 1e-05, loss: 2.86767
# cur_epoch: 1/800, cur_it: 283/464, lr: 1e-05, loss: 2.86693
# cur_epoch: 1/800, cur_it: 284/464, lr: 1e-05, loss: 2.86673
# cur_epoch: 1/800, cur_it: 285/464, lr: 1e-05, loss: 2.86676
# cur_epoch: 1/800, cur_it: 286/464, lr: 1e-05, loss: 2.86643
# cur_epoch: 1/800, cur_it: 287/464, lr: 1e-05, loss: 2.8661
# cur_epoch: 1/800, cur_it: 288/464, lr: 1e-05, loss: 2.86579
# cur_epoch: 1/800, cur_it: 289/464, lr: 1e-05, loss: 2.86607
# cur_epoch: 1/800, cur_it: 290/464, lr: 1e-05, loss: 2.86491
# cur_epoch: 1/800, cur_it: 291/464, lr: 1e-05, loss: 2.86438
# cur_epoch: 1/800, cur_it: 292/464, lr: 1e-05, loss: 2.86364
# cur_epoch: 1/800, cur_it: 293/464, lr: 1e-05, loss: 2.86334
# cur_epoch: 1/800, cur_it: 294/464, lr: 1e-05, loss: 2.86312
# cur_epoch: 1/800, cur_it: 295/464, lr: 1e-05, loss: 2.86286
# cur_epoch: 1/800, cur_it: 296/464, lr: 1e-05, loss: 2.86321
# cur_epoch: 1/800, cur_it: 297/464, lr: 1e-05, loss: 2.86261
# cur_epoch: 1/800, cur_it: 298/464, lr: 1e-05, loss: 2.86195
# cur_epoch: 1/800, cur_it: 299/464, lr: 1e-05, loss: 2.86158
# cur_epoch: 1/800, cur_it: 300/464, lr: 1e-05, loss: 2.86131
# cur_epoch: 1/800, cur_it: 301/464, lr: 1e-05, loss: 2.86074
# cur_epoch: 1/800, cur_it: 302/464, lr: 1e-05, loss: 2.86047
# cur_epoch: 1/800, cur_it: 303/464, lr: 1e-05, loss: 2.86012
# cur_epoch: 1/800, cur_it: 304/464, lr: 1e-05, loss: 2.85969
# cur_epoch: 1/800, cur_it: 305/464, lr: 1e-05, loss: 2.85918
# cur_epoch: 1/800, cur_it: 306/464, lr: 1e-05, loss: 2.85845
# cur_epoch: 1/800, cur_it: 307/464, lr: 1e-05, loss: 2.85831
# cur_epoch: 1/800, cur_it: 308/464, lr: 1e-05, loss: 2.85784
# cur_epoch: 1/800, cur_it: 309/464, lr: 1e-05, loss: 2.85743
# cur_epoch: 1/800, cur_it: 310/464, lr: 1e-05, loss: 2.85665
# cur_epoch: 1/800, cur_it: 311/464, lr: 1e-05, loss: 2.85635
# cur_epoch: 1/800, cur_it: 312/464, lr: 1e-05, loss: 2.85624
# cur_epoch: 1/800, cur_it: 313/464, lr: 1e-05, loss: 2.85593
# cur_epoch: 1/800, cur_it: 314/464, lr: 1e-05, loss: 2.8554
# cur_epoch: 1/800, cur_it: 315/464, lr: 1e-05, loss: 2.85523
# cur_epoch: 1/800, cur_it: 316/464, lr: 1e-05, loss: 2.85493
# cur_epoch: 1/800, cur_it: 317/464, lr: 1e-05, loss: 2.85473
# cur_epoch: 1/800, cur_it: 318/464, lr: 1e-05, loss: 2.85366
# cur_epoch: 1/800, cur_it: 319/464, lr: 1e-05, loss: 2.85335
# cur_epoch: 1/800, cur_it: 320/464, lr: 1e-05, loss: 2.85281
# cur_epoch: 1/800, cur_it: 321/464, lr: 1e-05, loss: 2.85259
# cur_epoch: 1/800, cur_it: 322/464, lr: 1e-05, loss: 2.85256
# cur_epoch: 1/800, cur_it: 323/464, lr: 1e-05, loss: 2.85258
# cur_epoch: 1/800, cur_it: 324/464, lr: 1e-05, loss: 2.85326
# cur_epoch: 1/800, cur_it: 325/464, lr: 1e-05, loss: 2.85268
# cur_epoch: 1/800, cur_it: 326/464, lr: 1e-05, loss: 2.85181
# cur_epoch: 1/800, cur_it: 327/464, lr: 1e-05, loss: 2.85136
# cur_epoch: 1/800, cur_it: 328/464, lr: 1e-05, loss: 2.85086
# cur_epoch: 1/800, cur_it: 329/464, lr: 1e-05, loss: 2.85012
# cur_epoch: 1/800, cur_it: 330/464, lr: 1e-05, loss: 2.85015
# cur_epoch: 1/800, cur_it: 331/464, lr: 1e-05, loss: 2.85435
# cur_epoch: 1/800, cur_it: 332/464, lr: 1e-05, loss: 2.85352
# cur_epoch: 1/800, cur_it: 333/464, lr: 1e-05, loss: 2.85333
# cur_epoch: 1/800, cur_it: 334/464, lr: 1e-05, loss: 2.85302
# cur_epoch: 1/800, cur_it: 335/464, lr: 1e-05, loss: 2.85347
# cur_epoch: 1/800, cur_it: 336/464, lr: 1e-05, loss: 2.85272
# cur_epoch: 1/800, cur_it: 337/464, lr: 1e-05, loss: 2.85203
# cur_epoch: 1/800, cur_it: 338/464, lr: 1e-05, loss: 2.85146
# cur_epoch: 1/800, cur_it: 339/464, lr: 1e-05, loss: 2.85154
# cur_epoch: 1/800, cur_it: 340/464, lr: 1e-05, loss: 2.85581
# cur_epoch: 1/800, cur_it: 341/464, lr: 1e-05, loss: 2.85555
# cur_epoch: 1/800, cur_it: 342/464, lr: 1e-05, loss: 2.85491
# cur_epoch: 1/800, cur_it: 343/464, lr: 1e-05, loss: 2.85437
# cur_epoch: 1/800, cur_it: 344/464, lr: 1e-05, loss: 2.85411
# cur_epoch: 1/800, cur_it: 345/464, lr: 1e-05, loss: 2.85361
# cur_epoch: 1/800, cur_it: 346/464, lr: 1e-05, loss: 2.85312
# cur_epoch: 1/800, cur_it: 347/464, lr: 1e-05, loss: 2.85278
# cur_epoch: 1/800, cur_it: 348/464, lr: 1e-05, loss: 2.85211
# cur_epoch: 1/800, cur_it: 349/464, lr: 1e-05, loss: 2.85178
# cur_epoch: 1/800, cur_it: 350/464, lr: 1e-05, loss: 2.85166
# cur_epoch: 1/800, cur_it: 351/464, lr: 1e-05, loss: 2.85186
# cur_epoch: 1/800, cur_it: 352/464, lr: 1e-05, loss: 2.851
# cur_epoch: 1/800, cur_it: 353/464, lr: 1e-05, loss: 2.85097
# cur_epoch: 1/800, cur_it: 354/464, lr: 1e-05, loss: 2.85023
# cur_epoch: 1/800, cur_it: 355/464, lr: 1e-05, loss: 2.8497
# cur_epoch: 1/800, cur_it: 356/464, lr: 1e-05, loss: 2.84971
# cur_epoch: 1/800, cur_it: 357/464, lr: 1e-05, loss: 2.84947
# cur_epoch: 1/800, cur_it: 358/464, lr: 1e-05, loss: 2.84892
# cur_epoch: 1/800, cur_it: 359/464, lr: 1e-05, loss: 2.84796
# cur_epoch: 1/800, cur_it: 360/464, lr: 1e-05, loss: 2.84734
# cur_epoch: 1/800, cur_it: 361/464, lr: 1e-05, loss: 2.84709
# cur_epoch: 1/800, cur_it: 362/464, lr: 1e-05, loss: 2.84687
# cur_epoch: 1/800, cur_it: 363/464, lr: 1e-05, loss: 2.8461
# cur_epoch: 1/800, cur_it: 364/464, lr: 1e-05, loss: 2.84561
# cur_epoch: 1/800, cur_it: 365/464, lr: 1e-05, loss: 2.84555
# cur_epoch: 1/800, cur_it: 366/464, lr: 1e-05, loss: 2.84583
# cur_epoch: 1/800, cur_it: 367/464, lr: 1e-05, loss: 2.84503
# cur_epoch: 1/800, cur_it: 368/464, lr: 1e-05, loss: 2.84476
# cur_epoch: 1/800, cur_it: 369/464, lr: 1e-05, loss: 2.84475
# cur_epoch: 1/800, cur_it: 370/464, lr: 1e-05, loss: 2.84448
# cur_epoch: 1/800, cur_it: 371/464, lr: 1e-05, loss: 2.84546
# cur_epoch: 1/800, cur_it: 372/464, lr: 1e-05, loss: 2.84474
# cur_epoch: 1/800, cur_it: 373/464, lr: 1e-05, loss: 2.84411
# cur_epoch: 1/800, cur_it: 374/464, lr: 1e-05, loss: 2.8439
# cur_epoch: 1/800, cur_it: 375/464, lr: 1e-05, loss: 2.84356
# cur_epoch: 1/800, cur_it: 376/464, lr: 1e-05, loss: 2.84312
# cur_epoch: 1/800, cur_it: 377/464, lr: 1e-05, loss: 2.84252
# cur_epoch: 1/800, cur_it: 378/464, lr: 1e-05, loss: 2.8421
# cur_epoch: 1/800, cur_it: 379/464, lr: 1e-05, loss: 2.84134
# cur_epoch: 1/800, cur_it: 380/464, lr: 1e-05, loss: 2.84107
# cur_epoch: 1/800, cur_it: 381/464, lr: 1e-05, loss: 2.84012
# cur_epoch: 1/800, cur_it: 382/464, lr: 1e-05, loss: 2.83957
# cur_epoch: 1/800, cur_it: 383/464, lr: 1e-05, loss: 2.83932
# cur_epoch: 1/800, cur_it: 384/464, lr: 1e-05, loss: 2.83836
# cur_epoch: 1/800, cur_it: 385/464, lr: 1e-05, loss: 2.83872
# cur_epoch: 1/800, cur_it: 386/464, lr: 1e-05, loss: 2.83789
# cur_epoch: 1/800, cur_it: 387/464, lr: 1e-05, loss: 2.83667
# cur_epoch: 1/800, cur_it: 388/464, lr: 1e-05, loss: 2.83587
# cur_epoch: 1/800, cur_it: 389/464, lr: 1e-05, loss: 2.83528
# cur_epoch: 1/800, cur_it: 390/464, lr: 1e-05, loss: 2.83519
# cur_epoch: 1/800, cur_it: 391/464, lr: 1e-05, loss: 2.8346
# cur_epoch: 1/800, cur_it: 392/464, lr: 1e-05, loss: 2.83396
# cur_epoch: 1/800, cur_it: 393/464, lr: 1e-05, loss: 2.8339
# cur_epoch: 1/800, cur_it: 394/464, lr: 1e-05, loss: 2.83351
# cur_epoch: 1/800, cur_it: 395/464, lr: 1e-05, loss: 2.83274
# cur_epoch: 1/800, cur_it: 396/464, lr: 1e-05, loss: 2.83218
# cur_epoch: 1/800, cur_it: 397/464, lr: 1e-05, loss: 2.83207
# cur_epoch: 1/800, cur_it: 398/464, lr: 1e-05, loss: 2.83152
# cur_epoch: 1/800, cur_it: 399/464, lr: 1e-05, loss: 2.83152
# cur_epoch: 1/800, cur_it: 400/464, lr: 1e-05, loss: 2.83103
# cur_epoch: 1/800, cur_it: 401/464, lr: 1e-05, loss: 2.831
# cur_epoch: 1/800, cur_it: 402/464, lr: 1e-05, loss: 2.83097
# cur_epoch: 1/800, cur_it: 403/464, lr: 1e-05, loss: 2.83069
# cur_epoch: 1/800, cur_it: 404/464, lr: 1e-05, loss: 2.8301
# cur_epoch: 1/800, cur_it: 405/464, lr: 1e-05, loss: 2.82936
# cur_epoch: 1/800, cur_it: 406/464, lr: 1e-05, loss: 2.82921
# cur_epoch: 1/800, cur_it: 407/464, lr: 1e-05, loss: 2.82895
# cur_epoch: 1/800, cur_it: 408/464, lr: 1e-05, loss: 2.82816
# cur_epoch: 1/800, cur_it: 409/464, lr: 1e-05, loss: 2.82747
# cur_epoch: 1/800, cur_it: 410/464, lr: 1e-05, loss: 2.82706
# cur_epoch: 1/800, cur_it: 411/464, lr: 1e-05, loss: 2.82668
# cur_epoch: 1/800, cur_it: 412/464, lr: 1e-05, loss: 2.82668
# cur_epoch: 1/800, cur_it: 413/464, lr: 1e-05, loss: 2.82594
# cur_epoch: 1/800, cur_it: 414/464, lr: 1e-05, loss: 2.8253
# cur_epoch: 1/800, cur_it: 415/464, lr: 1e-05, loss: 2.825
# cur_epoch: 1/800, cur_it: 416/464, lr: 1e-05, loss: 2.82485
# cur_epoch: 1/800, cur_it: 417/464, lr: 1e-05, loss: 2.82617
# cur_epoch: 1/800, cur_it: 418/464, lr: 1e-05, loss: 2.82567
# cur_epoch: 1/800, cur_it: 419/464, lr: 1e-05, loss: 2.82499
# cur_epoch: 1/800, cur_it: 420/464, lr: 1e-05, loss: 2.82425
# cur_epoch: 1/800, cur_it: 421/464, lr: 1e-05, loss: 2.82444
# cur_epoch: 1/800, cur_it: 422/464, lr: 1e-05, loss: 2.82364
# cur_epoch: 1/800, cur_it: 423/464, lr: 1e-05, loss: 2.82298
# cur_epoch: 1/800, cur_it: 424/464, lr: 1e-05, loss: 2.82254
# cur_epoch: 1/800, cur_it: 425/464, lr: 1e-05, loss: 2.8223
# cur_epoch: 1/800, cur_it: 426/464, lr: 1e-05, loss: 2.82176
# cur_epoch: 1/800, cur_it: 427/464, lr: 1e-05, loss: 2.82056
# cur_epoch: 1/800, cur_it: 428/464, lr: 1e-05, loss: 2.81976
# cur_epoch: 1/800, cur_it: 429/464, lr: 1e-05, loss: 2.82019
# cur_epoch: 1/800, cur_it: 430/464, lr: 1e-05, loss: 2.81967
# cur_epoch: 1/800, cur_it: 431/464, lr: 1e-05, loss: 2.81923
# cur_epoch: 1/800, cur_it: 432/464, lr: 1e-05, loss: 2.81851
# cur_epoch: 1/800, cur_it: 433/464, lr: 1e-05, loss: 2.81795
# cur_epoch: 1/800, cur_it: 434/464, lr: 1e-05, loss: 2.81742
# cur_epoch: 1/800, cur_it: 435/464, lr: 1e-05, loss: 2.8172
# cur_epoch: 1/800, cur_it: 436/464, lr: 1e-05, loss: 2.81651
# cur_epoch: 1/800, cur_it: 437/464, lr: 1e-05, loss: 2.81663
# cur_epoch: 1/800, cur_it: 438/464, lr: 1e-05, loss: 2.81663
# cur_epoch: 1/800, cur_it: 439/464, lr: 1e-05, loss: 2.81586
# cur_epoch: 1/800, cur_it: 440/464, lr: 1e-05, loss: 2.81546
# cur_epoch: 1/800, cur_it: 441/464, lr: 1e-05, loss: 2.81503
# cur_epoch: 1/800, cur_it: 442/464, lr: 1e-05, loss: 2.81464
# cur_epoch: 1/800, cur_it: 443/464, lr: 1e-05, loss: 2.81446
# cur_epoch: 1/800, cur_it: 444/464, lr: 1e-05, loss: 2.81391
# cur_epoch: 1/800, cur_it: 445/464, lr: 1e-05, loss: 2.81298
# cur_epoch: 1/800, cur_it: 446/464, lr: 1e-05, loss: 2.81276
# cur_epoch: 1/800, cur_it: 447/464, lr: 1e-05, loss: 2.8119
# cur_epoch: 1/800, cur_it: 448/464, lr: 1e-05, loss: 2.8113
# cur_epoch: 1/800, cur_it: 449/464, lr: 1e-05, loss: 2.8109
# cur_epoch: 1/800, cur_it: 450/464, lr: 1e-05, loss: 2.81054
# cur_epoch: 1/800, cur_it: 451/464, lr: 1e-05, loss: 2.81004
# cur_epoch: 1/800, cur_it: 452/464, lr: 1e-05, loss: 2.80963
# cur_epoch: 1/800, cur_it: 453/464, lr: 1e-05, loss: 2.80917
# cur_epoch: 1/800, cur_it: 454/464, lr: 1e-05, loss: 2.80857
# cur_epoch: 1/800, cur_it: 455/464, lr: 1e-05, loss: 2.80777
# cur_epoch: 1/800, cur_it: 456/464, lr: 1e-05, loss: 2.80697
# cur_epoch: 1/800, cur_it: 457/464, lr: 1e-05, loss: 2.80642
# cur_epoch: 1/800, cur_it: 458/464, lr: 1e-05, loss: 2.80651
# cur_epoch: 1/800, cur_it: 459/464, lr: 1e-05, loss: 2.80609
# cur_epoch: 1/800, cur_it: 460/464, lr: 1e-05, loss: 2.8058
# cur_epoch: 1/800, cur_it: 461/464, lr: 1e-05, loss: 2.80509
# cur_epoch: 1/800, cur_it: 462/464, lr: 1e-05, loss: 2.8047
# cur_epoch: 1/800, cur_it: 463/464, lr: 1e-05, loss: 2.80411
# 2023-07-22 22:07:50,735   INFO  **********************Start testing**********************
# 2023-07-22 22:07:50,738   INFO  Loading KITTI dataset
# 2023-07-22 22:07:50,833   INFO  Total samples for KITTI dataset: 3769
# cur_epoch: 1/800, cur_it: 464/464, lr: 1e-05, loss: 2.80347
# Average predicted number of objects(3769 samples): 0.000
# /home/pai/lib/python3.9/site-packages/numba/core/typed_passes.py:329: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see https://numba.readthedocs.io/en/stable/user/parallel.html#diagnostics for help.
#
# File "../pcdet/datasets/kitti/kitti_object_eval_python/eval.py", line 122:
# @numba.jit(nopython=True, parallel=True)
# def d3_box_overlap_kernel(boxes, qboxes, rinc, criterion=-1):
# ^
#
#   warnings.warn(errors.NumbaPerformanceWarning(msg,
# epochs:   0%|          | 1/800 [04:54<65:17:55, 294.21s/it]
# 0.0 0.0 {'recall/roi_0.3': 0.0, 'recall/rcnn_0.3': 0.0, 'recall/roi_0.5': 0.0, 'recall/rcnn_0.5': 0.0, 'recall/roi_0.7': 0.0, 'recall/rcnn_0.7': 0.0, 'Car_3d/easy_R40': 0.0, 'Car_3d/moderate_R40': 0.0, 'Car_3d/hard_R40': 0.0, 'Car_bev/easy_R40': 0.0, 'Car_bev/moderate_R40': 0.0, 'Car_bev/hard_R40': 0.0, 'Car_image/easy_R40': 0.0, 'Car_image/moderate_R40': 0.0, 'Car_image/hard_R40': 0.0, 'Pedestrian_3d/easy_R40': 0.0, 'Pedestrian_3d/moderate_R40': 0.0, 'Pedestrian_3d/hard_R40': 0.0, 'Pedestrian_bev/easy_R40': 0.0, 'Pedestrian_bev/moderate_R40': 0.0, 'Pedestrian_bev/hard_R40': 0.0, 'Pedestrian_image/easy_R40': 0.0, 'Pedestrian_image/moderate_R40': 0.0, 'Pedestrian_image/hard_R40': 0.0, 'Cyclist_3d/easy_R40': 0.0, 'Cyclist_3d/moderate_R40': 0.0, 'Cyclist_3d/hard_R40': 0.0, 'Cyclist_bev/easy_R40': 0.0, 'Cyclist_bev/moderate_R40': 0.0, 'Cyclist_bev/hard_R40': 0.0, 'Cyclist_image/easy_R40': 0.0, 'Cyclist_image/moderate_R40': 0.0, 'Cyclist_image/hard_R40': 0.0}
# cur_epoch: 2/800, cur_it: 1/464, lr: 1e-05, loss: 2.65601
# cur_epoch: 2/800, cur_it: 2/464, lr: 1e-05, loss: 2.61083
# cur_epoch: 2/800, cur_it: 3/464, lr: 1e-05, loss: 2.66714
# cur_epoch: 2/800, cur_it: 4/464, lr: 1e-05, loss: 2.64145
# cur_epoch: 2/800, cur_it: 5/464, lr: 1e-05, loss: 2.62648
# cur_epoch: 2/800, cur_it: 6/464, lr: 1e-05, loss: 2.64373
# cur_epoch: 2/800, cur_it: 7/464, lr: 1e-05, loss: 2.65312
# cur_epoch: 2/800, cur_it: 8/464, lr: 1e-05, loss: 2.65824
# cur_epoch: 2/800, cur_it: 9/464, lr: 1e-05, loss: 2.6548
# cur_epoch: 2/800, cur_it: 10/464, lr: 1e-05, loss: 2.64282
# cur_epoch: 2/800, cur_it: 11/464, lr: 1e-05, loss: 2.64604
# cur_epoch: 2/800, cur_it: 12/464, lr: 1e-05, loss: 2.64289
# cur_epoch: 2/800, cur_it: 13/464, lr: 1e-05, loss: 2.62612
# cur_epoch: 2/800, cur_it: 14/464, lr: 1e-05, loss: 2.63774
# cur_epoch: 2/800, cur_it: 15/464, lr: 1e-05, loss: 2.64175
# cur_epoch: 2/800, cur_it: 16/464, lr: 1e-05, loss: 2.62946
# cur_epoch: 2/800, cur_it: 17/464, lr: 1e-05, loss: 2.63054
# cur_epoch: 2/800, cur_it: 18/464, lr: 1e-05, loss: 2.62958
# cur_epoch: 2/800, cur_it: 19/464, lr: 1e-05, loss: 2.63038
# cur_epoch: 2/800, cur_it: 20/464, lr: 1e-05, loss: 2.63117
# cur_epoch: 2/800, cur_it: 21/464, lr: 1e-05, loss: 2.62573
# cur_epoch: 2/800, cur_it: 22/464, lr: 1e-05, loss: 2.63061
# cur_epoch: 2/800, cur_it: 23/464, lr: 1e-05, loss: 2.62196
# cur_epoch: 2/800, cur_it: 24/464, lr: 1e-05, loss: 2.63161
# cur_epoch: 2/800, cur_it: 25/464, lr: 1e-05, loss: 2.62585
# cur_epoch: 2/800, cur_it: 26/464, lr: 1e-05, loss: 2.62461
# cur_epoch: 2/800, cur_it: 27/464, lr: 1e-05, loss: 2.61792
# cur_epoch: 2/800, cur_it: 28/464, lr: 1e-05, loss: 2.61321
# cur_epoch: 2/800, cur_it: 29/464, lr: 1e-05, loss: 2.61169
# cur_epoch: 2/800, cur_it: 30/464, lr: 1e-05, loss: 2.61294
# cur_epoch: 2/800, cur_it: 31/464, lr: 1e-05, loss: 2.60538
# cur_epoch: 2/800, cur_it: 32/464, lr: 1e-05, loss: 2.60554
# cur_epoch: 2/800, cur_it: 33/464, lr: 1e-05, loss: 2.60183
# cur_epoch: 2/800, cur_it: 34/464, lr: 1e-05, loss: 2.71426
# cur_epoch: 2/800, cur_it: 35/464, lr: 1e-05, loss: 2.7168
# cur_epoch: 2/800, cur_it: 36/464, lr: 1e-05, loss: 2.70818
# cur_epoch: 2/800, cur_it: 37/464, lr: 1e-05, loss: 2.70768
# cur_epoch: 2/800, cur_it: 38/464, lr: 1e-05, loss: 2.70313
# cur_epoch: 2/800, cur_it: 39/464, lr: 1e-05, loss: 2.7033
# cur_epoch: 2/800, cur_it: 40/464, lr: 1e-05, loss: 2.69993
# cur_epoch: 2/800, cur_it: 41/464, lr: 1e-05, loss: 2.69797
# cur_epoch: 2/800, cur_it: 42/464, lr: 1e-05, loss: 2.69446
# cur_epoch: 2/800, cur_it: 43/464, lr: 1e-05, loss: 2.69223
# cur_epoch: 2/800, cur_it: 44/464, lr: 1e-05, loss: 2.68426
# cur_epoch: 2/800, cur_it: 45/464, lr: 1e-05, loss: 2.68417
# cur_epoch: 2/800, cur_it: 46/464, lr: 1e-05, loss: 2.67874
# cur_epoch: 2/800, cur_it: 47/464, lr: 1e-05, loss: 2.68513
# cur_epoch: 2/800, cur_it: 48/464, lr: 1e-05, loss: 2.67985
# cur_epoch: 2/800, cur_it: 49/464, lr: 1e-05, loss: 2.67805
# cur_epoch: 2/800, cur_it: 50/464, lr: 1e-05, loss: 2.67734
# cur_epoch: 2/800, cur_it: 51/464, lr: 1e-05, loss: 2.67596
# cur_epoch: 2/800, cur_it: 52/464, lr: 1e-05, loss: 2.67646
# cur_epoch: 2/800, cur_it: 53/464, lr: 1e-05, loss: 2.67531
# cur_epoch: 2/800, cur_it: 54/464, lr: 1e-05, loss: 2.67263
# cur_epoch: 2/800, cur_it: 55/464, lr: 1e-05, loss: 2.6735
# cur_epoch: 2/800, cur_it: 56/464, lr: 1e-05, loss: 2.67283
# cur_epoch: 2/800, cur_it: 57/464, lr: 1e-05, loss: 2.67119
# cur_epoch: 2/800, cur_it: 58/464, lr: 1e-05, loss: 2.66871
# cur_epoch: 2/800, cur_it: 59/464, lr: 1e-05, loss: 2.66697
# cur_epoch: 2/800, cur_it: 60/464, lr: 1e-05, loss: 2.66807
# cur_epoch: 2/800, cur_it: 61/464, lr: 1e-05, loss: 2.67022
# cur_epoch: 2/800, cur_it: 62/464, lr: 1e-05, loss: 2.66828
# cur_epoch: 2/800, cur_it: 63/464, lr: 1e-05, loss: 2.66522
# cur_epoch: 2/800, cur_it: 64/464, lr: 1e-05, loss: 2.66384
# cur_epoch: 2/800, cur_it: 65/464, lr: 1e-05, loss: 2.66379
# cur_epoch: 2/800, cur_it: 66/464, lr: 1e-05, loss: 2.66209
# cur_epoch: 2/800, cur_it: 67/464, lr: 1e-05, loss: 2.66799
# cur_epoch: 2/800, cur_it: 68/464, lr: 1e-05, loss: 2.66832
# cur_epoch: 2/800, cur_it: 69/464, lr: 1e-05, loss: 2.67394
# cur_epoch: 2/800, cur_it: 70/464, lr: 1e-05, loss: 2.67525
# cur_epoch: 2/800, cur_it: 71/464, lr: 1e-05, loss: 2.67722
# cur_epoch: 2/800, cur_it: 72/464, lr: 1e-05, loss: 2.684
# cur_epoch: 2/800, cur_it: 73/464, lr: 1e-05, loss: 2.68214
# cur_epoch: 2/800, cur_it: 74/464, lr: 1e-05, loss: 2.68207
# cur_epoch: 2/800, cur_it: 75/464, lr: 1e-05, loss: 2.68122
# cur_epoch: 2/800, cur_it: 76/464, lr: 1e-05, loss: 2.68008
# cur_epoch: 2/800, cur_it: 77/464, lr: 1e-05, loss: 2.67662
# cur_epoch: 2/800, cur_it: 78/464, lr: 1e-05, loss: 2.67447
# cur_epoch: 2/800, cur_it: 79/464, lr: 1e-05, loss: 2.67534
# cur_epoch: 2/800, cur_it: 80/464, lr: 1e-05, loss: 2.67371
# cur_epoch: 2/800, cur_it: 81/464, lr: 1e-05, loss: 2.67718
# cur_epoch: 2/800, cur_it: 82/464, lr: 1e-05, loss: 2.6782
# cur_epoch: 2/800, cur_it: 83/464, lr: 1e-05, loss: 2.67701
# cur_epoch: 2/800, cur_it: 84/464, lr: 1e-05, loss: 2.68761
# cur_epoch: 2/800, cur_it: 85/464, lr: 1e-05, loss: 2.68634
# cur_epoch: 2/800, cur_it: 86/464, lr: 1e-05, loss: 2.6833
# cur_epoch: 2/800, cur_it: 87/464, lr: 1e-05, loss: 2.68327
# cur_epoch: 2/800, cur_it: 88/464, lr: 1e-05, loss: 2.68313
# cur_epoch: 2/800, cur_it: 89/464, lr: 1e-05, loss: 2.68344
# cur_epoch: 2/800, cur_it: 90/464, lr: 1e-05, loss: 2.68317
# cur_epoch: 2/800, cur_it: 91/464, lr: 1e-05, loss: 2.68244
# cur_epoch: 2/800, cur_it: 92/464, lr: 1e-05, loss: 2.68177
# cur_epoch: 2/800, cur_it: 93/464, lr: 1e-05, loss: 2.68136
# cur_epoch: 2/800, cur_it: 94/464, lr: 1e-05, loss: 2.68188
# cur_epoch: 2/800, cur_it: 95/464, lr: 1e-05, loss: 2.68132
# cur_epoch: 2/800, cur_it: 96/464, lr: 1e-05, loss: 2.68088
# cur_epoch: 2/800, cur_it: 97/464, lr: 1e-05, loss: 2.67928
# cur_epoch: 2/800, cur_it: 98/464, lr: 1e-05, loss: 2.67976
# cur_epoch: 2/800, cur_it: 99/464, lr: 1e-05, loss: 2.6777
# cur_epoch: 2/800, cur_it: 100/464, lr: 1e-05, loss: 2.67645
# cur_epoch: 2/800, cur_it: 101/464, lr: 1e-05, loss: 2.67411
# cur_epoch: 2/800, cur_it: 102/464, lr: 1e-05, loss: 2.67223
# cur_epoch: 2/800, cur_it: 103/464, lr: 1e-05, loss: 2.68121
# cur_epoch: 2/800, cur_it: 104/464, lr: 1e-05, loss: 2.69316
# cur_epoch: 2/800, cur_it: 105/464, lr: 1e-05, loss: 2.69179
# cur_epoch: 2/800, cur_it: 106/464, lr: 1e-05, loss: 2.69116
# cur_epoch: 2/800, cur_it: 107/464, lr: 1e-05, loss: 2.69297
# cur_epoch: 2/800, cur_it: 108/464, lr: 1e-05, loss: 2.69147
# cur_epoch: 2/800, cur_it: 109/464, lr: 1e-05, loss: 2.69034
# cur_epoch: 2/800, cur_it: 110/464, lr: 1e-05, loss: 2.68983
# cur_epoch: 2/800, cur_it: 111/464, lr: 1e-05, loss: 2.69051
# cur_epoch: 2/800, cur_it: 112/464, lr: 1e-05, loss: 2.69109
# cur_epoch: 2/800, cur_it: 113/464, lr: 1e-05, loss: 2.69111
# cur_epoch: 2/800, cur_it: 114/464, lr: 1e-05, loss: 2.6893
# cur_epoch: 2/800, cur_it: 115/464, lr: 1e-05, loss: 2.68831
# cur_epoch: 2/800, cur_it: 116/464, lr: 1e-05, loss: 2.68836
# cur_epoch: 2/800, cur_it: 117/464, lr: 1e-05, loss: 2.68812
# cur_epoch: 2/800, cur_it: 118/464, lr: 1e-05, loss: 2.68731
# cur_epoch: 2/800, cur_it: 119/464, lr: 1e-05, loss: 2.68665
# cur_epoch: 2/800, cur_it: 120/464, lr: 1e-05, loss: 2.68798
# cur_epoch: 2/800, cur_it: 121/464, lr: 1e-05, loss: 2.68733
# cur_epoch: 2/800, cur_it: 122/464, lr: 1e-05, loss: 2.68732
# cur_epoch: 2/800, cur_it: 123/464, lr: 1e-05, loss: 2.68691
# cur_epoch: 2/800, cur_it: 124/464, lr: 1e-05, loss: 2.6873
# cur_epoch: 2/800, cur_it: 125/464, lr: 1e-05, loss: 2.68689
# cur_epoch: 2/800, cur_it: 126/464, lr: 1e-05, loss: 2.68613
# cur_epoch: 2/800, cur_it: 127/464, lr: 1e-05, loss: 2.6856
# cur_epoch: 2/800, cur_it: 128/464, lr: 1e-05, loss: 2.6867
# cur_epoch: 2/800, cur_it: 129/464, lr: 1e-05, loss: 2.68505
# cur_epoch: 2/800, cur_it: 130/464, lr: 1e-05, loss: 2.68398
# cur_epoch: 2/800, cur_it: 131/464, lr: 1e-05, loss: 2.68367
# cur_epoch: 2/800, cur_it: 132/464, lr: 1e-05, loss: 2.68263
# cur_epoch: 2/800, cur_it: 133/464, lr: 1e-05, loss: 2.68115
# cur_epoch: 2/800, cur_it: 134/464, lr: 1e-05, loss: 2.67985
# cur_epoch: 2/800, cur_it: 135/464, lr: 1e-05, loss: 2.67911
# cur_epoch: 2/800, cur_it: 137/464, lr: 1e-05, loss: 2.6774
# cur_epoch: 2/800, cur_it: 138/464, lr: 1e-05, loss: 2.67922
# cur_epoch: 2/800, cur_it: 139/464, lr: 1e-05, loss: 2.67931
# cur_epoch: 2/800, cur_it: 140/464, lr: 1e-05, loss: 2.67896
# cur_epoch: 2/800, cur_it: 141/464, lr: 1e-05, loss: 2.67855
# cur_epoch: 2/800, cur_it: 142/464, lr: 1e-05, loss: 2.6772
# cur_epoch: 2/800, cur_it: 143/464, lr: 1e-05, loss: 2.67704
# cur_epoch: 2/800, cur_it: 144/464, lr: 1e-05, loss: 2.67677
# cur_epoch: 2/800, cur_it: 145/464, lr: 1e-05, loss: 2.67651
# cur_epoch: 2/800, cur_it: 146/464, lr: 1e-05, loss: 2.67512
# cur_epoch: 2/800, cur_it: 147/464, lr: 1e-05, loss: 2.67538
# cur_epoch: 2/800, cur_it: 148/464, lr: 1e-05, loss: 2.67652
# cur_epoch: 2/800, cur_it: 149/464, lr: 1e-05, loss: 2.67503
# cur_epoch: 2/800, cur_it: 150/464, lr: 1e-05, loss: 2.67426
# cur_epoch: 2/800, cur_it: 151/464, lr: 1e-05, loss: 2.67458
# cur_epoch: 2/800, cur_it: 152/464, lr: 1e-05, loss: 2.67425
# cur_epoch: 2/800, cur_it: 153/464, lr: 1e-05, loss: 2.67393
# cur_epoch: 2/800, cur_it: 154/464, lr: 1e-05, loss: 2.67348
# cur_epoch: 2/800, cur_it: 155/464, lr: 1e-05, loss: 2.67146
# cur_epoch: 2/800, cur_it: 156/464, lr: 1e-05, loss: 2.67093
# cur_epoch: 2/800, cur_it: 157/464, lr: 1e-05, loss: 2.67054
# cur_epoch: 2/800, cur_it: 158/464, lr: 1e-05, loss: 2.67099
# cur_epoch: 2/800, cur_it: 159/464, lr: 1e-05, loss: 2.67045
# cur_epoch: 2/800, cur_it: 160/464, lr: 1e-05, loss: 2.67515
# cur_epoch: 2/800, cur_it: 161/464, lr: 1e-05, loss: 2.67453
# cur_epoch: 2/800, cur_it: 162/464, lr: 1e-05, loss: 2.67392
# cur_epoch: 2/800, cur_it: 163/464, lr: 1e-05, loss: 2.67396
# cur_epoch: 2/800, cur_it: 164/464, lr: 1e-05, loss: 2.67436
# cur_epoch: 2/800, cur_it: 165/464, lr: 1e-05, loss: 2.67424
# cur_epoch: 2/800, cur_it: 166/464, lr: 1e-05, loss: 2.67383
# cur_epoch: 2/800, cur_it: 167/464, lr: 1e-05, loss: 2.67304
# cur_epoch: 2/800, cur_it: 168/464, lr: 1e-05, loss: 2.67226
# cur_epoch: 2/800, cur_it: 169/464, lr: 1e-05, loss: 2.67175
# cur_epoch: 2/800, cur_it: 170/464, lr: 1e-05, loss: 2.67111
# cur_epoch: 2/800, cur_it: 171/464, lr: 1e-05, loss: 2.67055
# cur_epoch: 2/800, cur_it: 172/464, lr: 1e-05, loss: 2.67049
# cur_epoch: 2/800, cur_it: 173/464, lr: 1e-05, loss: 2.67019
# cur_epoch: 2/800, cur_it: 174/464, lr: 1e-05, loss: 2.66976
# cur_epoch: 2/800, cur_it: 175/464, lr: 1e-05, loss: 2.66904
# cur_epoch: 2/800, cur_it: 176/464, lr: 1e-05, loss: 2.66963
# cur_epoch: 2/800, cur_it: 177/464, lr: 1e-05, loss: 2.6693
# cur_epoch: 2/800, cur_it: 178/464, lr: 1e-05, loss: 2.67011
# cur_epoch: 2/800, cur_it: 179/464, lr: 1e-05, loss: 2.66971
# cur_epoch: 2/800, cur_it: 180/464, lr: 1e-05, loss: 2.66934
# cur_epoch: 2/800, cur_it: 181/464, lr: 1e-05, loss: 2.66868
# cur_epoch: 2/800, cur_it: 182/464, lr: 1e-05, loss: 2.66826
# cur_epoch: 2/800, cur_it: 183/464, lr: 1e-05, loss: 2.66795
# cur_epoch: 2/800, cur_it: 184/464, lr: 1e-05, loss: 2.6673
# cur_epoch: 2/800, cur_it: 185/464, lr: 1e-05, loss: 2.66743
# cur_epoch: 2/800, cur_it: 186/464, lr: 1e-05, loss: 2.66726
# cur_epoch: 2/800, cur_it: 187/464, lr: 1e-05, loss: 2.66629
# cur_epoch: 2/800, cur_it: 188/464, lr: 1e-05, loss: 2.66442
# cur_epoch: 2/800, cur_it: 189/464, lr: 1e-05, loss: 2.66396
# cur_epoch: 2/800, cur_it: 190/464, lr: 1e-05, loss: 2.66488
# cur_epoch: 2/800, cur_it: 191/464, lr: 1e-05, loss: 2.66509
# cur_epoch: 2/800, cur_it: 192/464, lr: 1e-05, loss: 2.66423
# cur_epoch: 2/800, cur_it: 193/464, lr: 1e-05, loss: 2.66355
# cur_epoch: 2/800, cur_it: 194/464, lr: 1e-05, loss: 2.66363
# cur_epoch: 2/800, cur_it: 195/464, lr: 1e-05, loss: 2.66387
# cur_epoch: 2/800, cur_it: 196/464, lr: 1e-05, loss: 2.66303
# cur_epoch: 2/800, cur_it: 197/464, lr: 1e-05, loss: 2.66279
# cur_epoch: 2/800, cur_it: 198/464, lr: 1e-05, loss: 2.66232
# cur_epoch: 2/800, cur_it: 199/464, lr: 1e-05, loss: 2.66196
# cur_epoch: 2/800, cur_it: 200/464, lr: 1e-05, loss: 2.66127
# cur_epoch: 2/800, cur_it: 201/464, lr: 1e-05, loss: 2.66095
# cur_epoch: 2/800, cur_it: 202/464, lr: 1e-05, loss: 2.66039
# cur_epoch: 2/800, cur_it: 203/464, lr: 1e-05, loss: 2.65887
# cur_epoch: 2/800, cur_it: 204/464, lr: 1e-05, loss: 2.65816
# cur_epoch: 2/800, cur_it: 205/464, lr: 1e-05, loss: 2.65812
# cur_epoch: 2/800, cur_it: 206/464, lr: 1e-05, loss: 2.65723
# cur_epoch: 2/800, cur_it: 207/464, lr: 1e-05, loss: 2.65697
# cur_epoch: 2/800, cur_it: 208/464, lr: 1e-05, loss: 2.65709
# cur_epoch: 2/800, cur_it: 209/464, lr: 1e-05, loss: 2.65773
# cur_epoch: 2/800, cur_it: 210/464, lr: 1e-05, loss: 2.65647
# cur_epoch: 2/800, cur_it: 211/464, lr: 1e-05, loss: 2.65596
# cur_epoch: 2/800, cur_it: 212/464, lr: 1e-05, loss: 2.65562
# cur_epoch: 2/800, cur_it: 213/464, lr: 1e-05, loss: 2.65487
# cur_epoch: 2/800, cur_it: 214/464, lr: 1e-05, loss: 2.65534
# cur_epoch: 2/800, cur_it: 215/464, lr: 1e-05, loss: 2.65548
# cur_epoch: 2/800, cur_it: 216/464, lr: 1e-05, loss: 2.654
# cur_epoch: 2/800, cur_it: 217/464, lr: 1e-05, loss: 2.65293
# cur_epoch: 2/800, cur_it: 218/464, lr: 1e-05, loss: 2.65331
# cur_epoch: 2/800, cur_it: 219/464, lr: 1e-05, loss: 2.65288
# cur_epoch: 2/800, cur_it: 220/464, lr: 1e-05, loss: 2.65267
# cur_epoch: 2/800, cur_it: 221/464, lr: 1e-05, loss: 2.65292
# cur_epoch: 2/800, cur_it: 222/464, lr: 1e-05, loss: 2.65315
# cur_epoch: 2/800, cur_it: 223/464, lr: 1e-05, loss: 2.65386
# cur_epoch: 2/800, cur_it: 224/464, lr: 1e-05, loss: 2.65393
# cur_epoch: 2/800, cur_it: 225/464, lr: 1e-05, loss: 2.65381
# cur_epoch: 2/800, cur_it: 226/464, lr: 1e-05, loss: 2.65336
# cur_epoch: 2/800, cur_it: 227/464, lr: 1e-05, loss: 2.65299
# cur_epoch: 2/800, cur_it: 228/464, lr: 1e-05, loss: 2.65294
# cur_epoch: 2/800, cur_it: 229/464, lr: 1e-05, loss: 2.65593
# cur_epoch: 2/800, cur_it: 230/464, lr: 1e-05, loss: 2.65566
# cur_epoch: 2/800, cur_it: 231/464, lr: 1e-05, loss: 2.65554
# cur_epoch: 2/800, cur_it: 232/464, lr: 1e-05, loss: 2.65567
# cur_epoch: 2/800, cur_it: 233/464, lr: 1e-05, loss: 2.6556
# cur_epoch: 2/800, cur_it: 234/464, lr: 1e-05, loss: 2.65619
# cur_epoch: 2/800, cur_it: 235/464, lr: 1e-05, loss: 2.65997
# cur_epoch: 2/800, cur_it: 236/464, lr: 1e-05, loss: 2.65983
# cur_epoch: 2/800, cur_it: 237/464, lr: 1e-05, loss: 2.6599
# cur_epoch: 2/800, cur_it: 238/464, lr: 1e-05, loss: 2.6596
# cur_epoch: 2/800, cur_it: 239/464, lr: 1e-05, loss: 2.65847
# cur_epoch: 2/800, cur_it: 240/464, lr: 1e-05, loss: 2.65872
# cur_epoch: 2/800, cur_it: 241/464, lr: 1e-05, loss: 2.65832
# cur_epoch: 2/800, cur_it: 242/464, lr: 1e-05, loss: 2.6575
# cur_epoch: 2/800, cur_it: 243/464, lr: 1e-05, loss: 2.65732
# cur_epoch: 2/800, cur_it: 244/464, lr: 1e-05, loss: 2.65642
# cur_epoch: 2/800, cur_it: 245/464, lr: 1e-05, loss: 2.6559
# cur_epoch: 2/800, cur_it: 246/464, lr: 1e-05, loss: 2.65541
# cur_epoch: 2/800, cur_it: 247/464, lr: 1e-05, loss: 2.6552
# cur_epoch: 2/800, cur_it: 248/464, lr: 1e-05, loss: 2.65448
# cur_epoch: 2/800, cur_it: 249/464, lr: 1e-05, loss: 2.65438
# cur_epoch: 2/800, cur_it: 250/464, lr: 1e-05, loss: 2.65366
# cur_epoch: 2/800, cur_it: 251/464, lr: 1e-05, loss: 2.65358
# cur_epoch: 2/800, cur_it: 252/464, lr: 1e-05, loss: 2.65402
# cur_epoch: 2/800, cur_it: 253/464, lr: 1e-05, loss: 2.65347
# cur_epoch: 2/800, cur_it: 254/464, lr: 1e-05, loss: 2.65316
# cur_epoch: 2/800, cur_it: 255/464, lr: 1e-05, loss: 2.65382
# cur_epoch: 2/800, cur_it: 256/464, lr: 1e-05, loss: 2.65358
# cur_epoch: 2/800, cur_it: 257/464, lr: 1e-05, loss: 2.65282
# cur_epoch: 2/800, cur_it: 258/464, lr: 1e-05, loss: 2.65313
# cur_epoch: 2/800, cur_it: 259/464, lr: 1e-05, loss: 2.65357
# cur_epoch: 2/800, cur_it: 260/464, lr: 1e-05, loss: 2.65252
# cur_epoch: 2/800, cur_it: 261/464, lr: 1e-05, loss: 2.65266
# cur_epoch: 2/800, cur_it: 262/464, lr: 1e-05, loss: 2.65206
# cur_epoch: 2/800, cur_it: 263/464, lr: 1e-05, loss: 2.65213
# cur_epoch: 2/800, cur_it: 264/464, lr: 1e-05, loss: 2.65191
# cur_epoch: 2/800, cur_it: 265/464, lr: 1e-05, loss: 2.65134
# cur_epoch: 2/800, cur_it: 266/464, lr: 1e-05, loss: 2.65045
# cur_epoch: 2/800, cur_it: 267/464, lr: 1e-05, loss: 2.64992
# cur_epoch: 2/800, cur_it: 268/464, lr: 1e-05, loss: 2.64966
# cur_epoch: 2/800, cur_it: 269/464, lr: 1e-05, loss: 2.64941
# cur_epoch: 2/800, cur_it: 270/464, lr: 1e-05, loss: 2.64904
# cur_epoch: 2/800, cur_it: 271/464, lr: 1e-05, loss: 2.64879
# cur_epoch: 2/800, cur_it: 272/464, lr: 1e-05, loss: 2.64799
# cur_epoch: 2/800, cur_it: 273/464, lr: 1e-05, loss: 2.64802
# cur_epoch: 2/800, cur_it: 274/464, lr: 1e-05, loss: 2.6476
# cur_epoch: 2/800, cur_it: 275/464, lr: 1e-05, loss: 2.64802
# cur_epoch: 2/800, cur_it: 276/464, lr: 1e-05, loss: 2.64861
# cur_epoch: 2/800, cur_it: 277/464, lr: 1e-05, loss: 2.64953
# cur_epoch: 2/800, cur_it: 278/464, lr: 1e-05, loss: 2.64959
# cur_epoch: 2/800, cur_it: 279/464, lr: 1e-05, loss: 2.64951
# cur_epoch: 2/800, cur_it: 280/464, lr: 1e-05, loss: 2.64892
# cur_epoch: 2/800, cur_it: 281/464, lr: 1e-05, loss: 2.64806
# cur_epoch: 2/800, cur_it: 282/464, lr: 1e-05, loss: 2.64727
# cur_epoch: 2/800, cur_it: 283/464, lr: 1e-05, loss: 2.64692
# cur_epoch: 2/800, cur_it: 284/464, lr: 1e-05, loss: 2.64722
# cur_epoch: 2/800, cur_it: 285/464, lr: 1e-05, loss: 2.6466
# cur_epoch: 2/800, cur_it: 286/464, lr: 1e-05, loss: 2.64649
# cur_epoch: 2/800, cur_it: 287/464, lr: 1e-05, loss: 2.64723
# cur_epoch: 2/800, cur_it: 288/464, lr: 1e-05, loss: 2.64706
# cur_epoch: 2/800, cur_it: 289/464, lr: 1e-05, loss: 2.64681
# cur_epoch: 2/800, cur_it: 290/464, lr: 1e-05, loss: 2.64601
# cur_epoch: 2/800, cur_it: 291/464, lr: 1e-05, loss: 2.64532
# ...
# cur_epoch: 6/800, cur_it: 104/464, lr: 1e-05, loss: 2.52063
# cur_epoch: 6/800, cur_it: 105/464, lr: 1e-05, loss: 2.52105
# cur_epoch: 6/800, cur_it: 106/464, lr: 1e-05, loss: 2.52069
# cur_epoch: 6/800, cur_it: 107/464, lr: 1e-05, loss: 2.52019
# cur_epoch: 6/800, cur_it: 108/464, lr: 1e-05, loss: 2.52105
# cur_epoch: 6/800, cur_it: 109/464, lr: 1e-05, loss: 2.52003
# cur_epoch: 6/800, cur_it: 110/464, lr: 1e-05, loss: 2.51955
# cur_epoch: 6/800, cur_it: 111/464, lr: 1e-05, loss: 2.51884
# cur_epoch: 6/800, cur_it: 112/464, lr: 1e-05, loss: 2.51889
# cur_epoch: 6/800, cur_it: 113/464, lr: 1e-05, loss: 2.51893
# cur_epoch: 6/800, cur_it: 114/464, lr: 1e-05, loss: 2.51784
# cur_epoch: 6/800, cur_it: 115/464, lr: 1e-05, loss: 2.51636
# cur_epoch: 6/800, cur_it: 116/464, lr: 1e-05, loss: 2.51727
# cur_epoch: 6/800, cur_it: 117/464, lr: 1e-05, loss: 2.5166
# cur_epoch: 6/800, cur_it: 118/464, lr: 1e-05, loss: 2.51648
# cur_epoch: 6/800, cur_it: 119/464, lr: 1e-05, loss: 2.51543
# cur_epoch: 6/800, cur_it: 120/464, lr: 1e-05, loss: 2.51643
# cur_epoch: 6/800, cur_it: 121/464, lr: 1e-05, loss: 2.51712
# cur_epoch: 6/800, cur_it: 122/464, lr: 1e-05, loss: 2.51723
# cur_epoch: 6/800, cur_it: 123/464, lr: 1e-05, loss: 2.51688
# cur_epoch: 6/800, cur_it: 124/464, lr: 1e-05, loss: 2.51724
# cur_epoch: 6/800, cur_it: 125/464, lr: 1e-05, loss: 2.51595
# cur_epoch: 6/800, cur_it: 126/464, lr: 1e-05, loss: 2.5157
# cur_epoch: 6/800, cur_it: 127/464, lr: 1e-05, loss: 2.51532
# cur_epoch: 6/800, cur_it: 128/464, lr: 1e-05, loss: 2.51588
# cur_epoch: 6/800, cur_it: 129/464, lr: 1e-05, loss: 2.51564
# cur_epoch: 6/800, cur_it: 130/464, lr: 1e-05, loss: 2.51359
# cur_epoch: 6/800, cur_it: 131/464, lr: 1e-05, loss: 2.51517
# cur_epoch: 6/800, cur_it: 132/464, lr: 1e-05, loss: 2.51594
# cur_epoch: 6/800, cur_it: 133/464, lr: 1e-05, loss: 2.51579
# cur_epoch: 6/800, cur_it: 134/464, lr: 1e-05, loss: 2.5164
# cur_epoch: 6/800, cur_it: 135/464, lr: 1e-05, loss: 2.51799
# cur_epoch: 6/800, cur_it: 136/464, lr: 1e-05, loss: 2.51617
# cur_epoch: 6/800, cur_it: 137/464, lr: 1e-05, loss: 2.51776
# cur_epoch: 6/800, cur_it: 138/464, lr: 1e-05, loss: 2.51634
# cur_epoch: 6/800, cur_it: 139/464, lr: 1e-05, loss: 2.51765
# cur_epoch: 6/800, cur_it: 140/464, lr: 1e-05, loss: 2.51767
# cur_epoch: 6/800, cur_it: 141/464, lr: 1e-05, loss: 2.51886
# cur_epoch: 6/800, cur_it: 142/464, lr: 1e-05, loss: 2.52047
# cur_epoch: 6/800, cur_it: 143/464, lr: 1e-05, loss: 2.52049
# cur_epoch: 6/800, cur_it: 144/464, lr: 1e-05, loss: 2.52066
# cur_epoch: 6/800, cur_it: 145/464, lr: 1e-05, loss: 2.52145
# cur_epoch: 6/800, cur_it: 146/464, lr: 1e-05, loss: 2.52
# cur_epoch: 6/800, cur_it: 147/464, lr: 1e-05, loss: 2.52193
# cur_epoch: 6/800, cur_it: 148/464, lr: 1e-05, loss: 2.52227
# cur_epoch: 6/800, cur_it: 149/464, lr: 1e-05, loss: 2.52252
# cur_epoch: 6/800, cur_it: 150/464, lr: 1e-05, loss: 2.52256
# cur_epoch: 6/800, cur_it: 151/464, lr: 1e-05, loss: 2.52386
# cur_epoch: 6/800, cur_it: 152/464, lr: 1e-05, loss: 2.52414
# cur_epoch: 6/800, cur_it: 153/464, lr: 1e-05, loss: 2.52401
# cur_epoch: 6/800, cur_it: 154/464, lr: 1e-05, loss: 2.52341
# cur_epoch: 6/800, cur_it: 155/464, lr: 1e-05, loss: 2.5226
# cur_epoch: 6/800, cur_it: 156/464, lr: 1e-05, loss: 2.52288
# cur_epoch: 6/800, cur_it: 157/464, lr: 1e-05, loss: 2.52172
# cur_epoch: 6/800, cur_it: 158/464, lr: 1e-05, loss: 2.52151
# cur_epoch: 6/800, cur_it: 159/464, lr: 1e-05, loss: 2.52192
# cur_epoch: 6/800, cur_it: 160/464, lr: 1e-05, loss: 2.52217
# cur_epoch: 6/800, cur_it: 161/464, lr: 1e-05, loss: 2.52283
# cur_epoch: 6/800, cur_it: 162/464, lr: 1e-05, loss: 2.52147
# cur_epoch: 6/800, cur_it: 163/464, lr: 1e-05, loss: 2.52175
# cur_epoch: 6/800, cur_it: 164/464, lr: 1e-05, loss: 2.52218
# cur_epoch: 6/800, cur_it: 165/464, lr: 1e-05, loss: 2.52218
# cur_epoch: 6/800, cur_it: 166/464, lr: 1e-05, loss: 2.52154
# cur_epoch: 6/800, cur_it: 167/464, lr: 1e-05, loss: 2.52102
# cur_epoch: 6/800, cur_it: 168/464, lr: 1e-05, loss: 2.52132
# cur_epoch: 6/800, cur_it: 169/464, lr: 1e-05, loss: 2.52084
# cur_epoch: 6/800, cur_it: 170/464, lr: 1e-05, loss: 2.52058
# cur_epoch: 6/800, cur_it: 171/464, lr: 1e-05, loss: 2.5205
# cur_epoch: 6/800, cur_it: 172/464, lr: 1e-05, loss: 2.51991
# cur_epoch: 6/800, cur_it: 173/464, lr: 1e-05, loss: 2.51887
# cur_epoch: 6/800, cur_it: 174/464, lr: 1e-05, loss: 2.52008
# cur_epoch: 6/800, cur_it: 175/464, lr: 1e-05, loss: 2.51886
# cur_epoch: 6/800, cur_it: 176/464, lr: 1e-05, loss: 2.51887
# cur_epoch: 6/800, cur_it: 177/464, lr: 1e-05, loss: 2.51838
# cur_epoch: 6/800, cur_it: 178/464, lr: 1e-05, loss: 2.51896
# cur_epoch: 6/800, cur_it: 179/464, lr: 1e-05, loss: 2.51835
# cur_epoch: 6/800, cur_it: 180/464, lr: 1e-05, loss: 2.51822
# cur_epoch: 6/800, cur_it: 181/464, lr: 1e-05, loss: 2.51708
# cur_epoch: 6/800, cur_it: 182/464, lr: 1e-05, loss: 2.51599
# cur_epoch: 6/800, cur_it: 183/464, lr: 1e-05, loss: 2.51633
# cur_epoch: 6/800, cur_it: 184/464, lr: 1e-05, loss: 2.51681
# cur_epoch: 6/800, cur_it: 185/464, lr: 1e-05, loss: 2.5164
# cur_epoch: 6/800, cur_it: 186/464, lr: 1e-05, loss: 2.51612
# cur_epoch: 6/800, cur_it: 187/464, lr: 1e-05, loss: 2.51711
# cur_epoch: 6/800, cur_it: 188/464, lr: 1e-05, loss: 2.51697
# cur_epoch: 6/800, cur_it: 189/464, lr: 1e-05, loss: 2.51723
# cur_epoch: 6/800, cur_it: 190/464, lr: 1e-05, loss: 2.51687
# cur_epoch: 6/800, cur_it: 191/464, lr: 1e-05, loss: 2.51642
# cur_epoch: 6/800, cur_it: 192/464, lr: 1e-05, loss: 2.51627
# cur_epoch: 6/800, cur_it: 193/464, lr: 1e-05, loss: 2.51583
# cur_epoch: 6/800, cur_it: 194/464, lr: 1e-05, loss: 2.51573
# cur_epoch: 6/800, cur_it: 195/464, lr: 1e-05, loss: 2.51542
# cur_epoch: 6/800, cur_it: 196/464, lr: 1e-05, loss: 2.51511
# cur_epoch: 6/800, cur_it: 197/464, lr: 1e-05, loss: 2.5148
# cur_epoch: 6/800, cur_it: 198/464, lr: 1e-05, loss: 2.51407
# cur_epoch: 6/800, cur_it: 199/464, lr: 1e-05, loss: 2.5138
# cur_epoch: 6/800, cur_it: 200/464, lr: 1e-05, loss: 2.51424
# cur_epoch: 6/800, cur_it: 201/464, lr: 1e-05, loss: 2.51377
# cur_epoch: 6/800, cur_it: 202/464, lr: 1e-05, loss: 2.51365
# cur_epoch: 6/800, cur_it: 203/464, lr: 1e-05, loss: 2.51678
# cur_epoch: 6/800, cur_it: 204/464, lr: 1e-05, loss: 2.51729
# cur_epoch: 6/800, cur_it: 205/464, lr: 1e-05, loss: 2.51685
# cur_epoch: 6/800, cur_it: 206/464, lr: 1e-05, loss: 2.51665
# cur_epoch: 6/800, cur_it: 207/464, lr: 1e-05, loss: 2.51628
# cur_epoch: 6/800, cur_it: 208/464, lr: 1e-05, loss: 2.51576
# cur_epoch: 6/800, cur_it: 209/464, lr: 1e-05, loss: 2.51701
# cur_epoch: 6/800, cur_it: 210/464, lr: 1e-05, loss: 2.51602
# cur_epoch: 6/800, cur_it: 211/464, lr: 1e-05, loss: 2.51595
# cur_epoch: 6/800, cur_it: 212/464, lr: 1e-05, loss: 2.51577
# cur_epoch: 6/800, cur_it: 213/464, lr: 1e-05, loss: 2.51499
# cur_epoch: 6/800, cur_it: 214/464, lr: 1e-05, loss: 2.51513
# cur_epoch: 6/800, cur_it: 215/464, lr: 1e-05, loss: 2.51578
# cur_epoch: 6/800, cur_it: 216/464, lr: 1e-05, loss: 2.51576
# cur_epoch: 6/800, cur_it: 217/464, lr: 1e-05, loss: 2.51717
# cur_epoch: 6/800, cur_it: 218/464, lr: 1e-05, loss: 2.51671
# cur_epoch: 6/800, cur_it: 219/464, lr: 1e-05, loss: 2.51693
# cur_epoch: 6/800, cur_it: 220/464, lr: 1e-05, loss: 2.51668
# cur_epoch: 6/800, cur_it: 221/464, lr: 1e-05, loss: 2.51587
# cur_epoch: 6/800, cur_it: 222/464, lr: 1e-05, loss: 2.51553
# cur_epoch: 6/800, cur_it: 223/464, lr: 1e-05, loss: 2.51449
# cur_epoch: 6/800, cur_it: 224/464, lr: 1e-05, loss: 2.51447
# cur_epoch: 6/800, cur_it: 225/464, lr: 1e-05, loss: 2.51472
# cur_epoch: 6/800, cur_it: 226/464, lr: 1e-05, loss: 2.51485
# cur_epoch: 6/800, cur_it: 227/464, lr: 1e-05, loss: 2.51452
# cur_epoch: 6/800, cur_it: 228/464, lr: 1e-05, loss: 2.51451
# cur_epoch: 6/800, cur_it: 229/464, lr: 1e-05, loss: 2.51364
# cur_epoch: 6/800, cur_it: 230/464, lr: 1e-05, loss: 2.51392
# cur_epoch: 6/800, cur_it: 231/464, lr: 1e-05, loss: 2.5136
# cur_epoch: 6/800, cur_it: 232/464, lr: 1e-05, loss: 2.5132
# cur_epoch: 6/800, cur_it: 233/464, lr: 1e-05, loss: 2.51312
# cur_epoch: 6/800, cur_it: 234/464, lr: 1e-05, loss: 2.51276
# cur_epoch: 6/800, cur_it: 235/464, lr: 1e-05, loss: 2.51235
# cur_epoch: 6/800, cur_it: 236/464, lr: 1e-05, loss: 2.51192
# cur_epoch: 6/800, cur_it: 237/464, lr: 1e-05, loss: 2.51141
# cur_epoch: 6/800, cur_it: 238/464, lr: 1e-05, loss: 2.51102
# cur_epoch: 6/800, cur_it: 239/464, lr: 1e-05, loss: 2.511
# cur_epoch: 6/800, cur_it: 240/464, lr: 1e-05, loss: 2.51095
# cur_epoch: 6/800, cur_it: 241/464, lr: 1e-05, loss: 2.51023
# cur_epoch: 6/800, cur_it: 242/464, lr: 1e-05, loss: 2.51041
# cur_epoch: 6/800, cur_it: 243/464, lr: 1e-05, loss: 2.51064
# cur_epoch: 6/800, cur_it: 244/464, lr: 1e-05, loss: 2.51013
# cur_epoch: 6/800, cur_it: 245/464, lr: 1e-05, loss: 2.51421
# cur_epoch: 6/800, cur_it: 246/464, lr: 1e-05, loss: 2.51459
# cur_epoch: 6/800, cur_it: 247/464, lr: 1e-05, loss: 2.51425
# cur_epoch: 6/800, cur_it: 248/464, lr: 1e-05, loss: 2.51484
# cur_epoch: 6/800, cur_it: 249/464, lr: 1e-05, loss: 2.51453
# cur_epoch: 6/800, cur_it: 250/464, lr: 1e-05, loss: 2.51575
# cur_epoch: 6/800, cur_it: 251/464, lr: 1e-05, loss: 2.51535
# cur_epoch: 6/800, cur_it: 252/464, lr: 1e-05, loss: 2.51532
# cur_epoch: 6/800, cur_it: 253/464, lr: 1e-05, loss: 2.51555
# cur_epoch: 6/800, cur_it: 254/464, lr: 1e-05, loss: 2.51582
# cur_epoch: 6/800, cur_it: 255/464, lr: 1e-05, loss: 2.51613
# cur_epoch: 6/800, cur_it: 256/464, lr: 1e-05, loss: 2.51623
# cur_epoch: 6/800, cur_it: 257/464, lr: 1e-05, loss: 2.51633
# cur_epoch: 6/800, cur_it: 258/464, lr: 1e-05, loss: 2.51606
# cur_epoch: 6/800, cur_it: 259/464, lr: 1e-05, loss: 2.51654
# cur_epoch: 6/800, cur_it: 260/464, lr: 1e-05, loss: 2.51596
# cur_epoch: 6/800, cur_it: 261/464, lr: 1e-05, loss: 2.51555
# cur_epoch: 6/800, cur_it: 262/464, lr: 1e-05, loss: 2.51618
# cur_epoch: 6/800, cur_it: 263/464, lr: 1e-05, loss: 2.51611
# cur_epoch: 6/800, cur_it: 264/464, lr: 1e-05, loss: 2.5153
# cur_epoch: 6/800, cur_it: 265/464, lr: 1e-05, loss: 2.51562
# cur_epoch: 6/800, cur_it: 266/464, lr: 1e-05, loss: 2.51491
# cur_epoch: 6/800, cur_it: 267/464, lr: 1e-05, loss: 2.51443
# cur_epoch: 6/800, cur_it: 268/464, lr: 1e-05, loss: 2.51412
# cur_epoch: 6/800, cur_it: 269/464, lr: 1e-05, loss: 2.51385
# cur_epoch: 6/800, cur_it: 270/464, lr: 1e-05, loss: 2.51334
# cur_epoch: 6/800, cur_it: 271/464, lr: 1e-05, loss: 2.51291
# cur_epoch: 6/800, cur_it: 272/464, lr: 1e-05, loss: 2.5123
# cur_epoch: 6/800, cur_it: 273/464, lr: 1e-05, loss: 2.5127
# cur_epoch: 6/800, cur_it: 274/464, lr: 1e-05, loss: 2.51254
# cur_epoch: 6/800, cur_it: 275/464, lr: 1e-05, loss: 2.51272
# cur_epoch: 6/800, cur_it: 276/464, lr: 1e-05, loss: 2.51241
# cur_epoch: 6/800, cur_it: 277/464, lr: 1e-05, loss: 2.51208
# cur_epoch: 6/800, cur_it: 278/464, lr: 1e-05, loss: 2.51146
# cur_epoch: 6/800, cur_it: 279/464, lr: 1e-05, loss: 2.51103
# cur_epoch: 6/800, cur_it: 280/464, lr: 1e-05, loss: 2.5117
# cur_epoch: 6/800, cur_it: 281/464, lr: 1e-05, loss: 2.51186
# cur_epoch: 6/800, cur_it: 282/464, lr: 1e-05, loss: 2.51164
# cur_epoch: 6/800, cur_it: 283/464, lr: 1e-05, loss: 2.51183
# cur_epoch: 6/800, cur_it: 284/464, lr: 1e-05, loss: 2.51184
# cur_epoch: 6/800, cur_it: 285/464, lr: 1e-05, loss: 2.51173
# cur_epoch: 6/800, cur_it: 286/464, lr: 1e-05, loss: 2.51135
# cur_epoch: 6/800, cur_it: 287/464, lr: 1e-05, loss: 2.51059
# cur_epoch: 6/800, cur_it: 288/464, lr: 1e-05, loss: 2.51032
# cur_epoch: 6/800, cur_it: 289/464, lr: 1e-05, loss: 2.51046
# cur_epoch: 6/800, cur_it: 290/464, lr: 1e-05, loss: 2.51025
# cur_epoch: 6/800, cur_it: 291/464, lr: 1e-05, loss: 2.51073
# cur_epoch: 6/800, cur_it: 292/464, lr: 1e-05, loss: 2.51143
# cur_epoch: 6/800, cur_it: 293/464, lr: 1e-05, loss: 2.51095
# cur_epoch: 6/800, cur_it: 294/464, lr: 1e-05, loss: 2.51049
# cur_epoch: 6/800, cur_it: 295/464, lr: 1e-05, loss: 2.51044
# cur_epoch: 6/800, cur_it: 296/464, lr: 1e-05, loss: 2.50996
# cur_epoch: 6/800, cur_it: 297/464, lr: 1e-05, loss: 2.50944
# cur_epoch: 6/800, cur_it: 298/464, lr: 1e-05, loss: 2.50873
# cur_epoch: 6/800, cur_it: 299/464, lr: 1e-05, loss: 2.50827
# cur_epoch: 6/800, cur_it: 300/464, lr: 1e-05, loss: 2.50801
# cur_epoch: 6/800, cur_it: 301/464, lr: 1e-05, loss: 2.5083
# cur_epoch: 6/800, cur_it: 302/464, lr: 1e-05, loss: 2.50874
# cur_epoch: 6/800, cur_it: 303/464, lr: 1e-05, loss: 2.50968
# cur_epoch: 6/800, cur_it: 304/464, lr: 1e-05, loss: 2.50951
# cur_epoch: 6/800, cur_it: 305/464, lr: 1e-05, loss: 2.50974
# cur_epoch: 6/800, cur_it: 306/464, lr: 1e-05, loss: 2.50995
# cur_epoch: 6/800, cur_it: 307/464, lr: 1e-05, loss: 2.50986
# cur_epoch: 6/800, cur_it: 308/464, lr: 1e-05, loss: 2.51041
# cur_epoch: 6/800, cur_it: 309/464, lr: 1e-05, loss: 2.50995
# cur_epoch: 6/800, cur_it: 310/464, lr: 1e-05, loss: 2.51052
# cur_epoch: 6/800, cur_it: 311/464, lr: 1e-05, loss: 2.51036
# cur_epoch: 6/800, cur_it: 312/464, lr: 1e-05, loss: 2.51011
# cur_epoch: 6/800, cur_it: 313/464, lr: 1e-05, loss: 2.51011
# cur_epoch: 6/800, cur_it: 314/464, lr: 1e-05, loss: 2.50981
# cur_epoch: 6/800, cur_it: 315/464, lr: 1e-05, loss: 2.50976
# cur_epoch: 6/800, cur_it: 316/464, lr: 1e-05, loss: 2.50954
# cur_epoch: 6/800, cur_it: 317/464, lr: 1e-05, loss: 2.50918
# cur_epoch: 6/800, cur_it: 318/464, lr: 1e-05, loss: 2.50841
# cur_epoch: 6/800, cur_it: 319/464, lr: 1e-05, loss: 2.5088
# cur_epoch: 6/800, cur_it: 320/464, lr: 1e-05, loss: 2.50872
# cur_epoch: 6/800, cur_it: 321/464, lr: 1e-05, loss: 2.50879
# cur_epoch: 6/800, cur_it: 322/464, lr: 1e-05, loss: 2.50865
# cur_epoch: 6/800, cur_it: 323/464, lr: 1e-05, loss: 2.50871
# cur_epoch: 6/800, cur_it: 324/464, lr: 1e-05, loss: 2.50893
# cur_epoch: 6/800, cur_it: 325/464, lr: 1e-05, loss: 2.50855
# cur_epoch: 6/800, cur_it: 326/464, lr: 1e-05, loss: 2.51016
# cur_epoch: 6/800, cur_it: 327/464, lr: 1e-05, loss: 2.51016
# cur_epoch: 6/800, cur_it: 328/464, lr: 1e-05, loss: 2.51014
# cur_epoch: 6/800, cur_it: 329/464, lr: 1e-05, loss: 2.50969
# cur_epoch: 6/800, cur_it: 330/464, lr: 1e-05, loss: 2.51002
# cur_epoch: 6/800, cur_it: 331/464, lr: 1e-05, loss: 2.50995
# cur_epoch: 6/800, cur_it: 332/464, lr: 1e-05, loss: 2.50962
# cur_epoch: 6/800, cur_it: 333/464, lr: 1e-05, loss: 2.50911
# cur_epoch: 6/800, cur_it: 334/464, lr: 1e-05, loss: 2.50877
# cur_epoch: 6/800, cur_it: 335/464, lr: 1e-05, loss: 2.50846
# cur_epoch: 6/800, cur_it: 336/464, lr: 1e-05, loss: 2.50879
# cur_epoch: 6/800, cur_it: 337/464, lr: 1e-05, loss: 2.5094
# cur_epoch: 6/800, cur_it: 338/464, lr: 1e-05, loss: 2.50893
# cur_epoch: 6/800, cur_it: 339/464, lr: 1e-05, loss: 2.50897
# cur_epoch: 6/800, cur_it: 340/464, lr: 1e-05, loss: 2.50905
# cur_epoch: 6/800, cur_it: 341/464, lr: 1e-05, loss: 2.50948
# cur_epoch: 6/800, cur_it: 342/464, lr: 1e-05, loss: 2.5097
# cur_epoch: 6/800, cur_it: 343/464, lr: 1e-05, loss: 2.50968
# cur_epoch: 6/800, cur_it: 344/464, lr: 1e-05, loss: 2.51004
# cur_epoch: 6/800, cur_it: 345/464, lr: 1e-05, loss: 2.5095
# cur_epoch: 6/800, cur_it: 346/464, lr: 1e-05, loss: 2.50971
# cur_epoch: 6/800, cur_it: 347/464, lr: 1e-05, loss: 2.50978
# cur_epoch: 6/800, cur_it: 348/464, lr: 1e-05, loss: 2.50975
# cur_epoch: 6/800, cur_it: 349/464, lr: 1e-05, loss: 2.50936
# cur_epoch: 6/800, cur_it: 350/464, lr: 1e-05, loss: 2.50954
# cur_epoch: 6/800, cur_it: 351/464, lr: 1e-05, loss: 2.50925
# cur_epoch: 6/800, cur_it: 352/464, lr: 1e-05, loss: 2.50926
# cur_epoch: 6/800, cur_it: 353/464, lr: 1e-05, loss: 2.50837
# cur_epoch: 6/800, cur_it: 354/464, lr: 1e-05, loss: 2.50878
# cur_epoch: 6/800, cur_it: 355/464, lr: 1e-05, loss: 2.50855
# cur_epoch: 6/800, cur_it: 356/464, lr: 1e-05, loss: 2.50824
# cur_epoch: 6/800, cur_it: 357/464, lr: 1e-05, loss: 2.50871
# cur_epoch: 6/800, cur_it: 358/464, lr: 1e-05, loss: 2.50854
# cur_epoch: 6/800, cur_it: 359/464, lr: 1e-05, loss: 2.50842
# cur_epoch: 6/800, cur_it: 360/464, lr: 1e-05, loss: 2.50857
# cur_epoch: 6/800, cur_it: 361/464, lr: 1e-05, loss: 2.50853
# cur_epoch: 6/800, cur_it: 362/464, lr: 1e-05, loss: 2.50837
# cur_epoch: 6/800, cur_it: 363/464, lr: 1e-05, loss: 2.50788
# cur_epoch: 6/800, cur_it: 364/464, lr: 1e-05, loss: 2.5078
# cur_epoch: 6/800, cur_it: 365/464, lr: 1e-05, loss: 2.50768
# cur_epoch: 6/800, cur_it: 366/464, lr: 1e-05, loss: 2.50774
# cur_epoch: 6/800, cur_it: 367/464, lr: 1e-05, loss: 2.50789
# cur_epoch: 6/800, cur_it: 368/464, lr: 1e-05, loss: 2.50796
# cur_epoch: 6/800, cur_it: 369/464, lr: 1e-05, loss: 2.50842
# cur_epoch: 6/800, cur_it: 370/464, lr: 1e-05, loss: 2.50846
