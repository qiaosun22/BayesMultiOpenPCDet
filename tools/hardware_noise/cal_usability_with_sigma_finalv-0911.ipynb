# %%
# sorted({'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_carbon_paste_no_wait.xlsx': 1.6053081047140199,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_probe_no_wait.xlsx': 0.5089266393042919,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_silver_paste_no_wait.xlsx': 1.9243707116797577,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_silver_paste_no_wait.xlsx': 0.4798596038532671,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': 1.1362099064411009,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_10h_180+210C_FAI_PMMA_200nm_Ag_memory_6V_probe_no_wait.xlsx': 0.999128600431641,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_10h_180+210C_FAI_PMMA_200nm_Ag_memory_6V_silver_paste_no_wait.xlsx': 1.3483077229188414,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_10h_180+210C_FAI_no_200nm_Ag_memory_6V_probe_no_wait.xlsx': 1.0854602612932667,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_10h_180+210C_FAI_no_200nm_Ag_memory_6V_silver_paste_no_wait.xlsx': 0.8238809168703681,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_carbon_paste_no_wait.xlsx': 0.34418406262744244,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_carbon_paste_no_wait_2.xlsx': 1.7252790676033432,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_210C_MABr_PMMA_200nm_Ag_memory_6V_probe_no_wait.xlsx': 0.49779432049368777,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_210C_MABr_PMMA_200nm_Ag_memory_6V_silver_paste_no_wait.xlsx': 1.02057814892313,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_210C_MABr_no_200nm_Ag_memory_6V_probe_no_wait.xlsx': 0.9714238269160511,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_210C_MABr_no_200nm_Ag_memory_6V_silver_paste_no_wait.xlsx': 1.3258548636710503,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': 0.35618437120832747,
#   'I-V_data_1.2um_length_250nm_diameter_BT_4V_10s_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.22859124963661484,
#   'I-V_data_1.2um_length_250nm_diameter_BT_4V_20s_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 1.3193264203714883,
#   'I-V_data_1.2um_length_250nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_PMMA_600nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.2986867724559867,
#   'I-V_data_1.2um_length_250nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_600nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.26758176015704066,
#   'I-V_data_1.5um_length_200nm_diameter_BT_2V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_4V_carbon_paste_wait_1min.xlsx': 0.10334850013273904,
#   'I-V_data_1.5um_length_200nm_diameter_BT_2V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.1279357252476451,
#   'I-V_data_1.5um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': 0.265606257796708,
#   'I-V_data_1.5um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait_2.xlsx': 0.06283342003106338,
#   'I-V_data_1.5um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.11413417169899973,
#   'I-V_data_1.5um_length_200nm_diameter_BT_4V_annealing_500C_5hrs_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.6323925893000903,
#   'I-V_data_1.5um_length_5nm_diameter_BT_4V_NA_third_etch_8min_Pb_ED_3h_180C_MAI_no_150nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.5569351628827743,
#   'I-V_data_1.6um_length_250nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_PMMA_100nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.48648235114313826,
#   'I-V_data_1.6um_length_250nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': 0.3668149375502879,
#   'I-V_data_1.8um_length_50nm_diameter_BT_4V_NA_third_etch_20min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.11051303530682587,
#   'I-V_data_1um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': 1.8525201229872086,
#   'I-V_data_1um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': 2.0648679839473925,
#   'I-V_data_2.5um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_3V_carbon_paste_no_wait.xlsx': 1.4824583818034565,
#   'I-V_data_2.5um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_silver_paste_no_wait.xlsx': 0.38795739930579476,
#   'I-V_data_2.5um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_silver_paste_no_wait.xlsx': 0.7826797796135713,
#   'I-V_data_2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_370+450C_CsPbI3_no_200nm_Ag_memory_6V_probe_wait_1min.xlsx': 0.47505440936126203,
#   'I-V_data_2um_length_200nm_diameter_BT_4V_NA_third_etch_18min_Pb_ED_10h_180+210C_FAI_no_200nm_Ag_memory_6V_silver_paste_no_wait.xlsx': 1.290083859271837,
#   'I-V_data_2um_length_200nm_diameter_BT_4V_NA_third_etch_18min_Pb_ED_3h_210C_MABr_no_200nm_Ag_memory_6V_silver_paste_no_wait.xlsx': 1.1109402086508142,
#   'I-V_data_2um_length_200nm_diameter_BT_4V_NA_third_etch_18min_Pb_ED_3h_210C_MABr_no_200nm_Ag_memory_8V_probe_no_wait.xlsx': 1.7779616996024774,
#   'I-V_data_2um_length_250nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.4032025720611529,
#   'I-V_data_2um_length_300nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_4V_carbon_paste_no_wait.xlsx': 1.6659007283188294,
#   'I-V_data_2um_length_300nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.15000099873611333,
#   'I-V_data_3um_length_50nm_diameter_BT_4V_NA_third_etch_20min_Pb_ED_3h_180C_MAI_no_200nm_Ag_memory_6V_carbon_paste_no_wait.xlsx': 0.5869547144763468}.values())

# %%
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
from scipy.stats import norm

# def calculate_max_current(f_name):
#     df = pd.read_excel(f_name, engine='openpyxl')
#     df = df[df.iloc[:, :1].values>0]  # 只考虑电压为正的情况
#     df = df.iloc[: int(len(df)/2), :]  # 只考虑电压为正且递增的情况
#     eps = 1e-12
#     current_cols = df.iloc[:, 1:]
#     # voltage_col = df.iloc[:, :1].values
#     max_cur_lower_bound = current_cols.max(axis=0) * 0.95
#     print(max_cur_lower_bound)
    
    
    
# dir_name = './hardware_IV_and_condition_summary/hardware_data/'
# for f_name in sorted(os.listdir(dir_name)):
#     if not f_name.endswith('.xlsx'):
#         continue
        
#     print('\n'+f_name)
#     calculate_max_current(dir_name + f_name)

# %%
from scipy import interpolate
import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pykalman import KalmanFilter

import torch
import torch.nn as nn
import torch.nn.functional as F

from scipy.stats import norm
# import matplotlib.pyplot as plt

def Kalman1D(observations, damping=0):
    # To return the smoothed time series data
    observation_covariance = damping
    initial_value_guess = observations[0]
    transition_matrix = 1
    transition_covariance = 0.1
    initial_value_guess
    kf = KalmanFilter(
            initial_state_mean=initial_value_guess,
            initial_state_covariance=observation_covariance,
            observation_covariance=observation_covariance,
            transition_covariance=transition_covariance,
            transition_matrices=transition_matrix
        )
    pred_state, state_cov = kf.smooth(observations)
    return pred_state

def LCIS(arr):
    """
    求最长连续[递增]*子序列
    返回最长连续递增子序列的
    ---------
    *该[递增]序列并不要求始终严格增，而是最多允许两次递减
    """
    decrease_cnt = 0
    start_index = 0
    end_index = 0
    sub_len = 0
    longest_start = 0
    longest_end = 0
    longest_len = 0
    decrease_point_0 = -1
    decrease_point_1 = -1
    for i in range(1, len(arr)):
        if arr[i] > arr[i-1]:
            end_index += 1
        else:
            decrease_cnt += 1
            if decrease_cnt == 1:
                end_index += 1
                decrease_point_0 = end_index
            elif decrease_cnt == 2:
                end_index += 1
                decrease_point_1 = end_index
            else:
                sub_len = end_index - start_index + 1
                if longest_len < sub_len:
                    longest_len = sub_len
                    longest_start = start_index
                    longest_end = end_index
                start_index = decrease_point_0
                decrease_point_0 = decrease_point_1
                decrease_point_1 = i
                end_index = i
                decrease_cnt = 2

    sub_len = end_index - start_index + 1
    if longest_len < sub_len:
        longest_len = sub_len
        longest_start = start_index
        longest_end = end_index

    return longest_start, longest_end


def mlesigma(f_name, st_indx, end_indx):
    """
    我们引入 MLE 方法来估计忆阻器电导值与对应电压水平下电导均值的比值的 mu 和 sigma
    函数返回 sigma 值，它的值反映了等效噪声水平的强度
    '''
    关于噪声分布形式设定与转换的说明：
    X ~ logNorm(a, b)  # m, v 是对数正态分布本身的均值和方差
    # 这说的是 X 是一个值永远为正的随机变量，只有取对数之后才是正态分布
    即 logX ~ Norm(mu, sigma)

    换算关系：
    m = exp(mu + sigma^2/2)  # 注意到 m 是 >0 的
    v = exp(2*mu + sigma^2) * exp(sigma^2 - 1)  

    因此，一个随机变量 Y 如果服从正态分布，即 Y ~ Norm(mu, sigma)
    就一定可以有一个 X = exp(Y), 使得 Y = logX ~ Norm(mu, sigma)

    所以，一个正态分布随机变量取指数得到的变量就服从对数正态分布

    具体到上面的代码，已知gaussian_kernel 服从正态分布，则 
            torch.exp(noise_sigma*gassian_kernel.sample(noise_sigma.size())) 
    服从对数正态分布，其中我们施加的 mu, sigma 都是对应的正态分布的参数，而非对数正态分布的参数

    又由于 (m, v) 和 (mu, sigma) 是一一映射，我们控制谁都一样，
    所以，为了方便和统一，今后：
    1）需要采样对数正态分布样本，都采取先用 mu, sigma 采样正态分布，再 exp 的方式
    2）需要估计对数正态分布参数，都采取先对对数正态分布样本取 log，再用 norm.fit 拟合的方式
    '''
    """
    eps = 1e-12
    data = pd.read_excel(f_name, engine='openpyxl').iloc[st_indx: end_indx+1, :]
    # data = data.iloc[st_indx: end_indx+1, :]
    
    conductance = data.drop(['voltage'], axis=1).div((data['voltage']+eps), axis=0)
    # conductance = conductance[(conductance!=np.inf).all(axis=1)]
    
    conductance_by_mean = np.array(conductance.div(conductance.mean(axis=1), axis=0)).reshape(1, -1)[0]
    samples = np.log(conductance_by_mean + eps)
    samples_fine = np.delete(conductance_by_mean, np.isfinite(samples)==False)

    mu_hat, sigma_hat = norm.fit(samples_fine)  # 通过极大似然估计得到 sigma\hat，不固定均值为 0
    # mu_hat, sigma_hat = norm.fit(samples_fine, floc=0)  # 通过极大似然估计得到 sigma\hat，固定均值为 0
    return mu_hat, sigma_hat


def calculate_smoothed_cmean(f_name):
    df = pd.read_excel(f_name, engine='openpyxl')
    eps = 1e-12
    current_cols = df.iloc[:, 1:]
    voltage_col = df.iloc[:, :1].values

    conductance_cols = current_cols.div(voltage_col + eps)
    conductance_mean_col = conductance_cols.mean(axis=1).values
    conductance_mean_col_head100 = conductance_mean_col[1: 101]
    c_mean_smooth = Kalman1D(conductance_mean_col_head100)
    # c_mean_smooth = c_mean_smooth.T[0]
    return c_mean_smooth

# %%
# np.array([[1,2,np.nan],[1,2,np.nan]])

# %%
# np.nanmean(np.array([[1,2,np.nan],[1,2,np.nan]]),axis=1)

# %%
eps = 1e-8
dir_name = './hardware_IV_and_condition_summary/hardware_data/'

file2mu = {}
file2sigma = {}
file2usability = {}
file2monotune = {}

for f_name in sorted(os.listdir(dir_name)):
    
    df = pd.read_excel(dir_name+f_name, engine='openpyxl')
    
    
    df = df[df.iloc[:, :1].values>0]  # 只考虑电压为正的情况
    df = df.iloc[: int(len(df)/2), :]  # 只考虑电压为正且递增的情况

    max_cur_lower_bound = df.max(axis=0) * 0.99
    df = df[df.iloc[:, :] < max_cur_lower_bound]

    current_cols = df.iloc[:, 1:]
    voltage_col = df.iloc[:, :1].values
    conductance = current_cols / (voltage_col + eps)
    
    c_mean = conductance.mean(axis=1)
    c_std = conductance.std(axis=1)
    # c_mean = Kalman1D(np.array(c_mean).reshape(-1, 1), damping=1)
    
    longest_start, longest_end = LCIS(np.array(c_mean))
    # print(longest_start, longest_end)
    
    conductance_by_mean = conductance.div(c_mean, axis=0)[longest_start: longest_end+1]
    conductance_by_mean_array = np.array(conductance_by_mean).reshape(1, -1)[0]
    conductance_by_mean_array_dropna = conductance_by_mean_array[~np.isnan(conductance_by_mean_array)]
    
    samples = np.log(conductance_by_mean_array_dropna + eps)
    samples_dropinf = samples[~np.isinf(samples)]
    samples_fine = sorted(samples_dropinf)[int(len(samples_dropinf)*0.05): int(len(samples_dropinf)*0.95)+1]

    mu_hat, sigma_hat = norm.fit(samples_fine)  # 通过极大似然估计得到 sigma\hat，不固定均值为 0
    # mu_hat, sigma_hat = norm.fit(samples_fine, floc=0)  # 通过极大似然估计得到 sigma\hat，固定均值为 0

    # print(mu_hat, sigma_hat)
    monotune = (longest_end - longest_start) / 100.
    usability = monotune * (1 - c_std.sum() / c_mean.sum())
    # usability = (longest_end - longest_start) / 100. * (1 - sigma_hat / mu_hat)
    # usability = (longest_end - longest_start + 1) / int(len(df) / 2)
    
    file2mu[f_name] = mu_hat
    file2sigma[f_name] = sigma_hat
    file2usability[f_name] = usability
    file2monotune[f_name] = monotune
    # print(usability, sigma_hat)

file2mu, file2sigma, file2usability, file2monotune
# Out:
# ({'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_carbon_paste_no_wait.xlsx': -1.3784557844565033,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_probe_no_wait.xlsx': -0.2401378082577507,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_silver_paste_no_wait.xlsx': -1.760113237657738,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_silver_paste_no_wait.xlsx': -0.14931369516006454,
#   'I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx': -0.5641224345339781,
#   'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_10h_180+210C_FAI_PMMA_200nm_Ag_memory_6V_probe_no_wait.xlsx': -0.5390298155671931,
# ...

# %%
for f in file2mu.keys():
    print(f, file2sigma[f], file2usability[f], file2monotune[f])
# Out:
# I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_carbon_paste_no_wait.xlsx 1.6053081047140199 -0.13436791555237654 0.25
# I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_probe_no_wait.xlsx 0.5089266393042919 0.10869917826173603 0.16
# I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_1V_silver_paste_no_wait.xlsx 1.9243707116797577 -0.11143783680886774 0.24
# I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_10min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_silver_paste_no_wait.xlsx 0.4798596038532671 -0.012445312096233322 0.13
# I-V_data_0.7um_length_200nm_diameter_BT_4V_NA_third_etch_25min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_8V_carbon_paste_no_wait.xlsx 1.1362099064411009 0.054422254744230514 0.13
# ...

# %%
fdata = pd.read_excel(dir_name+'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_carbon_paste_no_wait.xlsx', engine='openpyxl')
fdata
# Out:
#      voltage  current_cycle1  current_cycle8  current_cycle9  current_cycle12
# 0        0.0    1.862650e-08    1.490120e-08    1.862650e-08     1.303850e-08  \
# 1        0.1    3.725290e-09    3.725290e-09    5.587940e-09     5.587940e-09
# 2        0.2    3.725290e-09    1.117590e-08    9.313230e-09     1.117590e-08
# 3        0.3    9.313230e-09    3.725290e-09    9.313230e-09     9.313230e-09
# 4        0.4    5.587940e-09    1.676380e-08    1.117590e-08     1.303850e-08
# ..       ...             ...             ...             ...              ...
# 199     -0.4    4.656610e-08    3.539030e-08    4.097820e-08     3.725290e-08
# 200     -0.3    4.842880e-08    4.284080e-08    5.215410e-08     4.097820e-08
# 201     -0.2    4.656610e-08    4.097820e-08    5.401670e-08     4.284080e-08
# 202     -0.1    4.284080e-08    4.097820e-08    5.215410e-08     4.842880e-08
# 203      0.0    4.284080e-08    4.284080e-08    5.401670e-08     4.656610e-08
#
# ...

# %%
plt.plot(fdata.iloc[1:101, :1], fdata.iloc[1:101, 1:].mean(axis=1))
plt.show()

# %%
# c_mean = fdata.iloc[1:101, 1:].mean(axis=1) / (fdata.iloc[1:101, :1] + eps)
# longest_start, longest_end = LCIS(np.array(c_mean))

# %%
f_name = 'I-V_data_1.2um_length_200nm_diameter_BT_4V_NA_third_etch_15min_Pb_ED_1h_180C_MAI_no_100nm_Ag_memory_5V_carbon_paste_no_wait.xlsx'

df = pd.read_excel(dir_name+f_name, engine='openpyxl')

df = df[df.iloc[:, :1].values>0]  # 只考虑电压为正的情况
df1 = df
df = df.iloc[: int(len(df)/2), :]  # 只考虑电压为正且递增的情况

max_cur_lower_bound = df.max(axis=0) * 0.99
df = df[df.iloc[:, :] < max_cur_lower_bound]

current_cols = df.iloc[:, 1:]
voltage_col = df.iloc[:, :1].values
conductance = current_cols / (voltage_col + eps)

c_mean = conductance.mean(axis=1)
c_std = conductance.std(axis=1)
# c_mean = Kalman1D(np.array(c_mean).reshape(-1, 1), damping=1)

longest_start, longest_end = LCIS(np.array(c_mean))
# print(longest_start, longest_end)
longest_start, longest_end
# Out:
# (27, 48)

# %%
plt.plot(df1.iloc[:101, :1], df1.iloc[:101, 1:].mean(axis=1))
plt.plot(voltage_col, current_cols.mean(axis=1)+0.00001)
plt.plot(voltage_col[longest_start: longest_end+1], current_cols.mean(axis=1)[longest_start: longest_end+1]-0.00001)

plt.legend(['raw', 'ltotal', 'selected'])
plt.show()

# %%
plt.plot(voltage_col[longest_start: longest_end+1], current_cols.mean(axis=1)[longest_start: longest_end+1])

# %%
voltage_col[longest_start: longest_end+1].T[0]
# Out:
# array([2.8, 2.9, 3. , 3.1, 3.2, 3.3, 3.4, 3.5, 3.6, 3.7, 3.8, 3.9, 4. ,
#        4.1, 4.2, 4.3, 4.4, 4.5, 4.6, 4.7, 4.8, 4.9])

# %%
current_cols.mean(axis=1)[longest_start: longest_end+1]
# Out:
# 28    0.000005
# 29    0.000003
# 30    0.000002
# 31    0.000003
# 32    0.000003
# 33    0.000004
# 34    0.000005
# 35    0.000007
# 36    0.000009
# 37    0.000011
# 38    0.000013
# 39    0.000015
# 40    0.000019
# 41    0.000023
# 42    0.000027
# 43    0.000033
# 44    0.000039
# 45    0.000047
# 46    0.000054
# 47    0.000064
# 48    0.000075
# 49    0.000088
# dtype: float64

# %%
(current_cols.mean(axis=1)[longest_start: longest_end+1] / voltage_col[longest_start: longest_end+1].T[0]).mean()
# Out:
# 5.709867775829512e-06

# %%
# np.save('file2sigma.npy', file2sigma)
# np.save('file2usability.npy', file2usability)
